# %%
# %reload_ext autoreload
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Sourcing parameter information

# %% [markdown]
# At this point of time, the JS side did not implement a single source our truth (SSOT) architecture,
# we won't be able to source our truth from the same place.
# So we won't be doing real SSOT here, but will try to do so at least on the python side,
# by sourcing from various key places of the JS side, and create our own master SSOT.
#
# The purpose of the `cosmograph._resources` module (whose main object is `ConfigsDacc`),
# demoed in the following section is to create, and maintain (therefore, source, diagnose, edit, etc.)
# a master SSOT json file for the python interface. From this file, we'll draw what the names of our parameters/arguments
# are, as well as their type annotations, defaults, and descriptions.
#
# Our SSOT file is

# %%
from cosmograph.util import cosmograph_base_signature, cosmograph_base_docs, PARAMS_SSOT_PATH, _params_ssot

# The ssot file is stored locally with the package. It's path is given by PARAMS_SSOT_PATH
print(f"{PARAMS_SSOT_PATH=}")
# Out:
# PARAMS_SSOT_PATH=PosixPath('/Users/thorwhalen/Dropbox/py/proj/c/cosmograph/cosmograph/data/params_ssot.json')

# %%
# To extract the ssot information, we use the _params_ssot function
params = _params_ssot()
params[:2]  # see the first two entries
# Out:
# [{'name': 'disable_simulation',
#   'default': False,
#   'annotation': 'bool',
#   'description': 'Prevents the simulation from running, merely rendering the graph.'},
#  {'name': 'simulation_decay',
#   'default': 1000,
#   'annotation': 'float',
#   'description': 'Defines how quickly the simulation cools down.'}]

# %%
# We use the params to extract the descriptions of the various parameters we use in cosmograph, 
# and therefore be able to generate the part of the documentation that lists and describtes them
print(cosmograph_base_docs()[:200], '...')
# Out:
# Parameters
# ----------
# disable_simulation : bool, default=False
#     Prevents the simulation from running, merely rendering the graph.
# simulation_decay : float, default=1000
#     Defines how quickly the  ...

# %%
# We also use params to make a propert signature for our functions (instead of relying on uninformative *args and **kwargs)
print(cosmograph_base_signature())
# Out:
# (*, disable_simulation: bool = False, simulation_decay: float = 1000, simulation_gravity: float = 0, simulation_center: float = 0, simulation_repulsion: float = 0.1, simulation_repulsion_theta: float = 1.7, simulation_repulsion_quadtree_levels: float = 12, simulation_link_spring: float = 1, simulation_link_distance: float = 2, simulation_link_dist_random_variation_range: list[typing.Any] = [1, 1.2], simulation_repulsion_from_mouse: float = 2, simulation_friction: float = 0.85, simulation_cluster: float = None, background_color: Union[str, list[float]] = '#222222', space_size: int = 4096, point_color: Union[str, list[float]] = '#b3b3b3', point_greyout_opacity: float = 0.1, point_size: float = 4, point_size_scale: float = 1, hovered_point_cursor: str = None, render_hovered_point_ring: bool = 0.7, hovered_point_ring_color: Union[str, list[float]] = 'white', focused_point_ring_color: Union[str, list[float]] = 0.95, focused_point_index: int = None, render_links: bool = True, link_color: Union[str, list[float]] = '#666666', link_greyout_opacity: float = 0.1, link_width: float = 1, link_width_scale: float = 1, curved_links: bool = False, curved_link_segments: int = 19, curved_link_weight: float = 0.8, curved_link_control_point_distance: float = 0.5, link_arrows: bool = None, link_arrows_size_scale: float = 1, link_visibility_distance_range: list[float] = [50, 150], link_visibility_min_transparency: float = 0.25, use_quadtree: bool = False, show_FPS_monitor: bool = False, pixel_ratio: float = 2, scale_points_on_zoom: bool = True, initial_zoom_level: float = 3, disable_zoom: bool = False, enable_drag: bool = None, fit_view_on_init: bool = True, fit_view_delay: float = 250, fit_view_padding: float = None, fit_view_duration: float = None, fit_view_by_points_in_rect: list[list[float]] = None, random_seed: Union[int, str] = None, point_sampling_distance: int = 150, point_id_by: str = None, point_index_by: str = None, point_color_by: str = None, point_size_by: str = None, point_size_range: list[float] = None, point_label_by: str = None, point_label_weight_by: str = None, point_x_by: str = None, point_y_by: str = None, point_cluster_by: str = None, point_cluster_strength_by: str = None, point_include_columns: list[str] = None, link_source_by: str = None, link_source_index_by: str = None, link_target_by: str = None, link_target_index_by: str = None, link_color_by: str = None, link_width_by: str = None, link_arrow_by: str = None, link_strength_by: str = None, link_strength_range: list[float] = None, link_include_columns: list[str] = None, show_labels: bool = None, show_dynamic_labels: bool = None, show_labels_for: list[str] = None, show_top_labels: bool = None, show_top_labels_limit: int = None, show_top_labels_by: str = None, static_label_weight: float = None, dynamic_label_weight: float = None, label_margin: float = None, show_hovered_point_label: bool = None, disable_point_size_legend: bool = None, disable_link_width_legend: bool = None, disable_point_color_legend: bool = None, disable_link_color_legend: bool = None, points: object = None, links: object = None, clicked_point_index: int = None, clicked_point_id: str = None, selected_point_indices: list[int] = None, selected_point_ids: list[str] = None, changePoints: Callable[[Dict[str, Any]], Any] = None, changeLinks: Callable[[Dict[str, Any]], Any] = None)

# %% [markdown]
# ## ConfigsDacc

# %% [markdown]
# The `ConfigsDacc` manages access (and creation, and diagnosis) of the configs that
# constitute the interface of cosmograph visualization functionalities.
#
# Many of it's datas have two sides to them:
# * The side that acquires the data from some fixed sources (that may get updated sometimes)
# * The side that saves prepared, ready to use, data.
#
# Here are the various kinds of datas (and their sources):
#
# * **Names**: The names from the [traitlets definition in the cosmograph_widget Cosmograph class](https://github.com/cosmograph-org/cosmograph_widget/blob/dev/src/cosmograph_widget/widget.py), since these are the only names that are defined in the widget object that bridges with JS.
# * **Annotations**: These will also use the [traitlets definition in the cosmograph_widget Cosmograph class](https://github.com/cosmograph-org/cosmograph_widget/blob/dev/src/cosmograph_widget/widget.py), since these are the actual ones defining the python types. These have been defined manually, but in a later development, we should define these via a type mapping logic based on the types taken from the TS files (see below)
# * **Defaults**: From the [cosmos/.../variables.ts](https://github.com/cosmograph-org/cosmos/blob/main/src/variables.ts) file of the main branch. This file uses a standard, `export const NAME = DEFAULT_VALUE` format, so can robustly be parsed.
# * **Kinds**: All kinds will be (as they are in the base `Cosmograph` class) keyword-only, though one or two may be converted to keyword-or-position later.
# * **Descriptions**: Could be from the TS files above, and/or from md docs. Permanent source to be determined, but currently was pointed to [this commit](https://github.com/cosmograph-org/cosmograph/blob/8c868898f256a207e12085a17566943bea49c28a/packages/website/pages/docs/v2/widget/configuration.mdx)
#
# Extras:
# * **Types**: From the five TS files;
#    * from default branch: [cosmos/config.ts](https://github.com/cosmograph-org/cosmos/blob/next/src/config.ts)
#    * from cosmograph/config dev branch; [config.ts](https://github.com/cosmograph-org/cosmograph/blob/dev/packages/cosmograph/src/cosmograph/config/config.ts), [data.ts](https://github.com/cosmograph-org/cosmograph/blob/dev/packages/cosmograph/src/cosmograph/config/data.ts), [labels.ts](https://github.com/cosmograph-org/cosmograph/blob/dev/packages/cosmograph/src/cosmograph/config/labels.ts), [simulation.ts](https://github.com/cosmograph-org/cosmograph/blob/dev/packages/cosmograph/src/cosmograph/config/simulation.ts)
#
# It should be noted that these sources all have opinions on more than one interface feature.
# They all have names, and often defaults and types.
# We will only use these, at this point, for misalignment diagnoses, until we, one day, get a proper SoT setup.

# %%
from cosmograph._resources import ConfigsDacc
import pandas as pd

c = ConfigsDacc()

print(f"{len(c.source_strings)=}")
print(f"{list(c.source_strings)=}")
print(f"Example of value: '{next(iter(c.source_strings.values()))[:40]}...'")
# Out:
# len(c.source_strings)=7
# list(c.source_strings)=['cosmos/variables.ts', 'cosmos/config.ts', 'cosmograph/config.ts', 'cosmograph/data.ts', 'cosmograph/labels.ts', 'cosmograph/simulation.ts', 'cosmograph/configuration.mdx']
# Example of value: 'export const defaultNodeColor = '#b3b3b3...'

# %% [markdown]
# The `info_dfs()` yields `(name, dataframe)` pairs for the different sources of information we'll be sourcing from.

# %%
t = dict(c.info_dfs())
list(t)
# Out:
# ['traitlets', 'defaults', 'descriptions', 'types']

# %% [markdown]
# The `matched_info_df` dataframe joins these (keeping only those names that are in the traitlets, which defines what is actually accessible to the python interface)

# %%
c.matched_info_df
# Out:
#                                                       traitlet_annotation  \
# name
# disable_simulation                                         <class 'bool'>
# simulation_decay                                          <class 'float'>
# simulation_gravity                                        <class 'float'>
# simulation_center                                         <class 'float'>
# simulation_repulsion                                      <class 'float'>
# ...                                                                   ...
# clicked_point_id                                            <class 'str'>
# selected_point_indices                                          list[int]
# selected_point_ids                                              list[str]
# changePoints            typing.Callable[[typing.Dict[str, typing.Any]]...
# changeLinks             typing.Callable[[typing.Dict[str, typing.Any]]...
#
#                        defaults_default ts_types_default  \
# name
# disable_simulation                False              NaN
# simulation_decay                   1000              NaN
# simulation_gravity                    0              NaN
# simulation_center                     0              NaN
# simulation_repulsion                0.1              NaN
# ...                                 ...              ...
# clicked_point_id                    NaN              NaN
# selected_point_indices              NaN              NaN
# selected_point_ids                  NaN              NaN
# changePoints                        NaN              NaN
# changeLinks                         NaN              NaN
#
#                        md_descriptions_default  \
# name
# disable_simulation                        None
# simulation_decay                          1000
# simulation_gravity                           0
# simulation_center                            0
# simulation_repulsion                       0.1
# ...                                        ...
# clicked_point_id                           NaN
# selected_point_indices                     NaN
# selected_point_ids                         NaN
# changePoints                               NaN
# changeLinks                                NaN
#
#                                               md_descriptions_description  \
# name
# disable_simulation      Prevents the simulation from running, merely r...
# simulation_decay           Defines how quickly the simulation cools down.
# simulation_gravity                         Coefficient for gravity force.
# simulation_center                     Centers the mass force coefficient.
# simulation_repulsion           Configures point repulsion between points.
# ...                                                                   ...
# clicked_point_id                                                      NaN
# selected_point_indices                                                NaN
# selected_point_ids                                                    NaN
# changePoints                                                          NaN
# changeLinks                                                           NaN
#
#                                                      ts_types_description  \
# name
# disable_simulation      Do not run the simulation, just render the gra...
# simulation_decay        Decay coefficient for simulation cool down rat...
# simulation_gravity             Gravity force coefficient. Default `0.25`.
# simulation_center       Centering to center mass force coefficient. De...
# simulation_repulsion          Repulsion force coefficient. Default `1.0`.
# ...                                                                   ...
# clicked_point_id                                                      NaN
# selected_point_indices                                                NaN
# selected_point_ids                                                    NaN
# changePoints                                                          NaN
# changeLinks                                                           NaN
#
#                        ts_types_type     traitlet_default  \
# name
# disable_simulation           boolean                 None
# simulation_decay              number                 None
# simulation_gravity            number                 None
# simulation_center             number                 None
# simulation_repulsion          number                 None
# ...                              ...                  ...
# clicked_point_id                 NaN                 None
# selected_point_indices           NaN  traitlets.Undefined
# selected_point_ids               NaN  traitlets.Undefined
# changePoints                     NaN  traitlets.Undefined
# changeLinks                      NaN  traitlets.Undefined
#
#                        md_descriptions_type md_descriptions_group  \
# name
# disable_simulation                  boolean   Simulation Settings
# simulation_decay                     number   Simulation Settings
# simulation_gravity                   number   Simulation Settings
# simulation_center                    number   Simulation Settings
# simulation_repulsion                 number   Simulation Settings
# ...                                     ...                   ...
# clicked_point_id                        NaN                   NaN
# selected_point_indices                  NaN                   NaN
# selected_point_ids                      NaN                   NaN
# changePoints                            NaN                   NaN
# changeLinks                             NaN                   NaN
#
#                        md_descriptions_optional        ts_types_name  \
# name
# disable_simulation                         True    disableSimulation
# simulation_decay                           True      simulationDecay
# simulation_gravity                         True    simulationGravity
# simulation_center                          True     simulationCenter
# simulation_repulsion                       True  simulationRepulsion
# ...                                         ...                  ...
# clicked_point_id                            NaN                  NaN
# selected_point_indices                      NaN                  NaN
# selected_point_ids                          NaN                  NaN
# changePoints                                NaN                  NaN
# changeLinks                                 NaN                  NaN
#
#                        ts_types_optional      ts_types_py_name  \
# name
# disable_simulation                  True    disable_simulation
# simulation_decay                    True      simulation_decay
# simulation_gravity                  True    simulation_gravity
# simulation_center                   True     simulation_center
# simulation_repulsion                True  simulation_repulsion
# ...                                  ...                   ...
# clicked_point_id                     NaN                   NaN
# selected_point_indices               NaN                   NaN
# selected_point_ids                   NaN                   NaN
# changePoints                         NaN                   NaN
# changeLinks                          NaN                   NaN
#
#                         ts_types_origin_name
# name
# disable_simulation      GraphConfigInterface
# simulation_decay        GraphConfigInterface
# simulation_gravity      GraphConfigInterface
# simulation_center       GraphConfigInterface
# simulation_repulsion    GraphConfigInterface
# ...                                      ...
# clicked_point_id                         NaN
# selected_point_indices                   NaN
# selected_point_ids                       NaN
# changePoints                             NaN
# changeLinks                              NaN
#
# [97 rows x 15 columns]

# %%
c.matched_info_df.loc['render_hovered_point_ring']
# Out:
# traitlet_annotation                                               <class 'bool'>
# defaults_default                                                             0.7
# ts_types_default                                                             NaN
# md_descriptions_default                                                    False
# md_descriptions_description                  Enables ring around hovered points.
# ts_types_description           Rings rendering around a point on hover toggle...
# ts_types_type                                                            boolean
# traitlet_default                                                            None
# md_descriptions_type                                                     boolean
# md_descriptions_group                                           Graph Appearance
# md_descriptions_optional                                                    True
# ts_types_name                                             renderHoveredPointRing
# ts_types_optional                                                           True
# ts_types_py_name                                       render_hovered_point_ring
# ts_types_origin_name                                        GraphConfigInterface
# Name: render_hovered_point_ring, dtype: object

# %% [markdown]
# ## Example usage of these tables (exporting them for docs, making signatures, etc.)

# %%
# copy markdown version of matched_info_df to clipboard
__import__('pyperclip').copy(c.matched_info_df_prepared_for_export().to_markdown())

# %%
# copy csv version of matched_info_df to clipboard
__import__('pyperclip').copy(c.matched_info_df_prepared_for_export().to_csv(sep='\t'))

# %%
# The signature of the base class, made from the matched_info_df information
sig = c.cosmograph_base_signature()
sig
# Out:
# <Sig (*, disable_simulation: bool = False, simulation_decay: float = 1000, simulation_gravity: float = 0, simulation_center: float = 0, simulation_repulsion: float = 0.1, simulation_repulsion_theta: float = 1.7, simulation_repulsion_quadtree_levels: float = 12, simulation_link_spring: float = 1, simulation_link_distance: float = 2, simulation_link_dist_random_variation_range: list[typing.Any] = [1, 1.2], simulation_repulsion_from_mouse: float = 2, simulation_friction: float = 0.85, background_color: Union[str, list[float]] = '#222222', space_size: int = 4096, default_point_color: Union[str, list[float]] = nan, point_greyout_opacity: float = 0.1, default_point_size: float = nan, point_size_scale: float = 1, hovered_point_cursor: str = nan, render_hovered_point_ring: bool = 0.7, hovered_point_ring_color: Union[str, list[float]] = 'white', focused_point_ring_color: Union[str, list[float]] = 0.95, focused_point_index: int = nan, render_links: bool = True, default_link_color: Union[str, list[float]] = nan, link_greyout_opacity: float = 0.1, default_link_width: float = nan, link_width_scale: float = 1, curved_links: bool = False, curved_link_segments: int = 19, curved_link_weight: float = 0.8, curved_link_control_point_distance: float = 0.5, default_link_arrows: bool = True, link_arrows_size_scale: float = 1, link_visibility_distance_range: list[float] = [50, 150], link_visibility_min_transparency: float = 0.25, use_quadtree: bool = False, show_FPS_monitor: bool = False, pixel_ratio: float = 2, scale_points_on_zoom: bool = True, initial_zoom_level: float = 3, disable_zoom: bool = False, enable_drag: bool = nan, fit_view_on_init: bool = True, fit_view_delay: float = 250, fit_view_padding: float = nan, fit_view_duration: float = nan, fit_view_by_points_in_rect: list[list[float]] = nan, random_seed: Union[int, str] = nan, point_sampling_distance: int = 150, point_id: str = nan, point_index: str = nan, point_color: str = '#b3b3b3', point_size: str = 4, point_label: str = nan, point_label_weight: str = nan, point_x: str = nan, point_y: str = nan, point_include_columns: list[str] = nan, link_source: str = nan, link_source_index: str = nan, link_target: str = nan, link_target_index: str = nan, link_color: str = '#666666', link_width: str = 1, link_arrow: str = nan, link_strength: str = nan, link_include_columns: list[str] = nan, show_dynamic_labels: bool = nan, show_labels_for: list[str] = nan, show_top_labels: bool = nan, show_top_labels_limit: int = nan, show_top_labels_by: str = nan, static_label_weight: float = nan, dynamic_label_weight: float = nan, label_padding: float = nan, show_hovered_point_label: bool = nan, disable_point_size_legend: bool = nan, disable_link_width_legend: bool = nan, disable_point_color_legend: bool = nan, disable_link_color_legend: bool = nan, points: object = nan, links: object = nan, clicked_point_index: int = nan, selected_point_indices: list[int] = nan, changePoints: Callable[[Dict[str, Any]], Any] = nan, changeLinks: Callable[[Dict[str, Any]], Any] = nan)>

# %%
# Make the docs (params info part) for the base class
len(c.cosmograph_base_docs())
# Out:
# 7588

# %% [markdown]
# ## Diagnoses

# %%
c.print_diagnosis()
# Out:
# Duplicates of types group:
#
#                                                            0                      1
# disableSimulation                       GraphConfigInterface            BasicConfig
# simulationDecay                         GraphConfigInterface       SimulationConfig
# simulationGravity                       GraphConfigInterface       SimulationConfig
# simulationCenter                        GraphConfigInterface       SimulationConfig
# simulationRepulsion                     GraphConfigInterface       SimulationConfig
# simulationRepulsionTheta                GraphConfigInterface       SimulationConfig
# simulationRepulsionQuadtreeLevels       GraphConfigInterface       SimulationConfig
# simulationLinkSpring                    GraphConfigInterface       SimulationConfig
# simulationLinkDistance                  GraphConfigInterface       SimulationConfig
# simulationLinkDistRandomVariationRange  GraphConfigInterface       SimulationConfig
# simulationRepulsionFromMouse            GraphConfigInterface       SimulationConfig
# simulationFriction                      GraphConfigInterface       SimulationConfig
# onSimulationStart                       GraphConfigInterface  SimulationEventConfig
# onSimulationTick                        GraphConfigInterface  SimulationEventConfig
# onSimulationEnd                         GraphConfigInterface  SimulationEventConfig
# onSimulationPause                       GraphConfigInterface  SimulationEventConfig
# onSimulationRestart                     GraphConfigInterface  SimulationEventConfig

# %% [markdown]
# # Updating the configs

# %% [markdown]
# But how did we get these resources and configs data?
# How do we update them?
#
# We'll just take care of configs here.
# `ConfigDacc` is still your go-to tool.
# It's built to do everything it does in a lazy-eval fashion.
#
# When you do `current = ConfigsDacc()` what you get is an instance that points to the default place where prepared config data is saved.
# One thing you can do is just delete those files, and as you try to access configuration data,
# the `ConfigsDacc` instance will recreate them (fetch the original sources online, process them, and finally save the prepared data).
#
# But we prefer the following method: Staging the updated data, then comparing to the current configuration data, and finally replacing it if all looks okay.

# %% [markdown]
# So the first thing we'll do is select a temporary folder to put our staging data.
# You can do this however you want: Here we'll use a temporary folder for this.

# %%
import os
from dol import temp_dir


if 'staging_dir' not in locals():
    # if the staging_dir is not already defined, create a new one
    # Note: If you need a new dir, delete or empty the old one first
    staging_dir = temp_dir('cosmograph_config_staging_dir')

_staging_dir_contents = list(os.listdir(staging_dir))
if _staging_dir_contents:
    print(f"Warning: The staging dir is not empty: {_staging_dir_contents}")

staging_dir
# Out:
# Warning: The staging dir is not empty: ['config_prep']
# '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/cosmograph_config_staging_dir'

# %% [markdown]
# Now you can make two instances of `ConfigsDacc`: One pointing to the current data,
# and the other to `staging_dir`, where you'll renew the configs.

# %%
from cosmograph._resources import ConfigsDacc

current = ConfigsDacc()
stage = ConfigsDacc(staging_dir)

# %% [markdown]
# Now what we'll do is compare both `current` and `stage`, and if and when we feel like the `stage` is good, we can copy the files over.
#
# See that part below in the "Replacing current with stage".

# %%
current.matched_info_df
# Out:
#                                                       traitlet_annotation  \
# name
# disable_simulation                                         <class 'bool'>
# simulation_decay                                          <class 'float'>
# simulation_gravity                                        <class 'float'>
# simulation_center                                         <class 'float'>
# simulation_repulsion                                      <class 'float'>
# ...                                                                   ...
# clicked_point_id                                            <class 'str'>
# selected_point_indices                                          list[int]
# selected_point_ids                                              list[str]
# changePoints            typing.Callable[[typing.Dict[str, typing.Any]]...
# changeLinks             typing.Callable[[typing.Dict[str, typing.Any]]...
#
#                        defaults_default ts_types_default  \
# name
# disable_simulation                False              NaN
# simulation_decay                   1000              NaN
# simulation_gravity                    0              NaN
# simulation_center                     0              NaN
# simulation_repulsion                0.1              NaN
# ...                                 ...              ...
# clicked_point_id                    NaN              NaN
# selected_point_indices              NaN              NaN
# selected_point_ids                  NaN              NaN
# changePoints                        NaN              NaN
# changeLinks                         NaN              NaN
#
#                        md_descriptions_default  \
# name
# disable_simulation                        None
# simulation_decay                          1000
# simulation_gravity                           0
# simulation_center                            0
# simulation_repulsion                       0.1
# ...                                        ...
# clicked_point_id                           NaN
# selected_point_indices                     NaN
# selected_point_ids                         NaN
# changePoints                               NaN
# changeLinks                                NaN
#
#                                               md_descriptions_description  \
# name
# disable_simulation      Prevents the simulation from running, merely r...
# simulation_decay           Defines how quickly the simulation cools down.
# simulation_gravity                         Coefficient for gravity force.
# simulation_center                     Centers the mass force coefficient.
# simulation_repulsion           Configures point repulsion between points.
# ...                                                                   ...
# clicked_point_id                                                      NaN
# selected_point_indices                                                NaN
# selected_point_ids                                                    NaN
# changePoints                                                          NaN
# changeLinks                                                           NaN
#
#                                                      ts_types_description  \
# name
# disable_simulation      Do not run the simulation, just render the gra...
# simulation_decay        Decay coefficient for simulation cool down rat...
# simulation_gravity             Gravity force coefficient. Default `0.25`.
# simulation_center       Centering to center mass force coefficient. De...
# simulation_repulsion          Repulsion force coefficient. Default `1.0`.
# ...                                                                   ...
# clicked_point_id                                                      NaN
# selected_point_indices                                                NaN
# selected_point_ids                                                    NaN
# changePoints                                                          NaN
# changeLinks                                                           NaN
#
#                        ts_types_type     traitlet_default  \
# name
# disable_simulation           boolean                 None
# simulation_decay              number                 None
# simulation_gravity            number                 None
# simulation_center             number                 None
# simulation_repulsion          number                 None
# ...                              ...                  ...
# clicked_point_id                 NaN                 None
# selected_point_indices           NaN  traitlets.Undefined
# selected_point_ids               NaN  traitlets.Undefined
# changePoints                     NaN  traitlets.Undefined
# changeLinks                      NaN  traitlets.Undefined
#
#                        md_descriptions_type md_descriptions_group  \
# name
# disable_simulation                  boolean   Simulation Settings
# simulation_decay                     number   Simulation Settings
# simulation_gravity                   number   Simulation Settings
# simulation_center                    number   Simulation Settings
# simulation_repulsion                 number   Simulation Settings
# ...                                     ...                   ...
# clicked_point_id                        NaN                   NaN
# selected_point_indices                  NaN                   NaN
# selected_point_ids                      NaN                   NaN
# changePoints                            NaN                   NaN
# changeLinks                             NaN                   NaN
#
#                        md_descriptions_optional        ts_types_name  \
# name
# disable_simulation                         True    disableSimulation
# simulation_decay                           True      simulationDecay
# simulation_gravity                         True    simulationGravity
# simulation_center                          True     simulationCenter
# simulation_repulsion                       True  simulationRepulsion
# ...                                         ...                  ...
# clicked_point_id                            NaN                  NaN
# selected_point_indices                      NaN                  NaN
# selected_point_ids                          NaN                  NaN
# changePoints                                NaN                  NaN
# changeLinks                                 NaN                  NaN
#
#                        ts_types_optional      ts_types_py_name  \
# name
# disable_simulation                  True    disable_simulation
# simulation_decay                    True      simulation_decay
# simulation_gravity                  True    simulation_gravity
# simulation_center                   True     simulation_center
# simulation_repulsion                True  simulation_repulsion
# ...                                  ...                   ...
# clicked_point_id                     NaN                   NaN
# selected_point_indices               NaN                   NaN
# selected_point_ids                   NaN                   NaN
# changePoints                         NaN                   NaN
# changeLinks                          NaN                   NaN
#
#                         ts_types_origin_name
# name
# disable_simulation      GraphConfigInterface
# simulation_decay        GraphConfigInterface
# simulation_gravity      GraphConfigInterface
# simulation_center       GraphConfigInterface
# simulation_repulsion    GraphConfigInterface
# ...                                      ...
# clicked_point_id                         NaN
# selected_point_indices                   NaN
# selected_point_ids                       NaN
# changePoints                             NaN
# changeLinks                              NaN
#
# [97 rows x 15 columns]

# %%
stage.matched_info_df # takes ~2 minutes to run the first time
# Out:
# [autoreload of cosmograph._resources failed: Traceback (most recent call last):
#   File "/Users/thorwhalen/Dropbox/py/proj/i/dol/dol/filesys.py", line 276, in wrapped_method
#     return func(self, k, *args, **kwargs)
#   File "/Users/thorwhalen/Dropbox/py/proj/i/dol/dol/filesys.py", line 480, in __getitem__
#     with open(k, **self._read_open_kwargs) as fp:
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/thorwhalen/Dropbox/py/proj/c/py_cosmograph/cosmograph/data/config_info.json'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/thorwhalen/.pyenv/versions/3.10.13/envs/p10/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/thorwhalen/.pyenv/versions/3.10.13/envs/p10/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/Users/thorwhalen/.pyenv/versions/3.10.13/envs/p10/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/Users/thorwhalen/.pyenv/versions/3.10.13/envs/p10/lib/python3.10/site-packages/IPython/extensions/autoreload.py", line 335, in update_class
#     if (old_obj == new_obj) is True:
#   File "/Users/thorwhalen/.pyenv/versions/3.10.13/lib/python3.10/_collections_abc.py", line 851, in __eq__
#     return dict(self.items()) == dict(other.items())
#   File "/Users/thorwhalen/.pyenv/versions/3.10.13/lib/python3.10/_collections_abc.py", line 911, in __iter__
#     yield (key, self._mapping[key])
#   File "/Users/thorwhalen/Dropbox/py/proj/i/dol/dol/sources.py", line 758, in __getitem__
#     return self.funcs[k]()  # call the func
#   File "/Users/thorwhalen/Dropbox/py/proj/c/py_cosmograph/cosmograph/_resources.py", line 1038, in old_config_info
#     _config_info = json_files['config_info.json']
#   File "/Users/thorwhalen/Dropbox/py/proj/i/dol/dol/trans.py", line 1437, in __getitem__
#     return super(store_cls, self).__getitem__(k)
#   File "/Users/thorwhalen/Dropbox/py/proj/i/dol/dol/base.py", line 639, in __getitem__
#     raise error
# KeyError: FileNotFoundError(2, 'No such file or directory')
# ]
# /Users/thorwhalen/Dropbox/py/proj/c/py_cosmograph/cosmograph/_resources.py:435: UserWarning: WARNING:
# widget_config had some duplicate propertiesFirst and last instances of duplicates:
#                   name              type  \
# 88          PointColor            string
# 90   PointColorPalette          string[]
# 93           PointSize            string
# 94      PointSizeRange  [number, number]
# 108          LinkColor            string
# 110          LinkWidth            string
# 111     LinkWidthRange  [number, number]
# 117  LinkStrengthRange  [number, number]
#
#                                            description  optional  \
# 88   The column name for the point color. If provid...      True
# 90   An optional array of color strings used to col...      True
# 93   The column name for the point size. If provide...      True
# 94   Defines the range for automatic point size sca...      True
# 108  The column name for the link color. Colors lin...      True
# 110  The column name for the link width. Links will...      True
# 111  Defines range for automatic link width scaling...      True
# 117  Defines range for automatic link strength scal...      True
#
#                  py_name             origin_name     default properties
# 88           point_color  CosmographPointsConfig         NaN        NaN
# 90   point_color_palette  CosmographPointsConfig         NaN        NaN
# 93            point_size  CosmographPointsConfig         NaN        NaN
# 94      point_size_range  CosmographPointsConfig      [2, 9]        NaN
# 108           link_color   CosmographLinksConfig         NaN        NaN
# 110           link_width   CosmographLinksConfig         NaN        NaN
# 111     link_width_range   CosmographLinksConfig      [1, 9]        NaN
# 117  link_strength_range   CosmographLinksConfig  [0.2, 1.0]        NaN
#                  name                                       type  \
# 3          pointColor  string | [number, number, number, number]
# 5           pointSize                                     number
# 13          linkColor  string | [number, number, number, number]
# 15          linkWidth                                     number
# 74     pointSizeRange                                    unknown
# 75     linkWidthRange                                    unknown
# 76  linkStrengthRange                                    unknown
# 77  pointColorPalette                                    unknown
#
#                                           description  optional  \
# 3   The default color to use for points when not p...      True
# 5   The default size value to use for points. Defa...      True
# 13  The default color to use for links. Can be a h...      True
# 15  The default width value to use for links. Defa...      True
# 74            Range for point sizes within the graph.     False
# 75            Range for link widths within the graph.     False
# 76         Range for link strengths within the graph.     False
# 77                      Palette of colors for points.     False
#
#                 py_name              origin_name default properties
# 3           point_color     GraphConfigInterface     NaN        NaN
# 5            point_size     GraphConfigInterface     NaN        NaN
# 13           link_color     GraphConfigInterface     NaN        NaN
# 15           link_width     GraphConfigInterface     NaN        NaN
# 74     point_size_range  DefaultCosmographConfig     NaN        NaN
# 75     link_width_range  DefaultCosmographConfig     NaN        NaN
# 76  link_strength_range  DefaultCosmographConfig     NaN        NaN
# 77  point_color_palette  DefaultCosmographConfig     NaN        NaN
#   warn(f"WARNING:\n{msg}")
#                                                       traitlet_annotation  \
# name
# disable_simulation                                         <class 'bool'>
# simulation_decay                                          <class 'float'>
# simulation_gravity                                        <class 'float'>
# simulation_center                                         <class 'float'>
# simulation_repulsion                                      <class 'float'>
# ...                                                                   ...
# clicked_point_id                                            <class 'str'>
# selected_point_indices                                          list[int]
# selected_point_ids                                              list[str]
# changePoints            typing.Callable[[typing.Dict[str, typing.Any]]...
# changeLinks             typing.Callable[[typing.Dict[str, typing.Any]]...
#
#                        defaults_default ts_types_default  \
# name
# disable_simulation                False              NaN
# simulation_decay                   5000              NaN
# simulation_gravity                 0.25              NaN
# simulation_center                     0              NaN
# simulation_repulsion                  1              NaN
# ...                                 ...              ...
# clicked_point_id                    NaN              NaN
# selected_point_indices              NaN              NaN
# selected_point_ids                  NaN              NaN
# changePoints                        NaN              NaN
# changeLinks                         NaN              NaN
#
#                        md_descriptions_default  \
# name
# disable_simulation                        None
# simulation_decay                          1000
# simulation_gravity                           0
# simulation_center                            0
# simulation_repulsion                       0.1
# ...                                        ...
# clicked_point_id                           NaN
# selected_point_indices                     NaN
# selected_point_ids                         NaN
# changePoints                               NaN
# changeLinks                                NaN
#
#                                               md_descriptions_description  \
# name
# disable_simulation      Prevents the simulation from running, merely r...
# simulation_decay           Defines how quickly the simulation cools down.
# simulation_gravity                         Coefficient for gravity force.
# simulation_center                     Centers the mass force coefficient.
# simulation_repulsion           Configures point repulsion between points.
# ...                                                                   ...
# clicked_point_id                                                      NaN
# selected_point_indices                                                NaN
# selected_point_ids                                                    NaN
# changePoints                                                          NaN
# changeLinks                                                           NaN
#
#                                                      ts_types_description  \
# name
# disable_simulation      Do not run the simulation, just render the gra...
# simulation_decay                 Decay coefficient. Default value: `5000`
# simulation_gravity       Gravity force coefficient. Default value: `0.25`
# simulation_center       Centering to center mass force coefficient. De...
# simulation_repulsion    Repulsion force coefficient. Default value: `1.0`
# ...                                                                   ...
# clicked_point_id                                                      NaN
# selected_point_indices                                                NaN
# selected_point_ids                                                    NaN
# changePoints                                                          NaN
# changeLinks                                                           NaN
#
#                        ts_types_type     traitlet_default  \
# name
# disable_simulation           boolean                 None
# simulation_decay              number                 None
# simulation_gravity            number                 None
# simulation_center             number                 None
# simulation_repulsion          number                 None
# ...                              ...                  ...
# clicked_point_id                 NaN                 None
# selected_point_indices           NaN  traitlets.Undefined
# selected_point_ids               NaN  traitlets.Undefined
# changePoints                     NaN  traitlets.Undefined
# changeLinks                      NaN  traitlets.Undefined
#
#                        md_descriptions_type md_descriptions_group  \
# name
# disable_simulation                  boolean   Simulation Settings
# simulation_decay                     number   Simulation Settings
# simulation_gravity                   number   Simulation Settings
# simulation_center                    number   Simulation Settings
# simulation_repulsion                 number   Simulation Settings
# ...                                     ...                   ...
# clicked_point_id                        NaN                   NaN
# selected_point_indices                  NaN                   NaN
# selected_point_ids                      NaN                   NaN
# changePoints                            NaN                   NaN
# changeLinks                             NaN                   NaN
#
#                        md_descriptions_optional        ts_types_name  \
# name
# disable_simulation                         True    disableSimulation
# simulation_decay                           True      simulationDecay
# simulation_gravity                         True    simulationGravity
# simulation_center                          True     simulationCenter
# simulation_repulsion                       True  simulationRepulsion
# ...                                         ...                  ...
# clicked_point_id                            NaN                  NaN
# selected_point_indices                      NaN                  NaN
# selected_point_ids                          NaN                  NaN
# changePoints                                NaN                  NaN
# changeLinks                                 NaN                  NaN
#
#                        ts_types_optional      ts_types_py_name  \
# name
# disable_simulation                  True    disable_simulation
# simulation_decay                    True      simulation_decay
# simulation_gravity                  True    simulation_gravity
# simulation_center                   True     simulation_center
# simulation_repulsion                True  simulation_repulsion
# ...                                  ...                   ...
# clicked_point_id                     NaN                   NaN
# selected_point_indices               NaN                   NaN
# selected_point_ids                   NaN                   NaN
# changePoints                         NaN                   NaN
# changeLinks                          NaN                   NaN
#
#                         ts_types_origin_name ts_types_properties
# name
# disable_simulation      GraphConfigInterface                 NaN
# simulation_decay        GraphConfigInterface                 NaN
# simulation_gravity      GraphConfigInterface                 NaN
# simulation_center       GraphConfigInterface                 NaN
# simulation_repulsion    GraphConfigInterface                 NaN
# ...                                      ...                 ...
# clicked_point_id                         NaN                 NaN
# selected_point_indices                   NaN                 NaN
# selected_point_ids                       NaN                 NaN
# changePoints                             NaN                 NaN
# changeLinks                              NaN                 NaN
#
# [97 rows x 16 columns]

# %%
# stage.matched_info_df.loc['render_hovered_point_ring']

# %%
from cosmograph._resources import source_url_groups

def parsed_defaults(self):
    from jy import variable_declarations_pairs

    for k in source_url_groups['defaults']:
        yield k, dict(variable_declarations_pairs(self.source_strings[k]))

t = dict(parsed_defaults(stage))

# %%
t
# Out:
# {'cosmos/variables.ts': {'defaultPointColor': '#b3b3b3',
#   'defaultGreyoutPointOpacity': 0.1,
#   'defaultPointSize': 4,
#   'defaultLinkColor': '#666666',
#   'defaultGreyoutLinkOpacity': 0.1,
#   'defaultLinkWidth': 1,
#   'defaultBackgroundColor': '#222222',
#   'defaultConfigValues': {'disableSimulation': False,
#    'spaceSize': 8192,
#    'pointSizeScale': 1,
#    'linkWidthScale': 1,
#    'arrowSizeScale': 1,
#    'renderLinks': True,
#    'curvedLinks': False,
#    'curvedLinkSegments': 19,
#    'curvedLinkWeight': 0.8,
#    'curvedLinkControlPointDistance': 0.5,
#    'arrowLinks': False,
#    'linkVisibilityDistanceRange': [50, 150],
#    'linkVisibilityMinTransparency': 0.25,
#    'hoveredPointCursor': 'auto',
#    'renderHoveredPointRing': False,
#    'hoveredPointRingColor': 'white',
#    'focusedPointRingColor': 'white',
#    'focusedPointIndex': None,
#    'useQuadtree': False,
#    'simulation': {'decay': 5000,
#     'gravity': 0.25,
#     'center': 0,
#     'repulsion': 1,
#     'repulsionTheta': 1.15,
#     'repulsionQuadtreeLevels': 12,
#     'linkSpring': 1,
#     'linkDistance': 10,
#     'linkDistRandomVariationRange': [1, 1.2],
#     'repulsionFromMouse': 2,
#     'friction': 0.85,
#     'cluster': 0.1},
#    'showFPSMonitor': False,
#    'pixelRatio': 2,
#    'scalePointsOnZoom': True,
#    'disableZoom': False,
#    'enableDrag': False,
#    'fitViewOnInit': True,
#    'fitViewDelay': 250,
#    'fitViewPadding': 0.1,
#    'fitViewDuration': 250,
#    'pointSamplingDistance': 150,
#    'disableAttribution': False},
#   'hoveredPointRingOpacity': 0.7,
#   'focusedPointRingOpacity': 0.95,
#   'defaultScaleToZoom': 3}}

# %%
# Out:
# '/var/folders/mc/c070wfh51kxd9lft8dl74q1r0000gn/T/cosmograph_config_staging_dir/config_prep'

# %%
from pyperclip import copy
from cosmograph import Cosmograph
copy(stage.matched_info_df.fillna('').to_markdown())

# %% [markdown]
# ### What parameters are not documented?

# %%
md_descriptions = stage.matched_info_df.md_descriptions_description
missing_md_descriptions = md_descriptions[md_descriptions.isna()].fillna('').drop(['_ipc_points', '_ipc_links'])
print(f"{len(missing_md_descriptions)} missing descriptions")
missing_md_descriptions
# Out:
# 34 missing descriptions
# name
# simulation_cluster
# link_arrows
# point_id_by
# point_index_by
# point_color_by
# point_size_by
# point_size_range
# point_label_by
# point_label_weight_by
# point_x_by
# point_y_by
# point_cluster_by
# point_cluster_strength_by
# link_source_by
# link_source_index_by
# link_target_by
# link_target_index_by
# link_color_by
# link_width_by
# link_arrow_by
# link_strength_by
# link_strength_range
# show_labels
# label_margin
# disable_point_size_legend
# disable_link_width_legend
# disable_point_color_legend
# disable_link_color_legend
# clicked_point_index
# clicked_point_id
# selected_point_indices
# selected_point_ids
# changePoints
# changeLinks
# Name: md_descriptions_description, dtype: object

# %%
ts_descriptions = stage.matched_info_df.ts_types_description
missing_ts_descriptions = ts_descriptions[ts_descriptions.isna()].fillna('').drop(['_ipc_points', '_ipc_links'])
print(f"{len(missing_ts_descriptions)} missing descriptions")
missing_ts_descriptions
# Out:
# 11 missing descriptions
# name
# show_FPS_monitor
# disable_point_size_legend
# disable_link_width_legend
# disable_point_color_legend
# disable_link_color_legend
# clicked_point_index
# clicked_point_id
# selected_point_indices
# selected_point_ids
# changePoints
# changeLinks
# Name: ts_types_description, dtype: object

# %%
set(missing_ts_descriptions.index) & set(missing_md_descriptions.index)
# Out:
# {'changeLinks',
#  'changePoints',
#  'clicked_point_id',
#  'clicked_point_index',
#  'disable_link_color_legend',
#  'disable_link_width_legend',
#  'disable_point_color_legend',
#  'disable_point_size_legend',
#  'selected_point_ids',
#  'selected_point_indices'}

# %%
set(missing_ts_descriptions.index) - set(missing_md_descriptions.index)
# Out:
# {'show_FPS_monitor'}

# %%
# get duplicates of stage.matched_info_df.ts_types_name
duplicates = stage.matched_info_df.ts_types_name[stage.matched_info_df.ts_types_name.duplicated(keep=False)]
stage.matched_info_df.ts_types_name
# Out:
# name
# disable_simulation          disableSimulation
# simulation_decay              simulationDecay
# simulation_gravity          simulationGravity
# simulation_center            simulationCenter
# simulation_repulsion      simulationRepulsion
#                                  ...
# clicked_point_id                          NaN
# selected_point_indices                    NaN
# selected_point_ids                        NaN
# changePoints                              NaN
# changeLinks                               NaN
# Name: ts_types_name, Length: 97, dtype: object

# %%
# get a "py_for_ts_name" to map ts_types_name to the parameter names we're using in python
t = stage.matched_info_df.dropna(subset=['ts_types_name'])
py_for_ts_name = dict(zip(t.ts_types_name, t.index))
assert len(py_for_ts_name) == len(t), "some names weren't unique!"
len(py_for_ts_name)
# Out:
# 84

# %%
ts_names_that_have_descriptions_we_can_use_for_md = sorted(set(missing_md_descriptions.index) - set(missing_ts_descriptions.index))
alternate_descriptions = ts_descriptions.loc[ts_names_that_have_descriptions_we_can_use_for_md]
# go through the alternate_descriptions values (strings) and
# replace any ts_names we find (any of the keys of py_for_ts_name) with the corresponding python name
from lkj import regex_based_substitution
find_replace = regex_based_substitution(py_for_ts_name)
alternate_descriptions = alternate_descriptions.apply(find_replace)

print(f"{len(alternate_descriptions)} recoverable descriptions")
print(alternate_descriptions.to_markdown())
# Out:
# 24 recoverable descriptions
# | name                      | ts_types_description                                                                                                     |
# |:--------------------------|:-------------------------------------------------------------------------------------------------------------------------|
# | label_margin              | Specifies the margin between the label and the point.                                                                    |
# | link_arrow_by             | Column name that determines whether a link should have an arrow.                                                         |
# | link_arrows               | Control displaying link arrows. Default `false`.                                                                         |
# | link_color_by             | Column name for the link color. Links will be colored based on this column.                                              |
# | link_source_by            | Column name for the source point of each link. Should match point_id_by values in points data.                           |
# | link_source_index_by      | Column name for the source point index of each link. Should match point_index_by values in points data.                  |
# | link_strength_by          | Column name for the link strength affecting the force simulation.                                                        |
# | link_strength_range       | Range for automatic link strength scaling and affects only during the active simulation.                                 |
# | link_target_by            | Column name for the target point of each link. Should match point_id_by values in points data.                           |
# | link_target_index_by      | Column name for the target point index of each link. Should match point_index_by values in points data.                  |
# | link_width_by             | Column name for the link width.                                                                                          |
# | point_cluster_by          | Column name for the point clusters. Points will be clustered by this column.                                             |
# | point_cluster_strength_by | Defines how strongly each point is attracted to its assigned cluster. Works when `point_cluster_by` is provided.         |
# | point_color_by            | Column name for the point color. If provided, points will be colored based on this column.                               |
# | point_id_by               | Unique identifier column for each point. Required for mapping links to points correctly.                                 |
# | point_index_by            | Numeric index column for each point used for efficient lookups and should be a sequential integer starting from 0.       |
# | point_label_by            | Column name for the point label.                                                                                         |
# | point_label_weight_by     | Column name for point label weight. Accepts float values from 0 to 1. Higher values make labels more likely to be shown. |
# | point_size_by             | Column name for the point size. Points will be sized based on this column.                                               |
# | point_size_range          | Range for automatic point size scaling. Works when `point_size_by` column contains numeric values.                       |
# | point_x_by                | The column name for the point's x-coordinate.                                                                            |
# | point_y_by                | The column name for the point's y-coordinate.                                                                            |
# | show_labels               | Whether to show labels (except hovered) on the Cosmograph canvas.                                                        |
# | simulation_cluster        | Cluster coefficient. Default `0.1`.                                                                                      |

# %% [markdown]
# ## Diagnose the differences between current and stage

# %% [markdown]
# If you're here, this means you're an advanced cosmograph developer.
# Congradulations!
#
# It's aďsumed therefore that you have an idea of what the changes of the cosmograph interface have been
# (i.e. parameter names, descriptions, defaults, types).
#
# You should use that privileged knowledge to verify if everything that should be still there is still there in
# stage, what shouldn't be there is not, and that the new stuff is present...

# %%
stage_names = set(stage.matched_info_df.index)
len(stage_names)
# Out:
# 97

# %% [markdown]
# ### Compare names

# %% [markdown]
# Note that you shouldn't have any differences between current and stage property names
# (i.e. dataframe indices).
#
# This is because they both source from the same place, dynamically (not through a config file):
# From the `cosmograph_widget.Cosmograph` traitlets.

# %%
assert set(current.matched_info_df.index) - set(stage.matched_info_df.index) == set()
assert set(stage.matched_info_df.index) - set(current.matched_info_df.index) == set()

# %% [markdown]
# But fret not! If you want to actually compare some other traitlet names
# (other than the ones of the `cosmograph_widget.Cosmograph` of the environment you're running this on)
# you can simply specify an explicit `Cosmograph` class you want to use.
#
# One way you can do this is by specifying the **raw** (important!!) url of the module it's defined.
# See the example below:

# %%
raw_url_of_previous_widget_module = (
    'https://raw.githubusercontent.com/cosmograph-org/cosmograph_widget/e807bb829c33ce6f87ba16b63616a9b24d4c7d17/src/cosmograph_widget/__init__.py'
)
previous = ConfigsDacc(cosmograph_widget_source=raw_url_of_previous_widget_module)

# %%
in_previous_not_in_stage = set(previous.matched_info_df.index) - set(stage.matched_info_df.index)
in_stage_not_in_previous = set(stage.matched_info_df.index) - set(previous.matched_info_df.index)

from lkj import wrapped_print

print("In previous not in stage:")
wrapped_print(in_previous_not_in_stage)
print("\nIn stage not in previous:")
wrapped_print(in_stage_not_in_previous)
# Out:
# In previous not in stage:
# default_point_color, point_index, link_target, point_id, default_link_arrows,
# default_link_width, point_label_weight, point_label, link_strength,
# default_point_size, default_link_color, link_source, label_padding, point_y,
# link_source_index, point_x, link_arrow, link_target_index
#
# In stage not in previous:
# link_color_by, link_arrow_by, point_cluster_strength_by, link_target_index_by,
# link_target_by, point_label_by, point_color_by, point_label_weight_by,
# point_size_by, point_id_by, point_size_range, point_index_by, point_x_by,
# label_margin, show_labels, link_source_index_by, simulation_cluster,
# link_strength_range, link_source_by, point_cluster_by, link_width_by,
# link_strength_by, point_y_by, link_arrows

# %% [markdown]
# ### Signature differences beyond the names

# %% [markdown]
# Now, taking the current and stage names (which are the same), what you probably want to do is
# see what the differences in non-traitlet columns (columns prefixed by `ts_` and `md_`).

# %%
from cosmograph._resources import sig_to_df, signature_diffs
from tabled import dataframe_diffs

sig_diffs = signature_diffs(current.cosmograph_base_signature(), stage.cosmograph_base_signature())
sig_diffs
# Out:
# {}

# %%
current.cosmograph_base_docs() == stage.cosmograph_base_docs()
# Out:
# True

# %% [markdown]
# ### ... and more

# %%
from tabled import dataframe_diffs

def rename_columns(df):
    return df.rename(columns={'left': 'current', 'right': 'stage'})

t = dataframe_diffs(current.matched_info_df, stage.matched_info_df)
list(t['columns_value_diff'])
# Out:
# ['ts_types_default',
#  'ts_types_description',
#  'ts_types_type',
#  'md_descriptions_type',
#  'ts_types_name',
#  'ts_types_optional',
#  'ts_types_py_name',
#  'ts_types_origin_name']

# %%
rename_columns(t['columns_value_diff']['ts_types_default'])
# Out:
#                                                current       stage
# name
# disable_simulation                               False         NaN
# simulation_decay                                  5000         NaN
# simulation_gravity                                0.25         NaN
# simulation_center                                    0         NaN
# simulation_repulsion                               1.0         NaN
# simulation_repulsion_theta                        1.15         NaN
# simulation_repulsion_quadtree_levels                12         NaN
# simulation_link_spring                               1         NaN
# simulation_link_distance                            10         NaN
# simulation_link_dist_random_variation_range   [1, 1.2]         NaN
# simulation_repulsion_from_mouse                      2         NaN
# simulation_friction                               0.85         NaN
# simulation_cluster                                 0.1         NaN
# background_color                             '#222222'         NaN
# space_size                                        4096         NaN
# point_greyout_opacity                              0.1         NaN
# point_size_scale                                     1         NaN
# hovered_point_cursor                              auto         NaN
# render_hovered_point_ring                        False         NaN
# hovered_point_ring_color                         white         NaN
# focused_point_ring_color                         white         NaN
# render_links                                      True         NaN
# link_greyout_opacity                               0.1         NaN
# link_width_scale                                     1         NaN
# curved_links                                     False         NaN
# curved_link_segments                                19         NaN
# curved_link_weight                                 0.8         NaN
# curved_link_control_point_distance                 0.5         NaN
# link_arrows_size_scale                               1         NaN
# link_visibility_distance_range               [50, 150]         NaN
# link_visibility_min_transparency                  0.25         NaN
# use_quadtree                                     False         NaN
# pixel_ratio                                          2         NaN
# scale_points_on_zoom                              True         NaN
# disable_zoom                                     False         NaN
# enable_drag                                      False         NaN
# fit_view_on_init                                  True         NaN
# fit_view_delay                                     250         NaN
# fit_view_padding                                   0.1         NaN
# fit_view_duration                                  250         NaN
# point_sampling_distance                            150         NaN
# point_size_range                                   NaN      [2, 9]
# link_strength_range                                NaN  [0.2, 1.0]
# show_labels                                        NaN       false
# show_dynamic_labels                              False       false
# show_labels_for                                   None   undefined
# show_top_labels                                  False       false
# show_top_labels_limit                              100         100
# show_top_labels_by                                None   undefined
# static_label_weight                                0.8         0.8
# dynamic_label_weight                               0.7         0.7
# label_margin                                         5           5
# show_hovered_point_label                         False       false

# %%
def differences_for_name(name, *, current=current, stage=stage):
    t = pd.concat(
        [
            current.matched_info_df.loc[name].rename('current'),
            stage.matched_info_df.loc[name].rename('stage'),
        ],
        axis=1,
    )
    t = t.dropna(how='all')  # because no NaNs resolve as equal
    t['is_same'] = t['current'] == t['stage']
    t = t[t['is_same'] == False]
    del t['is_same']
    return t

# %%
differences_for_name('link_color')
# Out:
#                      current  \
# ts_types_description     NaN
# ts_types_type            NaN
# ts_types_name            NaN
# ts_types_optional        NaN
# ts_types_py_name         NaN
# ts_types_origin_name     NaN
#
#                                                                   stage
# ts_types_description  Default color for links. Either hex or RGBA. D...
# ts_types_type                 string | [number, number, number, number]
# ts_types_name                                                 linkColor
# ts_types_optional                                                  True
# ts_types_py_name                                             link_color
# ts_types_origin_name                               GraphConfigInterface

# %%
differences_for_name('link_color_by')
# Out:
#                      current  \
# ts_types_description     NaN
# ts_types_type            NaN
# ts_types_name            NaN
# ts_types_optional        NaN
# ts_types_py_name         NaN
# ts_types_origin_name     NaN
#
#                                                                   stage
# ts_types_description  Column name for the link color. Links will be ...
# ts_types_type                                                    string
# ts_types_name                                               linkColorBy
# ts_types_optional                                                  True
# ts_types_py_name                                          link_color_by
# ts_types_origin_name                              CosmographLinksConfig

# %% [markdown]
# ## Replacing current with stage (a.k.a. updating the interface)

# %%
list(current.config_jsons)
# Out:
# ['config_info.json',
#  '_color_table.parquet',
#  '_widget_config_from_md.json',
#  'config_prep/parsed_types.json',
#  'config_prep/source_strings.json',
#  'config_prep/parsed_defaults.json',
#  'config_prep/parsed_descriptions.json',
#  'color_names.json',
#  '_widget_config.json',
#  'nikita_config.json',
#  'cosmos_config.json']

# %%
list(stage.config_jsons)
# Out:
# ['config_prep/parsed_types.json',
#  'config_prep/source_strings.json',
#  'config_prep/parsed_defaults.json',
#  'config_prep/parsed_descriptions.json']

# %%
## Uncomment this and run to update current files with stage ones:
# current.config_jsons.update(stage.config_jsons)

# %% [markdown]
# ## Recreating and replacing the params_ssot.json file

# %%
new_params_ssot = stage.cosmograph_base_params_json()
print(new_params_ssot[:300])
# Out:
# [
#     {
#         "name":"disable_simulation",
#         "default":false,
#         "annotation":"bool",
#         "description":"Prevents the simulation from running, merely rendering the graph."
#     },
#     {
#         "name":"simulation_decay",
#         "default":1000,
#         "annotation":"float",
#         "

# %%
# TODO: Add some dict-diff diagnosis on the existing params_ssot.json

# %%
from cosmograph.util import PARAMS_SSOT_PATH

# Uncomment this and run to update the params_ssot file with the new one: CAREFUL! BE SURE YOU WANT TO DO THIS!
# PARAMS_SSOT_PATH.write_text(new_params_ssot)
# Out:
# 15070

# %%
from cosmograph.util import cosmograph_base_signature, cosmograph_base_docs

cosmograph_base_signature()
# Out:
# <Sig (*, disable_simulation: bool = False, simulation_decay: float = 1000, simulation_gravity: float = 0, simulation_center: float = 0, simulation_repulsion: float = 0.1, simulation_repulsion_theta: float = 1.7, simulation_repulsion_quadtree_levels: float = 12, simulation_link_spring: float = 1, simulation_link_distance: float = 2, simulation_link_dist_random_variation_range: list[typing.Any] = [1, 1.2], simulation_repulsion_from_mouse: float = 2, simulation_friction: float = 0.85, simulation_cluster: float = None, background_color: Union[str, list[float]] = '#222222', space_size: int = 4096, point_color: Union[str, list[float]] = '#b3b3b3', point_greyout_opacity: float = 0.1, point_size: float = 4, point_size_scale: float = 1, hovered_point_cursor: str = None, render_hovered_point_ring: bool = 0.7, hovered_point_ring_color: Union[str, list[float]] = 'white', focused_point_ring_color: Union[str, list[float]] = 0.95, focused_point_index: int = None, render_links: bool = True, link_color: Union[str, list[float]] = '#666666', link_greyout_opacity: float = 0.1, link_width: float = 1, link_width_scale: float = 1, curved_links: bool = False, curved_link_segments: int = 19, curved_link_weight: float = 0.8, curved_link_control_point_distance: float = 0.5, link_arrows: bool = None, link_arrows_size_scale: float = 1, link_visibility_distance_range: list[float] = [50, 150], link_visibility_min_transparency: float = 0.25, use_quadtree: bool = False, show_FPS_monitor: bool = False, pixel_ratio: float = 2, scale_points_on_zoom: bool = True, initial_zoom_level: float = 3, disable_zoom: bool = False, enable_drag: bool = None, fit_view_on_init: bool = True, fit_view_delay: float = 250, fit_view_padding: float = None, fit_view_duration: float = None, fit_view_by_points_in_rect: list[list[float]] = None, random_seed: Union[int, str] = None, point_sampling_distance: int = 150, point_id_by: str = None, point_index_by: str = None, point_color_by: str = None, point_size_by: str = None, point_size_range: list[float] = None, point_label_by: str = None, point_label_weight_by: str = None, point_x_by: str = None, point_y_by: str = None, point_cluster_by: str = None, point_cluster_strength_by: str = None, point_include_columns: list[str] = None, link_source_by: str = None, link_source_index_by: str = None, link_target_by: str = None, link_target_index_by: str = None, link_color_by: str = None, link_width_by: str = None, link_arrow_by: str = None, link_strength_by: str = None, link_strength_range: list[float] = None, link_include_columns: list[str] = None, show_labels: bool = None, show_dynamic_labels: bool = None, show_labels_for: list[str] = None, show_top_labels: bool = None, show_top_labels_limit: int = None, show_top_labels_by: str = None, static_label_weight: float = None, dynamic_label_weight: float = None, label_margin: float = None, show_hovered_point_label: bool = None, disable_point_size_legend: bool = None, disable_link_width_legend: bool = None, disable_point_color_legend: bool = None, disable_link_color_legend: bool = None, points: object = None, links: object = None, clicked_point_index: int = None, clicked_point_id: str = None, selected_point_indices: list[int] = None, selected_point_ids: list[str] = None, changePoints: Callable[[Dict[str, Any]], Any] = None, changeLinks: Callable[[Dict[str, Any]], Any] = None)>

# %%
cosmograph_base_docs()
# Out:
# 'Parameters\n----------\ndisable_simulation : bool, default=False\n    Prevents the simulation from running, merely rendering the graph.\nsimulation_decay : float, default=1000\n    Defines how quickly the simulation cools down.\nsimulation_gravity : float, default=0\n    Coefficient for gravity force.\nsimulation_center : float, default=0\n    Centers the mass force coefficient.\nsimulation_repulsion : float, default=0.1\n    Configures point repulsion between points.\nsimulation_repulsion_theta : float, default=1.7\n    Decreases / increases the detalization of the Many-Body force calculations.\nsimulation_repulsion_quadtree_levels : float, default=12\n    Barnes–Hut approximation depth, usable when useQuadtree is set to True.\nsimulation_link_spring : float, default=1\n    Spring constant for links.\nsimulation_link_distance : float, default=2\n    Default distance for links.\nsimulation_link_dist_random_variation_range : list[typing.Any], default=[1, 1.2]\n    Random link distance range.\nsimulation_repulsion_from_mouse : float, default=2\n    Mouse position repulsion coefficient, activated by right-click.\nsimulation_friction : float, default=0.85\n    Sets simulation friction.\nsimulation_cluster : float, default=None\n    \nbackground_color : typing.Union[str, list[float]], default="#222222"\n    Canvas background color.\nspace_size : int, default=4096\n    Size of the simulation space.\npoint_color : typing.Union[str, list[float]], default="#b3b3b3"\n    Column name for point colors.\npoint_greyout_opacity : float, default=0.1\n    Opacity of unselected nodes during selection.\npoint_size : float, default=4\n    Column name for point sizes.\npoint_size_scale : float, default=1\n    Scale factor for point sizes.\nhovered_point_cursor : str, default=None\n    Cursor type when hovering over a point.\nrender_hovered_point_ring : bool, default=0.7\n    Enables ring around hovered points.\nhovered_point_ring_color : typing.Union[str, list[float]], default="white"\n    Color of hovered point ring.\nfocused_point_ring_color : typing.Union[str, list[float]], default=0.95\n    Color of the focused point ring.\nfocused_point_index : int, default=None\n    Index of the focused point, prioritized over focus_point method.\nrender_links : bool, default=True\n    Enables or disables link rendering.\nlink_color : typing.Union[str, list[float]], default="#666666"\n    Column name for link colors.\nlink_greyout_opacity : float, default=0.1\n    Opacity of unselected links during selection.\nlink_width : float, default=1\n    Column name for link widths.\nlink_width_scale : float, default=1\n    Scale factor for link widths.\ncurved_links : bool, default=False\n    Enables or disables curved links.\ncurved_link_segments : int, default=19\n    Segments defining curved links.\ncurved_link_weight : float, default=0.8\n    Weight factor for link curvature.\ncurved_link_control_point_distance : float, default=0.5\n    Control point positioning for curves.\nlink_arrows : bool, default=None\n    \nlink_arrows_size_scale : float, default=1\n    Scale factor for link arrow size.\nlink_visibility_distance_range : list[float], default=[50, 150]\n    Pixel distance range for link transparency.\nlink_visibility_min_transparency : float, default=0.25\n    Minimum transparency of links based on link_visibility_distance_range.\nuse_quadtree : bool, default=False\n    Activates quadtree algorithm for Many-Body force when set to True.\nshow_FPS_monitor : bool, default=False\n    Display an FPS counter in the upper right corner of the canvas.\npixel_ratio : float, default=2\n    Canvas pixel ratio.\nscale_points_on_zoom : bool, default=True\n    Scales point sizes when zooming.\ninitial_zoom_level : float, default=3\n    Starting zoom level.\ndisable_zoom : bool, default=False\n    Enables or disables zooming.\nenable_drag : bool, default=None\n    Allows graph dragging.\nfit_view_on_init : bool, default=True\n    Automatically fits view to all points upon  ...

# %% [markdown]
# # Code gen

# %%
from cosmograph._code_sync import code_str_with_signature
from cosmograph.util import cosmograph_base_signature
# from cosmograph.base import cosmo 
from i2 import Sig

cosmo_base_sig = cosmograph_base_signature()
cosmo_base_sig

from inspect import getsource

old_code_str = getsource(foo)

cosmo_sig = Sig('(data=None)').merge_with_sig(cosmo_base_sig)

new_code_str = code_str_with_signature(cosmo, cosmo_sig)
print(new_code_str)
# Out:
# def foo_with_new_sig(
#     data=None,
#     *,
#     disable_simulation: bool = False,
#     simulation_decay: float = 1000,
#     simulation_gravity: float = 0,
#     simulation_center: float = 0,
#     simulation_repulsion: float = 0.1,
#     simulation_repulsion_theta: float = 1.7,
#     simulation_repulsion_quadtree_levels: float = 12,
#     simulation_link_spring: float = 1,
#     simulation_link_distance: float = 2,
#     simulation_link_dist_random_variation_range: list[typing.Any] = [1, 1.2],
#     simulation_repulsion_from_mouse: float = 2,
#     simulation_friction: float = 0.85,
#     simulation_cluster: float = None,
#     background_color: Union[str, list[float]] = '#222222',
#     space_size: int = 4096,
#     point_color: Union[str, list[float]] = '#b3b3b3',
#     point_greyout_opacity: float = 0.1,
#     point_size: float = 4,
#     point_size_scale: float = 1,
#     hovered_point_cursor: str = None,
#     render_hovered_point_ring: bool = 0.7,
#     hovered_point_ring_color: Union[str, list[float]] = 'white',
#     focused_point_ring_color: Union[str, list[float]] = 0.95,
#     focused_point_index: int = None,
#     render_links: bool = True,
#     link_color: Union[str, list[float]] = '#666666',
#     link_greyout_opacity: float = 0.1,
#     link_width: float = 1,
#     link_width_scale: float = 1,
#     curved_links: bool = False,
#     curved_link_segments: int = 19,
#     curved_link_weight: float = 0.8,
#     curved_link_control_point_distance: float = 0.5,
#     link_arrows: bool = None,
#     link_arrows_size_scale: float = 1,
#     link_visibility_distance_range: list[float] = [50, 150],
#     link_visibility_min_transparency: float = 0.25,
#     use_quadtree: bool = False,
#     show_FPS_monitor: bool = False,
#     pixel_ratio: float = 2,
#     scale_points_on_zoom: bool = True,
#     initial_zoom_level: float = 3,
#     disable_zoom: bool = False,
#     enable_drag: bool = None,
#     fit_view_on_init: bool = True,
#     fit_view_delay: float = 250,
#     fit_view_padding: float = None,
#     fit_view_duration: float = None,
#     fit_view_by_points_in_rect: list[list[float]] = None,
#     random_seed: Union[int, str] = None,
#     point_sampling_distance: int = 150,
#     point_id_by: str = None,
#     point_index_by: str = None,
#     point_color_by: str = None,
#     point_size_by: str = None,
#     point_size_range: list[float] = None,
#     point_label_by: str = None,
#     point_label_weight_by: str = None,
#     point_x_by: str = None,
#     point_y_by: str = None,
#     point_cluster_by: str = None,
#     point_cluster_strength_by: str = None,
#     point_include_columns: list[str] = None,
#     link_source_by: str = None,
#     link_source_index_by: str = None,
#     link_target_by: str = None,
#     link_target_index_by: str = None,
#     link_color_by: str = None,
#     link_width_by: str = None,
#     link_arrow_by: str = None,
#     link_strength_by: str = None,
#     link_strength_range: list[float] = None,
#     link_include_columns: list[str] = None,
#     show_labels: bool = None,
#     show_dynamic_labels: bool = None,
#     show_labels_for: list[str] = None,
#     show_top_labels: bool = None,
#     show_top_labels_limit: int = None,
#     show_top_labels_by: str = None,
#     static_label_weight: float = None,
#     dynamic_label_weight: float = None,
#     label_margin: float = None,
#     show_hovered_point_label: bool = None,
#     disable_point_size_legend: bool = None,
#     disable_link_width_legend: bool = None,
#     disable_point_color_legend: bool = None,
#     disable_link_color_legend: bool = None,
#     points: object = None,
#     links: object = None,
#     clicked_point_index: int = None,
#     clicked_point_id: str = None,
#     selected_point_indices: list[int] = None,
#     selected_point_ids: list[str] = None,
#     changePoints: Callable[[Dict[str, Any]], Any] = None,
#     changeLinks: Callable[[Dict[str, Any]], Any] = None
# ):
#     """This is some documentation."""
#     data, , disable_simulation: bool, simulation_decay: float, simulation_gravity: float, simulation_center: float, simulation_repulsion: float, simulation_repulsion_theta: float, simulation_repulsion_quadtree_levels: float, simulation_link_spring: float, simulation_link_distance: float, simulation_link_dist_random_variation_range: list[typing.Any], simulation_repulsion_from_mouse: float, simulation_friction: float, simulation_cluster: float, background_color: Union[str, list[float]], space_size: int, point_color: Union[str, list[float]], point_greyout_opacity: float, point_size: float, point_size_scale: float, hovered_point_cursor: str, render_hovered_point_ring: bool, hovered_point_ring_color: Union[str, list[float]], focused_point_ring_color: Union[str, list[float]], focused_point_index: int, render_links: bool, link_color: Union[str, list[float]], link_greyout_opacity: float, link_width: float, link_width_scale: float, curved_links: bool, curved_link_segments: int, curved_link_weight: float, curved_link_control_point_distance: float, link_arrows: bool, link_arrows_size_scale: float, link_visibility_distance_range: list[float], link_visibility_min_transparency: float, use_quadtree: bool, show_FPS_monitor: bool, pixel_ratio: float, scale_points_on_zoom: bool, initial_zoom_level: float, disable_zoom: bool, enable_drag: bool, fit_view_on_init: bool, fit_view_delay: float, fit_view_padding: float, fit_view_duration: float, fit_view_by_points_in_rect: list[list[float]], random_seed: Union[int, str], point_sampling_distance: int, point_id_by: str, point_index_by: str, point_color_by: str, point_size_by: str, point_size_range: list[float], point_label_by: str, point_label_weight_by: str, point_x_by: str, point_y_by: str, point_cluster_by: str, point_cluster_strength_by: str, point_include_columns: list[str], link_source_by: str, link_source_index_by: str, link_target_by: str, link_target_index_by: str, link_color_by: str, link_width_by: str, link_arrow_by: str, link_strength_by: str, link_strength_range: list[float], link_include_columns: list[str], show_labels: bool, show_dynamic_labels: bool, show_labels_for: list[str], show_top_labels: bool, show_top_labels_limit: int, show_top_labels_by: str, static_label_weight: float, dynamic_label_weight: float, label_margin: float, show_hovered_point_label: bool, disable_point_size_legend: bool, disable_link_width_legend: bool, disable_point_color_legend: bool, disable_link_color_legend: bool, points: object, links: object, clicked_point_index: int, clicked_point_id: str, selected_point_indices: list[int], selected_point_ids: list[str], changePoints: Callable[[Dict[str, Any]], Any], changeLinks: Callable[[Dict[str, Any]], Any] = locals().values()
#     kwargs = process_cosmo_input(data, kwargs)
#     if 'points' not in kwargs and 'links' not in kwargs:
#         # If no data is given, just return a partial function with the kwargs filled in
#         return partial(foo, **kwargs)
#     return Cosmograph(**kwargs)

# %%
from cosmograph._code_sync import code_str_with_signature

def original_function(a, b=10, *args, **kwargs):
    """
    This is a test function to demonstrate the functionality of
    `code_str_with_signature`. It adds `a` and `b`, and prints any
    additional arguments.

    Parameters
    ----------
    a : int
        The first number to add.
    b : int, optional
        The second number to add (default is 10).
    *args : tuple
        Additional positional arguments.
    **kwargs : dict
        Additional keyword arguments.

    Returns
    -------
    int
        The sum of `a` and `b`.
    """
    result = a + b
    if args:
        print("Positional args:", args)
    if kwargs:
        print("Keyword args:", kwargs)
    return result

# Custom signature to apply
new_signature = """def modified_function(x, y=20, z=None, *args, custom_kwarg='default', **kwargs):"""

# Generate the new function code as a string
new_function_code = code_str_with_signature(original_function, new_signature)

# Print the generated code to inspect it
print("Generated Code:\n")
print(new_function_code)

# Execute the generated code to test it dynamically
namespace = {}
exec(new_function_code, namespace)
modified_function = namespace["modified_function"]

# Tests
print("\nRunning Tests:")
print(modified_function(5, 15))  # Simple addition, no extra args
print(modified_function(3, 7, 1, 2, 3, custom_kwarg="test"))  # Positional and keyword args
# Out:
# Generated Code:
#
# def modified_function(
#     x,
#     y=20,
#     z=None,
#     *args,
#     custom_kwarg='default',
#     **kwargs
# ):
#     """This is a test function to demonstrate the functionality of
# `code_str_with_signature`. It adds `a` and `b`, and prints any
# additional arguments.
#
# Parameters
# ----------
# a : int
#     The first number to add.
# b : int, optional
#     The second number to add (default is 10).
# *args : tuple
#     Additional positional arguments.
# **kwargs : dict
#     Additional keyword arguments.
#
# Returns
# -------
# int
#     The sum of `a` and `b`."""
#     x, y, z, args, custom_kwarg, kwargs = locals().values()
#     result = a + b
#     if args:
#         print("Positional args:", args)
#     if kwargs:
#         print("Keyword args:", kwargs)
#     return result
#
# Running Tests:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 49
#      47 # Tests
#      48 print("\nRunning Tests:")
# ---> 49 print(modified_function(5, 15))  # Simple addition, no extra args
#      50 print(modified_function(3, 7, 1, 2, 3, custom_kwarg="test"))  # Positional and keyword args
#
# File <string>:29, in modified_function(x, y, z, custom_kwarg, *args, **kwargs)
#
# NameError: name 'a' is not defined

# %%
modified_function
print(new_function_code)
# Out:
# def modified_function(
#     x,
#     y=20,
#     z=None,
#     *args,
#     custom_kwarg='default',
#     **kwargs
# ):
#     """This is a test function to demonstrate the functionality of
# `code_str_with_signature`. It adds `a` and `b`, and prints any
# additional arguments.
#
# Parameters
# ----------
# a : int
#     The first number to add.
# b : int, optional
#     The second number to add (default is 10).
# *args : tuple
#     Additional positional arguments.
# **kwargs : dict
#     Additional keyword arguments.
#
# Returns
# -------
# int
#     The sum of `a` and `b`."""
#     x, y, z, args, custom_kwarg, kwargs = locals().values()
#     result = a + b
#     if args:
#         print("Positional args:", args)
#     if kwargs:
#         print("Keyword args:", kwargs)
#     return result

# %% [markdown]
# # ResourcesDacc

# %% [markdown]
# `ResourcesDacc` is a facade to resources datas that are stored locally.

# %%
from cosmograph._resources import _get_fresh_color_table, ResourcesDacc

resources = ResourcesDacc()

# %% [markdown]
# You can see what resources files you have by listing the `resources_jsons`.

# %%
list(resources.resources_jsons)
# Out:
# ['config_info.json',
#  '_color_table.parquet',
#  '_widget_config_from_md.json',
#  'config_prep/parsed_types.json',
#  'config_prep/source_strings.json',
#  'config_prep/parsed_defaults.json',
#  'config_prep/parsed_descriptions.json',
#  'color_names.json',
#  '_widget_config.json',
#  'nikita_config.json',
#  'cosmos_config.json']

# %% [markdown]
# Examples of accessing (formatted/prepared) resource data via attributes:

# %%
print(f"{resources._color_table.shape=}")
resources._color_table.iloc[0]
# Out:
# resources._color_table.shape=(148, 3)
# color_name      aliceblue
# hex_rgb           #f0f8ff
# decimal       240 248 255
# Name: 0, dtype: object

# %%
print(f"{len(resources.color_names)=}")
resources.color_names[:5]
# Out:
# len(resources.color_names)=148
# ['aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure']

# %% [markdown]
# # Parsing TS

# %%
# testing out the parse_ts
from jy.ts_parse import test_parse_ts
test_parse_ts()  # issues warning, but should not update (this works with tree-siter 0.21.3)
# Out:
# /Users/thorwhalen/.pyenv/versions/3.10.13/envs/p10/lib/python3.10/site-packages/tree_sitter/__init__.py:36: FutureWarning: Language(path, name) is deprecated. Use Language(ptr, name) instead.
#   warn("{} is deprecated. Use {} instead.".format(old, new), FutureWarning)

# %%
from graze import graze
from jy import parse_ts, parse_ts_with_oa

# %% [markdown]
# # Trying out cosmograph_widget.Cosmograph

# %%
from cosmograph_widget import Cosmograph
import pandas as pd
# dir(Cosmograph)

# %%
points = pd.read_json('./points.json')
points.head(3)
# Out:
#    id  index  value  value2                             date  \
# 0   0      0     -5     116 2022-11-25 03:25:04.851000+00:00
# 1   1      1     17     155 2020-08-21 06:38:36.826000+00:00
# 2   2      2    -31      51 2012-05-15 07:34:20.927000+00:00
#
#                        time    color         label
# 0  1970-01-01T01:20:59.956Z  #bab0ab       offence
# 1  1970-01-01T00:40:26.814Z  #9c755f     analytics
# 2  1970-01-01T01:07:34.760Z  #9c755f  minor-league

# %%
links = pd.read_json('./links.json')
links.head(2)
# Out:
#    source  sourceidx                             date  \
# 0       0          0 2012-02-08 11:17:27.900000+00:00
# 1       0          0 2012-02-08 11:17:27.900000+00:00
#
#                        time    color  target  targetidx
# 0  1970-01-01T01:06:54.149Z  #4e79a7       1          1
# 1  1970-01-01T01:06:54.149Z  #4e79a7      92         92

# %%
cosmo = Cosmograph(points=points, links=links,
           point_id='id',
           point_index='index',
           point_color='color',
           point_label='label',
           point_include_columns=['value', 'value2'],
           link_source='source',
           link_source_index='sourceidx',
           link_target='target',
           link_target_index='targetidx',
           link_color='color',
           link_width='value'
        )
cosmo
# Out:
# Cosmograph(background_color=None, default_link_color=None, default_point_color=None, focused_point_ring_color=…

# %%
cosmo.activate_rect_selection()

# %%
cosmo.deactivate_rect_selection()

# %%
cosmo.selected_point_indices
# Out:
# [5482, 5693, 6338, 6430]

# %%
cosmo.select_points_by_indices([1,2,3,4,5])
# cosmo.select_points_by_indices([]) # unselect points

# %%
cosmo.focus_point(5)
# cosmo.focus_point()

# %%
# cosmo.fit_view()
# cosmo.fit_view_by_indices([1,2,3,4,5], 250, 0.1)
cosmo.fit_view_by_coordinates([1400, 1400, 2500, 2500], 2000)

# %%
cosmo.background_color = 'hotpink'
# cosmo.background_color = 'gold'

# %% [markdown]
# # Gathering widget properties

# %%
from cosmograph_widget import Cosmograph

vars(Cosmograph)
# Out:
# mappingproxy({'__module__': 'cosmograph_widget',
#               '_esm': <anywidget._file_contents.FileContents at 0x1313d2bf0>,
#               '_css': <anywidget._file_contents.FileContents at 0x1313d2ad0>,
#               'disable_simulation': <traitlets.traitlets.Bool at 0x107ea52a0>,
#               'simulation_decay': <traitlets.traitlets.Float at 0x107edc070>,
#               'simulation_gravity': <traitlets.traitlets.Float at 0x131346e30>,
#               'simulation_center': <traitlets.traitlets.Float at 0x131346e00>,
#               'simulation_repulsion': <traitlets.traitlets.Float at 0x131346dd0>,
#               'simulation_repulsion_theta': <traitlets.traitlets.Float at 0x1205cbd30>,
#               'simulation_repulsion_quadtree_levels': <traitlets.traitlets.Float at 0x1205cbe20>,
#               'simulation_link_spring': <traitlets.traitlets.Float at 0x1205cbe50>,
#               'simulation_link_distance': <traitlets.traitlets.Float at 0x1313d1690>,
#               'simulation_link_dist_random_variation_range': <traitlets.traitlets.List at 0x1313d1660>,
#               'simulation_repulsion_from_mouse': <traitlets.traitlets.Float at 0x1313d16c0>,
#               'simulation_friction': <traitlets.traitlets.Float at 0x1313d16f0>,
#               'background_color': <traitlets.traitlets.Union at 0x1313d17b0>,
#               'space_size': <traitlets.traitlets.Int at 0x1313d17e0>,
#               'default_point_color': <traitlets.traitlets.Union at 0x1313d18a0>,
#               'point_greyout_opacity': <traitlets.traitlets.Float at 0x1313d18d0>,
#               'default_point_size': <traitlets.traitlets.Float at 0x1313d1900>,
#               'point_size_scale': <traitlets.traitlets.Float at 0x1313d1930>,
#               'hovered_point_cursor': <traitlets.traitlets.Unicode at 0x1313d1960>,
#               'render_hovered_point_ring': <traitlets.traitlets.Bool at 0x1313d1990>,
#               'hovered_point_ring_color': <traitlets.traitlets.Union at 0x1313d1a50>,
#               'focused_point_ring_color': <traitlets.traitlets.Union at 0x1313d1b10>,
#               'focused_point_index': <traitlets.traitlets.Int at 0x1313d1b40>,
#               'render_links': <traitlets.traitlets.Bool at 0x1313d1b70>,
#               'default_link_color': <traitlets.traitlets.Union at 0x1313d1c30>,
#               'link_greyout_opacity': <traitlets.traitlets.Float at 0x1313d1c60>,
#               'default_link_width': <traitlets.traitlets.Float at 0x1313d1c90>,
#               'link_width_scale': <traitlets.traitlets.Float at 0x1313d1cc0>,
#               'curved_links': <traitlets.traitlets.Bool at 0x1313d1cf0>,
#               'curved_link_segments': <traitlets.traitlets.Int at 0x1313d1d20>,
#               'curved_link_weight': <traitlets.traitlets.Float at 0x1313d1d50>,
#               'curved_link_control_point_distance': <traitlets.traitlets.Float at 0x1313d1d80>,
#               'default_link_arrows': <traitlets.traitlets.Bool at 0x1313d1db0>,
#               'link_arrows_size_scale': <traitlets.traitlets.Float at 0x1313d1de0>,
#               'link_visibility_distance_range': <traitlets.traitlets.List at 0x1313d1e10>,
#               'link_visibility_min_transparency': <traitlets.traitlets.Float at 0x1313d1e40>,
#               'use_quadtree': <traitlets.traitlets.Bool at 0x1313d1ea0>,
#               'show_FPS_monitor': <traitlets.traitlets.Bool at 0x1313d1ed0>,
#               'pixel_ratio': <traitlets.traitlets.Float at 0x1313d1f00>,
#               'scale_points_on_zoom': <traitlets.traitlets.Bool at 0x1313d1f30>,
#               'initial_zoom_level': <traitlets.traitlets.Float at 0x1313d1f60>,
#               'disable_zoom': <traitlets.traitlets.Bool at 0x1313d1f90>,
#               'enable_drag': <traitlets.traitlets.Bool at 0x1313d1fc0>,
#               'fit_view_on_init': <traitlets.traitlets.Bool at 0x1313d1ff0>,
#               'fit_view_delay': <traitlets.traitlets.Float at 0x1313d2020>,
#               'fit_view_padding': <traitlets.traitlets.Float at 0x1313d2050>,
#               'fit_view_duration': <traitlets.traitlets.Float at 0x1313d2080>,
#               'fit_view_by_points_in_rect': <traitlets.traitlets.List at 0x1313d2110>,
#               'random_seed': <traitlets.traitlets.Union at 0x1313d21a0>,
#               'point_sampling_distance': <traitlets.traitlets.Int at 0x1313d21d0>,
#               '_ipc_points': <traitlets.traitlets.Bytes at 0x1313d2200>,
#               'points': <traitlets.traitlets.Any at 0x1313d2260>,
#               '_ipc_links': <traitlets.traitlets.Bytes at 0x1313d2290>,
#               'links': <traitlets.traitlets.Any at 0x1313d22f0>,
#               'point_id': <traitlets.traitlets.Unicode at 0x1313d2320>,
#               'point_index': <traitlets.traitlets.Unicode at 0x1313d2350>,
#               'point_color': <traitlets.traitlets.Unicode at 0x1313d2380>,
#               'point_size': <traitlets.traitlets.Unicode at 0x1313d23b0>,
#               'point_label': <traitlets.traitlets.Unicode at 0x1313d23e0>,
#               'point_label_weight': <traitlets.traitlets.Unicode at 0x1313d2410>,
#               'point_x': <traitlets.traitlets.Unicode at 0x1313d2440>,
#               'point_y': <traitlets.traitlets.Unicode at 0x1313d2470>,
#               'point_include_columns': <traitlets.traitlets.List at 0x1313d24a0>,
#               'link_source': <traitlets.traitlets.Unicode at 0x1313d24d0>,
#               'link_source_index': <traitlets.traitlets.Unicode at 0x1313d2530>,
#               'link_target': <traitlets.traitlets.Unicode at 0x1313d2560>,
#               'link_target_index': <traitlets.traitlets.Unicode at 0x1313d2590>,
#               'link_color': <traitlets.traitlets.Unicode at 0x1313d25c0>,
#               'link_width': <traitlets.traitlets.Unicode at 0x1313d25f0>,
#               'link_arrow': <traitlets.traitlets.Unicode at 0x1313d2620>,
#               'link_strength': <traitlets.traitlets.Unicode at 0x1313d2650>,
#               'link_include_columns': <traitlets.traitlets.List at 0x1313d2680>,
#               'show_dynamic_labels': <traitlets.traitlets.Bool at 0x1313d26b0>,
#               'show_labels_for': <traitlets.traitlets.List at 0x1313d2710>,
#               'show_top_labels': <traitlets.traitlets.Bool at 0x1313d2770>,
#               'show_top_labels_limit': <traitlets.traitlets.Int at 0x1313d27a0>,
#               'show_top_labels_by': <traitlets.traitlets.Unicode at 0x1313d27d0>,
#               'static_label_weight': <traitlets.traitlets.Float at 0x1313d2800>,
#               'dynamic_label_weight': <traitlets.traitlets.Float at 0x1313d2830>,
#               'label_padding': <traitlets.traitlets.Float at 0x1313d2860>,
#               'show_hovered_point_label': <traitlets.traitlets.Bool at 0x1313d2890>,
#               'clicked_node_index': <traitlets.traitlets.Int at 0x1313d28c0>,
#               'selected_point_indices': <traitlets.traitlets.List at 0x1313d28f0>,
#               'get_buffered_arrow_table': <function cosmograph_widget.Cosmograph.get_buffered_arrow_table(self, df)>,
#               'change': <traitlets.traitlets.ObserveHandler at 0x1313d2950>,
#               'changeLinks': <traitlets.traitlets.ObserveHandler at 0x1313d29b0>,
#               'select_point_by_index': <function cosmograph_widget.Cosmograph.select_point_by_index(self, index)>,
#               'select_points_by_indices': <function cosmograph_widget.Cosmograph.select_points_by_indices(self, indices)>,
#               'activate_rect_selection': <function cosmograph_widget.Cosmograph.activate_rect_selection(self)>,
#               'deactivate_rect_selection': <function cosmograph_widget.Cosmograph.deactivate_rect_selection(self)>,
#               'fit_view': <function cosmograph_widget.Cosmograph.fit_view(self)>,
#               'fit_view_by_indices': <function cosmograph_widget.Cosmograph.fit_view_by_indices(self, indices, duration=None, padding=None)>,
#               'fit_view_by_coordinates': <function cosmograph_widget.Cosmograph.fit_view_by_coordinates(self, coordinates, duration=None, padding=None)>,
#               'focus_point': <function cosmograph_widget.Cosmograph.focus_point(self, index=None)>,
#               'start': <function cosmograph_widget.Cosmograph.start(self, alpha=None)>,
#               'pause': <function cosmograph_widget.Cosmograph.pause(self)>,
#               'restart': <function cosmograph_widget.Cosmograph.restart(self)>,
#               'step': <function cosmograph_widget.Cosmograph.step(self)>,
#               '__doc__': None,
#               '_trait_default_generators': {},
#               '_all_trait_default_generators': {'_dom_classes': <bound method TraitType.default of <ipywidgets.widgets.trait_types.TypedTuple object at 0x107bccb50>>,
#                '_ipc_links': <bound method TraitType.default of <traitlets.traitlets.Bytes object at 0x1313d2290>>,
#                '_ipc_points': <bound method TraitType.default of <traitlets.traitlets.Bytes object at 0x1313d2200>>,
#                '_model_module': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1312c8d00>>,
#                '_model_module_version': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x131346ce0>>,
#                '_model_name': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1312c8cd0>>,
#                '_msg_callbacks': <bound method TraitType.default of <traitlets.traitlets.Instance object at 0x107b6ffd0>>,
#                '_property_lock': <bound method TraitType.default of <traitlets.traitlets.Dict object at 0x107b6ff70>>,
#                '_states_to_send': <bound method TraitType.default of <traitlets.traitlets.Set object at 0x107b6feb0>>,
#                '_view_count': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x107b6f580>>,
#                '_view_module': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x131346d40>>,
#                '_view_module_version': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x131346d70>>,
#                '_view_name': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x131346d10>>,
#                'background_color': <bound method Union.default of <traitlets.traitlets.Union object at 0x1313d17b0>>,
#                'clicked_node_index': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x1313d28c0>>,
#                'comm': <bound method TraitType.default of <traitlets.traitlets.Any object at 0x107b6fb50>>,
#                'curved_link_control_point_distance': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1d80>>,
#                'curved_link_segments': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x1313d1d20>>,
#                'curved_link_weight': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1d50>>,
#                'curved_links': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1cf0>>,
#                'default_link_arrows': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1db0>>,
#                'default_link_color': <bound method Union.default of <traitlets.traitlets.Union object at 0x1313d1c30>>,
#                'default_link_width': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1c90>>,
#                'default_point_color': <bound method Union.default of <traitlets.traitlets.Union object at 0x1313d18a0>>,
#                'default_point_size': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1900>>,
#                'disable_simulation': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x107ea52a0>>,
#                'disable_zoom': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1f90>>,
#                'dynamic_label_weight': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d2830>>,
#                'enable_drag': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1fc0>>,
#                'fit_view_by_points_in_rect': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d2110>>,
#                'fit_view_delay': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d2020>>,
#                'fit_view_duration': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d2080>>,
#                'fit_view_on_init': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1ff0>>,
#                'fit_view_padding': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d2050>>,
#                'focused_point_index': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x1313d1b40>>,
#                'focused_point_ring_color': <bound method Union.default of <traitlets.traitlets.Union object at 0x1313d1b10>>,
#                'hovered_point_cursor': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d1960>>,
#                'hovered_point_ring_color': <bound method Union.default of <traitlets.traitlets.Union object at 0x1313d1a50>>,
#                'initial_zoom_level': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1f60>>,
#                'keys': <traitlets.traitlets.DefaultHandler at 0x107b6ff40>,
#                'label_padding': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d2860>>,
#                'layout': <bound method TraitType.default of <ipywidgets.widgets.trait_types.InstanceDict object at 0x107bcd9f0>>,
#                'link_arrow': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2620>>,
#                'link_arrows_size_scale': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1de0>>,
#                'link_color': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d25c0>>,
#                'link_greyout_opacity': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1c60>>,
#                'link_include_columns': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d2680>>,
#                'link_source': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d24d0>>,
#                'link_source_index': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2530>>,
#                'link_strength': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2650>>,
#                'link_target': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2560>>,
#                'link_target_index': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2590>>,
#                'link_visibility_distance_range': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d1e10>>,
#                'link_visibility_min_transparency': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1e40>>,
#                'link_width': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d25f0>>,
#                'link_width_scale': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1cc0>>,
#                'links': <bound method TraitType.default of <traitlets.traitlets.Any object at 0x1313d22f0>>,
#                'log': <traitlets.traitlets.DefaultHandler at 0x107b6eaa0>,
#                'pixel_ratio': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1f00>>,
#                'point_color': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2380>>,
#                'point_greyout_opacity': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d18d0>>,
#                'point_id': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2320>>,
#                'point_include_columns': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d24a0>>,
#                'point_index': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2350>>,
#                'point_label': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d23e0>>,
#                'point_label_weight': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2410>>,
#                'point_sampling_distance': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x1313d21d0>>,
#                'point_size': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d23b0>>,
#                'point_size_scale': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1930>>,
#                'point_x': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2440>>,
#                'point_y': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d2470>>,
#                'points': <bound method TraitType.default of <traitlets.traitlets.Any object at 0x1313d2260>>,
#                'random_seed': <bound method Union.default of <traitlets.traitlets.Union object at 0x1313d21a0>>,
#                'render_hovered_point_ring': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1990>>,
#                'render_links': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1b70>>,
#                'scale_points_on_zoom': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1f30>>,
#                'selected_point_indices': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d28f0>>,
#                'show_FPS_monitor': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1ed0>>,
#                'show_dynamic_labels': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d26b0>>,
#                'show_hovered_point_label': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d2890>>,
#                'show_labels_for': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d2710>>,
#                'show_top_labels': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d2770>>,
#                'show_top_labels_by': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x1313d27d0>>,
#                'show_top_labels_limit': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x1313d27a0>>,
#                'simulation_center': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x131346e00>>,
#                'simulation_decay': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x107edc070>>,
#                'simulation_friction': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d16f0>>,
#                'simulation_gravity': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x131346e30>>,
#                'simulation_link_dist_random_variation_range': <bound method TraitType.default of <traitlets.traitlets.List object at 0x1313d1660>>,
#                'simulation_link_distance': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d1690>>,
#                'simulation_link_spring': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1205cbe50>>,
#                'simulation_repulsion': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x131346dd0>>,
#                'simulation_repulsion_from_mouse': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d16c0>>,
#                'simulation_repulsion_quadtree_levels': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1205cbe20>>,
#                'simulation_repulsion_theta': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1205cbd30>>,
#                'space_size': <bound method TraitType.default of <traitlets.traitlets.Int object at 0x1313d17e0>>,
#                'static_label_weight': <bound method TraitType.default of <traitlets.traitlets.Float object at 0x1313d2800>>,
#                'tabbable': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x107bcd600>>,
#                'tooltip': <bound method TraitType.default of <traitlets.traitlets.Unicode object at 0x107bcd630>>,
#                'use_quadtree': <bound method TraitType.default of <traitlets.traitlets.Bool object at 0x1313d1ea0>>},
#               '_traits': {'_dom_classes': <ipywidgets.widgets.trait_types.TypedTuple at 0x107bccb50>,
#                '_ipc_links': <traitlets.traitlets.Bytes at 0x1313d2290>,
#                '_ipc_points': <traitlets.traitlets.Bytes at 0x1313d2200>,
#                '_model_module': <traitlets.traitlets.Unicode at 0x1312c8d00>,
#                '_model_module_version': <traitlets.traitlets.Unicode at 0x131346ce0>,
#                '_model_name': <traitlets.traitlets.Unicode at 0x1312c8cd0>,
#                '_msg_callbacks': <traitlets.traitlets.Instance at 0x107b6ffd0>,
#                '_property_lock': <traitlets.traitlets.Dict at 0x107b6ff70>,
#                '_states_to_send': <traitlets.traitlets.Set at 0x107b6feb0>,
#                '_view_count': <traitlets.traitlets.Int at 0x107b6f580>,
#                '_view_module': <traitlets.traitlets.Unicode at 0x131346d40>,
#                '_view_module_version': <traitlets.traitlets.Unicode at 0x131346d70>,
#                '_view_name': <traitlets.traitlets.Unicode at 0x131346d10>,
#                'background_color': <traitlets.traitlets.Union at 0x1313d17b0>,
#                'clicked_node_index': <traitlets.traitlets.Int at 0x1313d28c0>,
#                'comm': <traitlets.traitlets.Any at 0x107b6fb50>,
#                'curved_link_control_point_distance': <traitlets.traitlets.Float at 0x1313d1d80>,
#                'curved_link_segments': <traitlets.traitlets.Int at 0x1313d1d20>,
#                'curved_link_weight': <traitlets.traitlets.Float at 0x1313d1d50>,
#                'curved_links': <traitlets.traitlets.Bool at 0x1313d1cf0>,
#                'default_link_arrows': <traitlets.traitlets.Bool at 0x1313d1db0>,
#                'default_link_color': <traitlets.traitlets.Union at 0x1313d1c30>,
#                'default_link_width': <traitlets.traitlets.Float at 0x1313d1c90>,
#                'default_point_color': <traitlets.traitlets.Union at 0x1313d18a0>,
#                'default_point_size': <traitlets.traitlets.Float at 0x1313d1900>,
#                'disable_simulation': <traitlets.traitlets.Bool at 0x107ea52a0>,
#                'disable_zoom': <traitlets.traitlets.Bool at 0x1313d1f90>,
#                'dynamic_label_weight': <traitlets.traitlets.Float at 0x1313d2830>,
#                'enable_drag': <traitlets.traitlets.Bool at 0x1313d1fc0>,
#                'fit_view_by_points_in_rect': <traitlets.traitlets.List at 0x1313d2110>,
#                'fit_view_delay': <traitlets.traitlets.Float at 0x1313d2020>,
#                'fit_view_duration': <traitlets.traitlets.Float at 0x1313d2080>,
#                'fit_view_on_init': <traitlets.traitlets.Bool at 0x1313d1ff0>,
#                'fit_view_padding': <traitlets.traitlets.Float at 0x1313d2050>,
#                'focused_point_index': <traitlets.traitlets.Int at 0x1313d1b40>,
#                'focused_point_ring_color': <traitlets.traitlets.Union at 0x1313d1b10>,
#                'hovered_point_cursor': <traitlets.traitlets.Unicode at 0x1313d1960>,
#                'hovered_point_ring_color': <traitlets.traitlets.Union at 0x1313d1a50>,
#                'initial_zoom_level': <traitlets.traitlets.Float at 0x1313d1f60>,
#                'keys': <traitlets.traitlets.List at 0x107b6fbb0>,
#                'label_padding': <traitlets.traitlets.Float at 0x1313d2860>,
#                'layout': <ipywidgets.widgets.trait_types.InstanceDict at 0x107bcd9f0>,
#                'link_arrow': <traitlets.traitlets.Unicode at 0x1313d2620>,
#                'link_arrows_size_scale': <traitlets.traitlets.Float at 0x1313d1de0>,
#                'link_color': <traitlets.traitlets.Unicode at 0x1313d25c0>,
#                'link_greyout_opacity': <traitlets.traitlets.Float at 0x1313d1c60>,
#                'link_include_columns': <traitlets.traitlets.List at 0x1313d2680>,
#                'link_source': <traitlets.traitlets.Unicode at 0x1313d24d0>,
#                'link_source_index': <traitlets.traitlets.Unicode at 0x1313d2530>,
#                'link_strength': <traitlets.traitlets.Unicode at 0x1313d2650>,
#                'link_target': <traitlets.traitlets.Unicode at 0x1313d2560>,
#                'link_target_index': <traitlets.traitlets.Unicode at 0x1313d2590>,
#                'link_visibility_distance_range': <traitlets.traitlets.List at 0x1313d1e10>,
#                'link_visibility_min_transparency': <traitlets.traitlets.Float at 0x1313d1e40>,
#                'link_width': <traitlets.traitlets.Unicode at 0x1313d25f0>,
#                'link_width_scale': <traitlets.traitlets.Float at 0x1313d1cc0>,
#                'links': <traitlets.traitlets.Any at 0x1313d22f0>,
#                'log': <traitlets.traitlets.Instance at 0x107b6ea10>,
#                'pixel_ratio': <traitlets.traitlets.Float at 0x1313d1f00>,
#                'point_color': <traitlets.traitlets.Unicode at 0x1313d2380>,
#                'point_greyout_opacity': <traitlets.traitlets.Float at 0x1313d18d0>,
#                'point_id': <traitlets.traitlets.Unicode at 0x1313d2320>,
#                'point_include_columns': <traitlets.traitlets.List at 0x1313d24a0>,
#                'point_index': <traitlets.traitlets.Unicode at 0x1313d2350>,
#                'point_label': <traitlets.traitlets.Unicode at 0x1313d23e0>,
#                'point_label_weight': <traitlets.traitlets.Unicode at 0x1313d2410>,
#                'point_sampling_distance': <traitlets.traitlets.Int at 0x1313d21d0>,
#                'point_size': <traitlets.traitlets.Unicode at 0x1313d23b0>,
#                'point_size_scale': <traitlets.traitlets.Float at 0x1313d1930>,
#                'point_x': <traitlets.traitlets.Unicode at 0x1313d2440>,
#                'point_y': <traitlets.traitlets.Unicode at 0x1313d2470>,
#                'points': <traitlets.traitlets.Any at 0x1313d2260>,
#                'random_seed': <traitlets.traitlets.Union at 0x1313d21a0>,
#                'render_hovered_point_ring': <traitlets.traitlets.Bool at 0x1313d1990>,
#                'render_links': <traitlets.traitlets.Bool at 0x1313d1b70>,
#                'scale_points_on_zoom': <traitlets.traitlets.Bool at 0x1313d1f30>,
#                'selected_point_indices': <traitlets.traitlets.List at 0x1313d28f0>,
#                'show_FPS_monitor': <traitlets.traitlets.Bool at 0x1313d1ed0>,
#                'show_dynamic_labels': <traitlets.traitlets.Bool at 0x1313d26b0>,
#                'show_hovered_point_label': <traitlets.traitlets.Bool at 0x1313d2890>,
#                'show_labels_for': <traitlets.traitlets.List at 0x1313d2710>,
#                'show_top_labels': <traitlets.traitlets.Bool at 0x1313d2770>,
#                'show_top_labels_by': <traitlets.traitlets.Unicode at 0x1313d27d0>,
#                'show_top_labels_limit': <traitlets.traitlets.Int at 0x1313d27a0>,
#                'simulation_center': <traitlets.traitlets.Float at 0x131346e00>,
#                'simulation_decay': <traitlets.traitlets.Float at 0x107edc070>,
#                'simulation_friction': <traitlets.traitlets.Float at 0x1313d16f0>,
#                'simulation_gravity': <traitlets.traitlets.Float at 0x131346e30>,
#                'simulation_link_dist_random_variation_range': <traitlets.traitlets.List at 0x1313d1660>,
#                'simulation_link_distance': <traitlets.traitlets.Float at 0x1313d1690>,
#                'simulation_link_spring': <traitlets.traitlets.Float at 0x1205cbe50>,
#                'simulation_repulsion': <traitlets.traitlets.Float at 0x131346dd0>,
#                'simulation_repulsion_from_mouse': <traitlets.traitlets.Float at 0x1313d16c0>,
#                'simulation_repulsion_quadtree_levels': <traitlets.traitlets.Float at 0x1205cbe20>,
#                'simulation_repulsion_theta': <traitlets.traitlets.Float at 0x1205cbd30>,
#                'space_size': <traitlets.traitlets.Int at 0x1313d17e0>,
#                'static_label_weight': <traitlets.traitlets.Float at 0x1313d2800>,
#                'tabbable': <traitlets.traitlets.Bool at 0x107bcd600>,
#                'tooltip': <traitlets.traitlets.Unicode at 0x107bcd630>,
#                'use_quadtree': <traitlets.traitlets.Bool at 0x1313d1ea0>},
#               '_static_immutable_initial_values': {'_model_module': 'anywidget',
#                '_model_module_version': '0.9.0',
#                '_model_name': 'AnyModel',
#                '_view_count': None,
#                '_view_module': 'anywidget',
#                '_view_module_version': '0.9.0',
#                '_view_name': 'AnyView',
#                'clicked_node_index': None,
#                'comm': None,
#                'curved_link_segments': None,
#                'curved_links': None,
#                'default_link_arrows': None,
#                'disable_simulation': None,
#                'disable_zoom': None,
#                'enable_drag': None,
#                'fit_view_on_init': None,
#                'focused_point_index': None,
#                'hovered_point_cursor': None,
#                'link_arrow': None,
#                'link_color': None,
#                'link_source': None,
#                'link_source_index': None,
#                'link_strength': None,
#                'link_target': None,
#                'link_target_index': None,
#                'link_width': None,
#                'links': None,
#                'point_color': None,
#                'point_id': None,
#                'point_index': None,
#                'point_label': None,
#                'point_label_weight': None,
#                'point_sampling_distance': None,
#                'point_size': None,
#                'point_x': None,
#                'point_y': None,
#                'points': None,
#                'render_hovered_point_ring': None,
#                'render_links': None,
#                'scale_points_on_zoom': None,
#                'show_FPS_monitor': None,
#                'show_dynamic_labels': None,
#                'show_hovered_point_label': None,
#                'show_top_labels': None,
#                'show_top_labels_by': None,
#                'show_top_labels_limit': None,
#                'space_size': None,
#                'tabbable': None,
#                'tooltip': None,
#                'use_quadtree': None},
#               '_descriptors': [<traitlets.traitlets.ObserveHandler at 0x107bcc040>,
#                <traitlets.traitlets.DefaultHandler at 0x107b6ff40>,
#                <ipywidgets.widgets.trait_types.TypedTuple at 0x107bccb50>,
#                <traitlets.traitlets.Bytes at 0x1313d2290>,
#                <traitlets.traitlets.Bytes at 0x1313d2200>,
#                <traitlets.traitlets.DefaultHandler at 0x107b6eaa0>,
#                <traitlets.traitlets.Unicode at 0x1312c8d00>,
#                <traitlets.traitlets.Unicode at 0x131346ce0>,
#                <traitlets.traitlets.Unicode at 0x1312c8cd0>,
#                <traitlets.traitlets.Instance at 0x107b6ffd0>,
#                <traitlets.traitlets.Dict at 0x107b6ff70>,
#                <traitlets.traitlets.Set at 0x107b6feb0>,
#                <traitlets.traitlets.Int at 0x107b6f580>,
#                <traitlets.traitlets.Unicode at 0x131346d40>,
#                <traitlets.traitlets.Unicode at 0x131346d70>,
#                <traitlets.traitlets.Unicode at 0x131346d10>,
#                <traitlets.traitlets.Union at 0x1313d17b0>,
#                <traitlets.traitlets.ObserveHandler at 0x1313d2950>,
#                <traitlets.traitlets.ObserveHandler at 0x1313d29b0>,
#                <traitlets.traitlets.Int at 0x1313d28c0>,
#                <traitlets.traitlets.Any at 0x107b6fb50>,
#                <traitlets.traitlets.Float at 0x1313d1d80>,
#                <traitlets.traitlets.Int at 0x1313d1d20>,
#                <traitlets.traitlets.Float at 0x1313d1d50>,
#                <traitlets.traitlets.Bool at 0x1313d1cf0>,
#                <traitlets.traitlets.Bool at 0x1313d1db0>,
#                <traitlets.traitlets.Union at 0x1313d1c30>,
#                <traitlets.traitlets.Float at 0x1313d1c90>,
#                <traitlets.traitlets.Union at 0x1313d18a0>,
#                <traitlets.traitlets.Float at 0x1313d1900>,
#                <traitlets.traitlets.Bool at 0x107ea52a0>,
#                <traitlets.traitlets.Bool at 0x1313d1f90>,
#                <traitlets.traitlets.Float at 0x1313d2830>,
#                <traitlets.traitlets.Bool at 0x1313d1fc0>,
#                <traitlets.traitlets.List at 0x1313d2110>,
#                <traitlets.traitlets.Float at 0x1313d2020>,
#                <traitlets.traitlets.Float at 0x1313d2080>,
#                <traitlets.traitlets.Bool at 0x1313d1ff0>,
#                <traitlets.traitlets.Float at 0x1313d2050>,
#                <traitlets.traitlets.Int at 0x1313d1b40>,
#                <traitlets.traitlets.Union at 0x1313d1b10>,
#                <traitlets.traitlets.Unicode at 0x1313d1960>,
#                <traitlets.traitlets.Union at 0x1313d1a50>,
#                <traitlets.traitlets.Float at 0x1313d1f60>,
#                <traitlets.traitlets.List at 0x107b6fbb0>,
#                <traitlets.traitlets.Float at 0x1313d2860>,
#                <ipywidgets.widgets.trait_types.InstanceDict at 0x107bcd9f0>,
#                <traitlets.traitlets.Unicode at 0x1313d2620>,
#                <traitlets.traitlets.Float at 0x1313d1de0>,
#                <traitlets.traitlets.Unicode at 0x1313d25c0>,
#                <traitlets.traitlets.Float at 0x1313d1c60>,
#                <traitlets.traitlets.List at 0x1313d2680>,
#                <traitlets.traitlets.Unicode at 0x1313d24d0>,
#                <traitlets.traitlets.Unicode at 0x1313d2530>,
#                <traitlets.traitlets.Unicode at 0x1313d2650>,
#                <traitlets.traitlets.Unicode at 0x1313d2560>,
#                <traitlets.traitlets.Unicode at 0x1313d2590>,
#                <traitlets.traitlets.List at 0x1313d1e10>,
#                <traitlets.traitlets.Float at 0x1313d1e40>,
#                <traitlets.traitlets.Unicode at 0x1313d25f0>,
#                <traitlets.traitlets.Float at 0x1313d1cc0>,
#                <traitlets.traitlets.Any at 0x1313d22f0>,
#                <traitlets.traitlets.Instance at 0x107b6ea10>,
#                <traitlets.traitlets.Float at 0x1313d1f00>,
#                <traitlets.traitlets.Unicode at 0x1313d2380>,
#                <traitlets.traitlets.Float at 0x1313d18d0>,
#                <traitlets.traitlets.Unicode at 0x1313d2320>,
#                <traitlets.traitlets.List at 0x1313d24a0>,
#                <traitlets.traitlets.Unicode at 0x1313d2350>,
#                <traitlets.traitlets.Unicode at 0x1313d23e0>,
#                <traitlets.traitlets.Unicode at 0x1313d2410>,
#                <traitlets.traitlets.Int at 0x1313d21d0>,
#                <traitlets.traitlets.Unicode at 0x1313d23b0>,
#                <traitlets.traitlets.Float at 0x1313d1930>,
#                <traitlets.traitlets.Unicode at 0x1313d2440>,
#                <traitlets.traitlets.Unicode at 0x1313d2470>,
#                <traitlets.traitlets.Any at 0x1313d2260>,
#                <traitlets.traitlets.Union at 0x1313d21a0>,
#                <traitlets.traitlets.Bool at 0x1313d1990>,
#                <traitlets.traitlets.Bool at 0x1313d1b70>,
#                <traitlets.traitlets.Bool at 0x1313d1f30>,
#                <traitlets.traitlets.List at 0x1313d28f0>,
#                <traitlets.traitlets.Bool at 0x1313d1ed0>,
#                <traitlets.traitlets.Bool at 0x1313d26b0>,
#                <traitlets.traitlets.Bool at 0x1313d2890>,
#                <traitlets.traitlets.List at 0x1313d2710>,
#                <traitlets.traitlets.Bool at 0x1313d2770>,
#                <traitlets.traitlets.Unicode at 0x1313d27d0>,
#                <traitlets.traitlets.Int at 0x1313d27a0>,
#                <traitlets.traitlets.Float at 0x131346e00>,
#                <traitlets.traitlets.Float at 0x107edc070>,
#                <traitlets.traitlets.Float at 0x1313d16f0>,
#                <traitlets.traitlets.Float at 0x131346e30>,
#                <traitlets.traitlets.List at 0x1313d1660>,
#                <traitlets.traitlets.Float at 0x1313d1690>,
#                <traitlets.traitlets.Float at 0x1205cbe50>,
#                <traitlets.traitlets.Float at 0x131346dd0>,
#                <traitlets.traitlets.Float at 0x1313d16c0>,
#                <traitlets.traitlets.Float at 0x1205cbe20>,
#                <traitlets.traitlets.Float at 0x1205cbd30>,
#                <traitlets.traitlets.Int at 0x1313d17e0>,
#                <traitlets.traitlets.Float at 0x1313d2800>,
#                <traitlets.traitlets.Bool at 0x107bcd600>,
#                <traitlets.traitlets.Unicode at 0x107bcd630>,
#                <traitlets.traitlets.Bool at 0x1313d1ea0>],
#               '_instance_inits': [<bound method ObserveHandler.instance_init of <traitlets.traitlets.ObserveHandler object at 0x107bcc040>>,
#                <bound method BaseDescriptor.instance_init of <traitlets.traitlets.DefaultHandler object at 0x107b6ff40>>,
#                <bound method BaseDescriptor.instance_init of <traitlets.traitlets.DefaultHandler object at 0x107b6eaa0>>,
#                <bound method Instance.instance_init of <traitlets.traitlets.Instance object at 0x107b6ffd0>>,
#                <bound method ObserveHandler.instance_init of <traitlets.traitlets.ObserveHandler object at 0x1313d2950>>,
#                <bound method ObserveHandler.instance_init of <traitlets.traitlets.ObserveHandler object at 0x1313d29b0>>,
#                <bound method Instance.instance_init of <ipywidgets.widgets.trait_types.InstanceDict object at 0x107bcd9f0>>,
#                <bound method Instance.instance_init of <traitlets.traitlets.Instance object at 0x107b6ea10>>],
#               '__annotations__': {}})

# %%
# Out:
# [cosmograph_widget.Cosmograph,
#  anywidget.widget.AnyWidget,
#  ipywidgets.widgets.domwidget.DOMWidget,
#  ipywidgets.widgets.widget.Widget,
#  ipywidgets.widgets.widget.LoggingHasTraits,
#  traitlets.traitlets.HasTraits,
#  traitlets.traitlets.HasDescriptors,
#  object]

# %%
w = [1,2,3,4, 5]
w[::-1][:-1]
# different way of doing w[::-1][:-1]
w[-1:0:-1]
# Out:
# [5, 4, 3, 2]

# %%
def vars_parents_diff(typ):
    parent_types = typ.mro()[-1:0:-1]
    parent_vars = {}
    for parent in parent_types:
        parent_vars.update(vars(parent))

    return {k: v for k, v in vars(typ).items() if k not in parent_vars}


t = vars_parents_diff(Cosmograph)
t = {k: v for k, v in t.items() if not callable(v)}
t
# Out:
# {'_esm': <anywidget._file_contents.FileContents at 0x1313d2bf0>,
#  '_css': <anywidget._file_contents.FileContents at 0x1313d2ad0>,
#  'disable_simulation': <traitlets.traitlets.Bool at 0x107ea52a0>,
#  'simulation_decay': <traitlets.traitlets.Float at 0x107edc070>,
#  'simulation_gravity': <traitlets.traitlets.Float at 0x131346e30>,
#  'simulation_center': <traitlets.traitlets.Float at 0x131346e00>,
#  'simulation_repulsion': <traitlets.traitlets.Float at 0x131346dd0>,
#  'simulation_repulsion_theta': <traitlets.traitlets.Float at 0x1205cbd30>,
#  'simulation_repulsion_quadtree_levels': <traitlets.traitlets.Float at 0x1205cbe20>,
#  'simulation_link_spring': <traitlets.traitlets.Float at 0x1205cbe50>,
#  'simulation_link_distance': <traitlets.traitlets.Float at 0x1313d1690>,
#  'simulation_link_dist_random_variation_range': <traitlets.traitlets.List at 0x1313d1660>,
#  'simulation_repulsion_from_mouse': <traitlets.traitlets.Float at 0x1313d16c0>,
#  'simulation_friction': <traitlets.traitlets.Float at 0x1313d16f0>,
#  'background_color': <traitlets.traitlets.Union at 0x1313d17b0>,
#  'space_size': <traitlets.traitlets.Int at 0x1313d17e0>,
#  'default_point_color': <traitlets.traitlets.Union at 0x1313d18a0>,
#  'point_greyout_opacity': <traitlets.traitlets.Float at 0x1313d18d0>,
#  'default_point_size': <traitlets.traitlets.Float at 0x1313d1900>,
#  'point_size_scale': <traitlets.traitlets.Float at 0x1313d1930>,
#  'hovered_point_cursor': <traitlets.traitlets.Unicode at 0x1313d1960>,
#  'render_hovered_point_ring': <traitlets.traitlets.Bool at 0x1313d1990>,
#  'hovered_point_ring_color': <traitlets.traitlets.Union at 0x1313d1a50>,
#  'focused_point_ring_color': <traitlets.traitlets.Union at 0x1313d1b10>,
#  'focused_point_index': <traitlets.traitlets.Int at 0x1313d1b40>,
#  'render_links': <traitlets.traitlets.Bool at 0x1313d1b70>,
#  'default_link_color': <traitlets.traitlets.Union at 0x1313d1c30>,
#  'link_greyout_opacity': <traitlets.traitlets.Float at 0x1313d1c60>,
#  'default_link_width': <traitlets.traitlets.Float at 0x1313d1c90>,
#  'link_width_scale': <traitlets.traitlets.Float at 0x1313d1cc0>,
#  'curved_links': <traitlets.traitlets.Bool at 0x1313d1cf0>,
#  'curved_link_segments': <traitlets.traitlets.Int at 0x1313d1d20>,
#  'curved_link_weight': <traitlets.traitlets.Float at 0x1313d1d50>,
#  'curved_link_control_point_distance': <traitlets.traitlets.Float at 0x1313d1d80>,
#  'default_link_arrows': <traitlets.traitlets.Bool at 0x1313d1db0>,
#  'link_arrows_size_scale': <traitlets.traitlets.Float at 0x1313d1de0>,
#  'link_visibility_distance_range': <traitlets.traitlets.List at 0x1313d1e10>,
#  'link_visibility_min_transparency': <traitlets.traitlets.Float at 0x1313d1e40>,
#  'use_quadtree': <traitlets.traitlets.Bool at 0x1313d1ea0>,
#  'show_FPS_monitor': <traitlets.traitlets.Bool at 0x1313d1ed0>,
#  'pixel_ratio': <traitlets.traitlets.Float at 0x1313d1f00>,
#  'scale_points_on_zoom': <traitlets.traitlets.Bool at 0x1313d1f30>,
#  'initial_zoom_level': <traitlets.traitlets.Float at 0x1313d1f60>,
#  'disable_zoom': <traitlets.traitlets.Bool at 0x1313d1f90>,
#  'enable_drag': <traitlets.traitlets.Bool at 0x1313d1fc0>,
#  'fit_view_on_init': <traitlets.traitlets.Bool at 0x1313d1ff0>,
#  'fit_view_delay': <traitlets.traitlets.Float at 0x1313d2020>,
#  'fit_view_padding': <traitlets.traitlets.Float at 0x1313d2050>,
#  'fit_view_duration': <traitlets.traitlets.Float at 0x1313d2080>,
#  'fit_view_by_points_in_rect': <traitlets.traitlets.List at 0x1313d2110>,
#  'random_seed': <traitlets.traitlets.Union at 0x1313d21a0>,
#  'point_sampling_distance': <traitlets.traitlets.Int at 0x1313d21d0>,
#  '_ipc_points': <traitlets.traitlets.Bytes at 0x1313d2200>,
#  'points': <traitlets.traitlets.Any at 0x1313d2260>,
#  '_ipc_links': <traitlets.traitlets.Bytes at 0x1313d2290>,
#  'links': <traitlets.traitlets.Any at 0x1313d22f0>,
#  'point_id': <traitlets.traitlets.Unicode at 0x1313d2320>,
#  'point_index': <traitlets.traitlets.Unicode at 0x1313d2350>,
#  'point_color': <traitlets.traitlets.Unicode at 0x1313d2380>,
#  'point_size': <traitlets.traitlets.Unicode at 0x1313d23b0>,
#  'point_label': <traitlets.traitlets.Unicode at 0x1313d23e0>,
#  'point_label_weight': <traitlets.traitlets.Unicode at 0x1313d2410>,
#  'point_x': <traitlets.traitlets.Unicode at 0x1313d2440>,
#  'point_y': <traitlets.traitlets.Unicode at 0x1313d2470>,
#  'point_include_columns': <traitlets.traitlets.List at 0x1313d24a0>,
#  'link_source': <traitlets.traitlets.Unicode at 0x1313d24d0>,
#  'link_source_index': <traitlets.traitlets.Unicode at 0x1313d2530>,
#  'link_target': <traitlets.traitlets.Unicode at 0x1313d2560>,
#  'link_target_index': <traitlets.traitlets.Unicode at 0x1313d2590>,
#  'link_color': <traitlets.traitlets.Unicode at 0x1313d25c0>,
#  'link_width': <traitlets.traitlets.Unicode at 0x1313d25f0>,
#  'link_arrow': <traitlets.traitlets.Unicode at 0x1313d2620>,
#  'link_strength': <traitlets.traitlets.Unicode at 0x1313d2650>,
#  'link_include_columns': <traitlets.traitlets.List at 0x1313d2680>,
#  'show_dynamic_labels': <traitlets.traitlets.Bool at 0x1313d26b0>,
#  'show_labels_for': <traitlets.traitlets.List at 0x1313d2710>,
#  'show_top_labels': <traitlets.traitlets.Bool at 0x1313d2770>,
#  'show_top_labels_limit': <traitlets.traitlets.Int at 0x1313d27a0>,
#  'show_top_labels_by': <traitlets.traitlets.Unicode at 0x1313d27d0>,
#  'static_label_weight': <traitlets.traitlets.Float at 0x1313d2800>,
#  'dynamic_label_weight': <traitlets.traitlets.Float at 0x1313d2830>,
#  'label_padding': <traitlets.traitlets.Float at 0x1313d2860>,
#  'show_hovered_point_label': <traitlets.traitlets.Bool at 0x1313d2890>,
#  'clicked_node_index': <traitlets.traitlets.Int at 0x1313d28c0>,
#  'selected_point_indices': <traitlets.traitlets.List at 0x1313d28f0>}

# %%
from graze import graze

url = 'https://raw.githubusercontent.com/cosmograph-org/cosmograph/refs/heads/dev/packages/cosmograph/src/modules/cosmograph/config/simulation.ts?token=GHSAT0AAAAAACSGWAOWSPSYWQEN2BYDRHO6ZYH5S6Q'
code_str = graze(url).decode()
len(code_str)


import jy

t = jy.func_name_and_params_pairs(code_str)

# %%
code_str
# Out:
# b'import { GraphSimulationSettings } from \'@cosmograph/cosmos\'\n\nexport interface SimulationConfig {\n  /**\n   * Decay coefficient. Use bigger values if you want the simulation to "cool down" slower.\n   * Default value: `1000`\n   */\n  simulationDecay?: GraphSimulationSettings[\'decay\'];\n\n  /**\n   * Gravity force coefficient.\n   * Default value: `0`\n   */\n  simulationGravity?: GraphSimulationSettings[\'gravity\'];\n\n  /**\n   * Centering to center mass force coefficient.\n   * Default value: `0`\n   */\n  simulationCenter?: GraphSimulationSettings[\'center\'];\n\n  /**\n   * Repulsion force coefficient.\n   * Default value: `0.1`\n   */\n  simulationRepulsion?: GraphSimulationSettings[\'repulsion\'];\n\n  /**\n   * Decreases / increases the detalization of the Many-Body force calculations.\n   * When `useQuadtree` is set to `true`, this property corresponds to the Barnes\xe2\x80\x93Hut approximation criterion.\n   * Default value: `1.7`\n   */\n  simulationRepulsionTheta?: GraphSimulationSettings[\'repulsionTheta\'];\n\n  /**\n   * Barnes\xe2\x80\x93Hut approximation depth.\n   * Can only be used when `useQuadtree` is set `true`.\n   * Default value: `12`\n   */\n  simulationRepulsionQuadtreeLevels?: GraphSimulationSettings[\'repulsionQuadtreeLevels\'];\n\n  /**\n   * Link spring force coefficient.\n   * Default value: `1`\n   */\n  simulationLinkSpring?: GraphSimulationSettings[\'linkSpring\'];\n\n  /**\n   * Minimum link distance.\n   * Default value: `2`\n   */\n  simulationLinkDistance?: GraphSimulationSettings[\'linkDistance\'];\n\n  /**\n   * Range of random link distance values.\n   * Default value: `[1, 1.2]`\n   */\n  simulationLinkDistRandomVariationRange?: GraphSimulationSettings[\'linkDistRandomVariationRange\'];\n\n  /**\n   * Repulsion coefficient from mouse position.\n   * The repulsion force is activated by pressing the right mouse button.\n   * Default value: `2`\n   */\n  simulationRepulsionFromMouse?: GraphSimulationSettings[\'repulsionFromMouse\'];\n\n  /**\n   * Friction coefficient.\n   * Default value: `0.85`\n   */\n  simulationFriction?: GraphSimulationSettings[\'friction\'];\n}\n\nexport interface SimulationEventConfig {\n  /** Callback function that will be called when the simulation starts. */\n  onSimulationStart?: GraphSimulationSettings[\'onStart\'];\n\n  /** Callback function that will be called when the simulation stops. */\n  onSimulationEnd?: GraphSimulationSettings[\'onEnd\'];\n\n  /** Callback function that will be called when the simulation is paused. */\n  onSimulationPause?: GraphSimulationSettings[\'onPause\'];\n\n  /** Callback function that will be called when the simulation is restarted. */\n  onSimulationRestart?: GraphSimulationSettings[\'onRestart\'];\n\n  /** Callback function that will be called on every tick of the simulation.\n   *\n   * @param {number} alpha - The value of alpha will decrease over time as the simulation "cools down".\n   * @param {number | undefined} index - The index of the hovered point.\n   * @param {[number, number] | undefined} pointPosition - The position of the point under the cursor.\n   */\n  onSimulationTick?: GraphSimulationSettings[\'onTick\'];\n}\n'

# %%
import pyperclip
pyperclip.copy(code_str)

# %%
print(code_str)
# Out:
# import { GraphSimulationSettings } from '@cosmograph/cosmos'
#
# export interface SimulationConfig {
#   /**
#    * Decay coefficient. Use bigger values if you want the simulation to "cool down" slower.
#    * Default value: `1000`
#    */
#   simulationDecay?: GraphSimulationSettings['decay'];
#
#   /**
#    * Gravity force coefficient.
#    * Default value: `0`
#    */
#   simulationGravity?: GraphSimulationSettings['gravity'];
#
#   /**
#    * Centering to center mass force coefficient.
#    * Default value: `0`
#    */
#   simulationCenter?: GraphSimulationSettings['center'];
#
#   /**
#    * Repulsion force coefficient.
#    * Default value: `0.1`
#    */
#   simulationRepulsion?: GraphSimulationSettings['repulsion'];
#
#   /**
#    * Decreases / increases the detalization of the Many-Body force calculations.
#    * When `useQuadtree` is set to `true`, this property corresponds to the Barnes–Hut approximation criterion.
#    * Default value: `1.7`
#    */
#   simulationRepulsionTheta?: GraphSimulationSettings['repulsionTheta'];
#
#   /**
#    * Barnes–Hut approximation depth.
#    * Can only be used when `useQuadtree` is set `true`.
#    * Default value: `12`
#    */
#   simulationRepulsionQuadtreeLevels?: GraphSimulationSettings['repulsionQuadtreeLevels'];
#
#   /**
#    * Link spring force coefficient.
#    * Default value: `1`
#    */
#   simulationLinkSpring?: GraphSimulationSettings['linkSpring'];
#
#   /**
#    * Minimum link distance.
#    * Default value: `2`
#    */
#   simulationLinkDistance?: GraphSimulationSettings['linkDistance'];
#
#   /**
#    * Range of random link distance values.
#    * Default value: `[1, 1.2]`
#    */
#   simulationLinkDistRandomVariationRange?: GraphSimulationSettings['linkDistRandomVariationRange'];
#
#   /**
#    * Repulsion coefficient from mouse position.
#    * The repulsion force is activated by pressing the right mouse button.
#    * Default value: `2`
#    */
#   simulationRepulsionFromMouse?: GraphSimulationSettings['repulsionFromMouse'];
#
#   /**
#    * Friction coefficient.
#    * Default value: `0.85`
#    */
#   simulationFriction?: GraphSimulationSettings['friction'];
# }
#
# export interface SimulationEventConfig {
#   /** Callback function that will be called when the simulation starts. */
#   onSimulationStart?: GraphSimulationSettings['onStart'];
#
#   /** Callback function that will be called when the simulation stops. */
#   onSimulationEnd?: GraphSimulationSettings['onEnd'];
#
#   /** Callback function that will be called when the simulation is paused. */
#   onSimulationPause?: GraphSimulationSettings['onPause'];
#
#   /** Callback function that will be called when the simulation is restarted. */
#   onSimulationRestart?: GraphSimulationSettings['onRestart'];
#
#   /** Callback function that will be called on every tick of the simulation.
#    *
#    * @param {number} alpha - The value of alpha will decrease over time as the simulation "cools down".
#    * @param {number | undefined} index - The index of the hovered point.
#    * @param {[number, number] | undefined} pointPosition - The position of the point under the cursor.
#    */
#   onSimulationTick?: GraphSimulationSettings['onTick'];
# }

# %%
# TODO: Delete when integrated to config_properties.py

# from oa import chat
# from oa.util import data_files

# # To make sure we get a json schema that is openAI compliant, we'll use an example of 
# # one in our prompt to AI to give us one...
# example_of_a_openai_json_schema = example_of_a_openai_json_schema = (
#     data_files.joinpath('json_schema_example.json').read_text()
# )

# json_schema_str = chat("""
#     Give me the json of a json_schema I can use to represent information on the objects 
#     that you'll parse out of typescript definitions. 
    
#     For example, if given a TS string like this:
                       
#     ```
# import { GraphSimulationSettings } from '@cosmograph/cosmos'

# export interface SimulationConfig {
#   /**
#    * Decay coefficient. Use bigger values if you want the simulation to "cool down" slower.
#    * Default value: `1000`
#    */
#   simulationDecay?: GraphSimulationSettings['decay'];

#   /**
#    * Gravity force coefficient.
#    * Default value: `0`
#    */
#   simulationGravity?: GraphSimulationSettings['gravity'];
                       
# export interface SimulationEventConfig {
#   /** Callback function that will be called when the simulation starts. */
#   onSimulationStart?: GraphSimulationSettings['onStart'];
                       
# I'd like my json to communicate the fact that there were two object (SimulationConfig and SimulationEventConfig)
# that wer interfaces, and also give me the information about those object's properties
# for each, their name, type (if available), decription (if available), default (if available), 
# and what ever you think might be useful
# ```
# """,
#     model='gpt-4o-mini',
#     response_format={'type': 'json_object'}
# )

# import json
# from pprint import pprint

# schema = json.loads(json_schema_str)

# schema
# Out:
# {'$schema': 'http://json-schema.org/draft-07/schema#',
#  'type': 'object',
#  'properties': {'interfaces': {'type': 'array',
#    'items': {'type': 'object',
#     'properties': {'name': {'type': 'string',
#       'description': 'The name of the interface.'},
#      'description': {'type': 'string',
#       'description': 'A brief description of the interface (if available).'},
#      'properties': {'type': 'array',
#       'items': {'type': 'object',
#        'properties': {'name': {'type': 'string',
#          'description': 'The name of the property within the interface.'},
#         'type': {'type': 'string',
#          'description': 'The TypeScript type of the property.'},
#         'description': {'type': 'string',
#          'description': 'A brief description of the property (if available).'},
#         'default': {'type': ['string', 'number', 'null'],
#          'description': 'The default value for the property (if available).'},
#         'optional': {'type': 'boolean',
#          'description': 'Indicates whether the property is optional.'}},
#        'required': ['name']}}},
#     'required': ['name', 'properties']}}},
#  'required': ['interfaces']}

# %%
# TODO: Delete when integrated to config_properties.py


# from oa import prompt_function
# import json
# from typing import Mapping

# from functools import partial

# from oa.tools import prompt_json_function

# schema = {
#     'name': 'whatevs',
#     'strict': False,
#     'schema': {
#         'type': 'object',
#         'properties': {
#             'interfaces': {
#                 'type': 'array',
#                 'items': {
#                     'type': 'object',
#                     'properties': {
#                         'name': {
#                             'type': 'string',
#                             'description': 'The name of the interface.',
#                         },
#                         'description': {
#                             'type': 'string',
#                             'description': 'A brief description of the interface (if available).',
#                         },
#                         'properties': {
#                             'type': 'array',
#                             'items': {
#                                 'type': 'object',
#                                 'properties': {
#                                     'name': {
#                                         'type': 'string',
#                                         'description': 'The name of the property within the interface.',
#                                     },
#                                     'type': {
#                                         'type': 'string',
#                                         'description': 'The TypeScript type of the property.',
#                                     },
#                                     'description': {
#                                         'type': 'string',
#                                         'description': 'A brief description of the property (if available).',
#                                     },
#                                     'default': {
#                                         'type': ['string', 'number', 'null'],
#                                         'description': 'The default value for the property (if available).',
#                                     },
#                                     'optional': {
#                                         'type': 'boolean',
#                                         'description': 'Indicates whether the property is optional.',
#                                     },
#                                 },
#                                 'required': ['name'],
#                             },
#                         },
#                     },
#                     'required': ['name', 'properties'],
#                 },
#             }
#         },
#     }
# }


# from graze import graze 


# url = 'https://raw.githubusercontent.com/cosmograph-org/cosmograph/refs/heads/dev/packages/cosmograph/src/modules/cosmograph/config/simulation.ts?token=GHSAT0AAAAAACSGWAOWSPSYWQEN2BYDRHO6ZYH5S6Q'
# code_str = graze(url).decode()

# parse_my_ts = prompt_json_function(
#     """
#     You are a typescript parser.
#     Parse through the following typescript file(s) contents and extract information 
#     about the objects in them, returning a json that fits the json_schema.

#     {ts_code}
#     """,
#     json_schema=schema,
# )

# t = parse_my_ts(code_str)

# %%
# TODO: Delete when integrated to config_properties.py


# from oa import prompt_function
# import json
# from typing import Mapping

# from functools import partial

# from oa.tools import prompt_json_function

# schema = {
#     'name': 'whatevs',
#     'strict': False,
#     'schema': {
#         'type': 'object',
#         'properties': {
#             'interfaces': {
#                 'type': 'array',
#                 'items': {
#                     'type': 'object',
#                     'properties': {
#                         'name': {
#                             'type': 'string',
#                             'description': 'The name of the interface.',
#                         },
#                         'description': {
#                             'type': 'string',
#                             'description': 'A brief description of the interface (if available).',
#                         },
#                         'properties': {
#                             'type': 'array',
#                             'items': {
#                                 'type': 'object',
#                                 'properties': {
#                                     'name': {
#                                         'type': 'string',
#                                         'description': 'The name of the property within the interface.',
#                                     },
#                                     'type': {
#                                         'type': 'string',
#                                         'description': 'The type of the property.',
#                                     },
#                                     'description': {
#                                         'type': 'string',
#                                         'description': 'A brief description of the property (if available).',
#                                     },
#                                     'default': {
#                                         'type': ['string', 'number', 'null'],
#                                         'description': 'The default value for the property (if available).',
#                                     },
#                                     'group': {
#                                         'type': ['string'],
#                                         'description': 'The group to which the property belongs.',
#                                     },
#                                     'optional': {
#                                         'type': 'boolean',
#                                         'description': 'Indicates whether the property is optional.',
#                                     },
#                                 },
#                                 'required': ['name', 'default'],
#                             },
#                         },
#                     },
#                     'required': ['name', 'properties'],
#                 },
#             }
#         },
#     }
# }


# from graze import graze 


# parse_my_md = prompt_json_function(
#     """
#     Parse through the following markdown contents and extract information 
#     about the objects in them, returning a json that fits the json_schema.
#     The "group" field is supposed to denote the section where you found the property;
#     i.e. "Minimal Configuration for Points", "Additional Points Configuration", etc.

#     You must always include a default field in the properties. 
#     It is usually in the descriptions as "Default value: ...". 
#     If you can't find a default, please just set it to "NO_DEFAULT", but still include the field.

#     {md_string}
#     """,
#     json_schema=schema,
# )



# md_string = """## Data and Configuration Parameters

# The Cosmograph widget builds upon the native Cosmograph library, inheriting most of its configuration parameters, most of which are optional and can be modified in real-time. For detailed insights about configuration parameters, refer to the [documentation](../lib/api/interfaces/CosmographConfig.mdx).

# ### Minimal Configuration for Points

# To render a graph, the following minimal configuration is required:

# - **`points`**: Data in a pandas DataFrame format.
# - **`point_id`**: Unique identifier column for each point.
# - **`point_index`**: Ordinal index of each point ranging from 0 to x (the number of unique points).

# ### Additional Points Configuration

# - **`point_color`**: Column name for point colors.
# - **`point_size`**: Column name for point sizes.
# - **`point_label`**: Column name for associated point labels.
# - **`point_label_weight`**: Column name for point label weights.
# - **`point_x`**: Column name for the x-coordinate.
# - **`point_y`**: Column name for the y-coordinate.
# - **`point_include_columns`**: An array of additional column names to include in point data.

# ### Minimal Configuration for Links

# To define links, the following fields are necessary:

# - **`links`**: Data in a pandas DataFrame format.
# - **`link_source`**: Column with the unique identifier for source points.
# - **`link_source_index`**: Index column of the source point, corresponding to `point_index`.
# - **`link_target`**: Column with the unique identifier for target points.
# - **`link_target_index`**: Index column of the target point, corresponding to `point_index`.

# ### Additional Links Configuration

# - **`link_color`**: Column name for link colors.
# - **`link_width`**: Column name for link widths.
# - **`link_arrow`**: Column name that indicates links with arrows.
# - **`link_strength`**: Column name for link strengths.
# - **`link_include_columns`**: An array of additional column names to include in link data.

# ### Simulation Settings

# Various simulation settings allow for detailed customization:

# - **`disable_simulation`**: Prevents the simulation from running, merely rendering the graph. Default: `None`.
# - **`simulation_decay`**: Defines how quickly the simulation cools down. Default: `1000`.
# - **`simulation_gravity`**: Coefficient for gravity force. Default: `0`.
# - **`simulation_center`**: Centers the mass force coefficient. Default: `0`.
# - **`simulation_repulsion`**: Configures point repulsion between points. Default: `0.1`.
# - **`simulation_repulsion_theta`**: Decreases / increases the detalization of the Many-Body force calculations. When `useQuadtree` is set to `True`, this property corresponds to the Barnes–Hut approximation criterion. Default: `1.7`.
# - **`simulation_link_spring`**: Spring constant for links. Default value: `1`.
# - **`simulation_link_distance`**: Default distance for links. Default value: `2`.
# - **`simulation_link_dist_random_variation_range`**: Random link distance range. Default value: `[1, 1.2]`.
# - **`simulation_repulsion_from_mouse`**:  Mouse position repulsion coefficient, activated by right-click. Default value: `2`.
# - **`simulation_friction`**: Sets simulation friction. Default value: `0.85`.

# ### Quadtree algorithm settings

# - **`use_quadtree`**: Activates quadtree algorithm for Many-Body force when set to `True`. Default value: `False`.
# - **`simulation_repulsion_quadtree_levels`**: Barnes–Hut approximation depth, usable when `useQuadtree` is set to `True`. Default value: `12`.

# ### Graph Appearance

# Customize the widget’s visual aspects:

# - **`background_color`**: Canvas background color. Default value: `'#222222'`.
# - **`space_size`**: Size of the simulation space. Default value: `4096`.
# - **`default_point_color`**: Default point size when `point_color` not specified. Default value: `'#b3b3b3'`.
# - **`point_greyout_opacity`**: Opacity of unselected nodes during selection. Default value: `0.1`.
# - **`default_point_size`**: The default size value to use for points when no `point_size` are provided. Default: `4`.
# - **`point_size_scale`**: Scale factor for point sizes. Default value: `1`.
# - **`hovered_point_cursor`**: Cursor type when hovering over a point. Default value: `'auto'`.
# - **`render_hovered_point_ring`**: Enables ring around hovered points. Default value: `False`.
# - **`hovered_point_ring_color`**: Color of hovered point ring. Default value: `'white'`.
# - **`focused_point_ring_color`**: Color of the focused point ring. Default value: `'white'`.
# - **`focused_point_index`**: Index of the focused point, prioritized over `focus_point` method. Default value: `None`.
# - **`render_links`**: Enables or disables link rendering. Default value: `True`.
# - **`default_link_color`**: Default link color when `link_color` not specified. Default value: `'#666666'`.
# - **`link_greyout_opacity`**: Opacity of unselected links during selection. Default value: `0.1`.
# - **`default_link_width`**: Default link width when `link_width` not specified. Default value: `1`.
# - **`link_width_scale`**: Scale factor for link widths. Default value: `1`.
# - **`curved_links`**: Enables or disables curved links. Default value: `False`.
# - **`curved_link_segments`**: Segments defining curved links. Default value: `19`.
# - **`curved_link_weight`**: Weight factor for link curvature. Default value: `0.8`.
# - **`curved_link_control_point_distance`**: Control point positioning for curves. If set to 1 then the control point is at a distance equal to the length of the line. Default value: `0.5`.
# - **`default_link_arrows`**: Enables or disables arrows on links when `link_arrow` not specified. Default value: `False`.
# - **`link_arrows_size_scale`**: Scale factor for link arrow size. Default value: `1`.
# - **`link_visibility_distance_range`**: Pixel distance range for link transparency. Default value: `[50, 150]`.
# - **`link_visibility_min_transparency`**: Minimum transparency of links based on `link_visibility_distance_range`. Default value: `0.25`.
# - **`scale_points_on_zoom`**: Scales point sizes when zooming. Default value: `True`.
# - **`initial_zoom_level`**: Starting zoom level. Default value: `None`.
# - **`disable_zoom`**: Enables or disables zooming. Default value: `False`.
# - **`enable_drag`**: Allows graph dragging. Default value: `False`.
# - **`fit_view_on_init`**: Automatically fits view to all points upon initialization. Default value: `True`.
# - **`fit_view_delay`**: Delay for fitting view after initialization in milliseconds. Default value: `250`.
# - **`fit_view_padding`**: Padding around fit view area. Default value: `0.1`.
# - **`fit_view_duration`**: Animation duration for view fitting in milliseconds. Default value: `250`.
# - **`fit_view_by_points_in_rect`**: Fits view to specified rectangle of points, active when `fit_view_on_init` is `True`. Default value: `None`.

# ### Label Options

# Control label display on the graph:

# - **`show_dynamic_labels`**: Flag to show dynamic labels for visible points. Default value: `False`.
# - **`show_labels_for`**: An array of point ids for which to show labels. Default value: `None`.
# - **`show_top_labels`**: Flag to display labels for the top points. Default values: `False`.
# - **`show_top_labels_limit`**: Maximum number of top points to show labels for. Default value: `100`.
# - **`show_top_labels_by`**: Column to determine which points are considered as a top. If not provided, the top points will be sorted by their total links count. Default value: `None`.
# - **`static_label_weight`**: Weight of static labels. Default value: `0.8`.
# - **`dynamic_label_weight`**: Weight of dynamic labels. Default value: `0.7`.
# - **`label_padding`**: Padding around labels in the graph.
# - **`show_hovered_point_label`**: Flag to display the label for the currently hovered point. Default value: `False`.

# ### Additional Parameters

# Various additional parameters enhance functionality:

# - **`show_FPS_monitor`**: Display an FPS counter in the upper right corner of the canvas. Default value: `False`.
# - **`pixel_ratio`**: Canvas pixel ratio. Default value: `2`.
# - **`random_seed`**: Seed value for generating random numbers in simulations. Default value: `None`.
# - **`point_sampling_distance`**: Distance threshold for sampling points. Default value: `150`.

# ## Methods and Values

# The Cosmograph widget provides several methods for data interaction:

# - **`select_point_by_index(index)`**: Selects point by index.
# - **`select_points_by_indices(indices)`**: Selects points by indices.
# - **`activate_rect_selection()`**: Activates rectangular selection.
# - **`deactivate_rect_selection()`**: Deactivates rectangular selection.
# - **`fit_view()`**: Center and zoom in/out the view to fit all points in the scene.
# - **`fit_view_by_indices(indices, duration, padding)`**: Center and zoom in/out the viewport to fit points by their indices.
# - **`fit_view_by_coordinates(coordinates, duration, padding)`**: Fit the given coordinates into the viewport.
# - **`focus_point(index)`**: Set focus on a point by index. A ring will be drawn around the focused point.
# - **`start(alpha)`**: Starts the simulation.
# - **`pause()`**: Pause the simulation.
# - **`restart()`**: Restarts the simulation.
# - **`step()`**: Render only one frame of the simulation.

# #### Values

# - **`clicked_point_index`**: Point index that currently clicked.
# - **`selected_point_indices`**: Point indices that currently selected.

# #### Legends
# - **`disable_point_color_legend`**: Disable point color legend.
# - **`disable_point_size_legend`**: Disable point size legend.
# - **`disable_link_color_legend`**: Disable link color legend.
# - **`disable_link_width_legend`**: Disable link width legend."""


# parsed_md_string = parse_my_md(md_string)

# # parsed_md_dict = json.loads(parsed_md_string)
# print(json.dumps(parsed_md_string, indent=2))
# Out:
# {
#   "interfaces": [
#     {
#       "name": "CosmographConfig",
#       "description": "The configuration parameters for the Cosmograph widget.",
#       "properties": [
#         {
#           "name": "points",
#           "type": "DataFrame",
#           "description": "Data in a pandas DataFrame format.",
#           "group": "Minimal Configuration for Points",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_id",
#           "type": "string",
#           "description": "Unique identifier column for each point.",
#           "group": "Minimal Configuration for Points",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_index",
#           "type": "integer",
#           "description": "Ordinal index of each point ranging from 0 to x (the number of unique points).",
#           "group": "Minimal Configuration for Points",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_color",
#           "type": "string",
#           "description": "Column name for point colors.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_size",
#           "type": "string",
#           "description": "Column name for point sizes.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_label",
#           "type": "string",
#           "description": "Column name for associated point labels.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_label_weight",
#           "type": "string",
#           "description": "Column name for point label weights.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_x",
#           "type": "string",
#           "description": "Column name for the x-coordinate.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_y",
#           "type": "string",
#           "description": "Column name for the y-coordinate.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "point_include_columns",
#           "type": "array",
#           "description": "An array of additional column names to include in point data.",
#           "group": "Additional Points Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "links",
#           "type": "DataFrame",
#           "description": "Data in a pandas DataFrame format.",
#           "group": "Minimal Configuration for Links",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_source",
#           "type": "string",
#           "description": "Column with the unique identifier for source points.",
#           "group": "Minimal Configuration for Links",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_source_index",
#           "type": "integer",
#           "description": "Index column of the source point, corresponding to point_index.",
#           "group": "Minimal Configuration for Links",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_target",
#           "type": "string",
#           "description": "Column with the unique identifier for target points.",
#           "group": "Minimal Configuration for Links",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_target_index",
#           "type": "integer",
#           "description": "Index column of the target point, corresponding to point_index.",
#           "group": "Minimal Configuration for Links",
#           "optional": false,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_color",
#           "type": "string",
#           "description": "Column name for link colors.",
#           "group": "Additional Links Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_width",
#           "type": "string",
#           "description": "Column name for link widths.",
#           "group": "Additional Links Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_arrow",
#           "type": "string",
#           "description": "Column name that indicates links with arrows.",
#           "group": "Additional Links Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_strength",
#           "type": "string",
#           "description": "Column name for link strengths.",
#           "group": "Additional Links Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "link_include_columns",
#           "type": "array",
#           "description": "An array of additional column names to include in link data.",
#           "group": "Additional Links Configuration",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "disable_simulation",
#           "type": "boolean",
#           "description": "Prevents the simulation from running, merely rendering the graph.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "simulation_decay",
#           "type": "integer",
#           "description": "Defines how quickly the simulation cools down.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "1000"
#         },
#         {
#           "name": "simulation_gravity",
#           "type": "integer",
#           "description": "Coefficient for gravity force.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "0"
#         },
#         {
#           "name": "simulation_center",
#           "type": "integer",
#           "description": "Centers the mass force coefficient.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "0"
#         },
#         {
#           "name": "simulation_repulsion",
#           "type": "number",
#           "description": "Configures point repulsion between points.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "0.1"
#         },
#         {
#           "name": "simulation_repulsion_theta",
#           "type": "number",
#           "description": "Decreases / increases the detalization of the Many-Body force calculations.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "1.7"
#         },
#         {
#           "name": "simulation_link_spring",
#           "type": "number",
#           "description": "Spring constant for links.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "1"
#         },
#         {
#           "name": "simulation_link_distance",
#           "type": "number",
#           "description": "Default distance for links.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "2"
#         },
#         {
#           "name": "simulation_link_dist_random_variation_range",
#           "type": "array",
#           "description": "Random link distance range.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "[1, 1.2]"
#         },
#         {
#           "name": "simulation_repulsion_from_mouse",
#           "type": "number",
#           "description": "Mouse position repulsion coefficient, activated by right-click.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "2"
#         },
#         {
#           "name": "simulation_friction",
#           "type": "number",
#           "description": "Sets simulation friction.",
#           "group": "Simulation Settings",
#           "optional": true,
#           "default": "0.85"
#         },
#         {
#           "name": "use_quadtree",
#           "type": "boolean",
#           "description": "Activates quadtree algorithm for Many-Body force when set to True.",
#           "group": "Quadtree algorithm settings",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "simulation_repulsion_quadtree_levels",
#           "type": "integer",
#           "description": "Barnes\u2013Hut approximation depth, usable when useQuadtree is set to True.",
#           "group": "Quadtree algorithm settings",
#           "optional": true,
#           "default": "12"
#         },
#         {
#           "name": "background_color",
#           "type": "string",
#           "description": "Canvas background color.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "'#222222'"
#         },
#         {
#           "name": "space_size",
#           "type": "integer",
#           "description": "Size of the simulation space.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "4096"
#         },
#         {
#           "name": "default_point_color",
#           "type": "string",
#           "description": "Default point size when point_color not specified.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "'#b3b3b3'"
#         },
#         {
#           "name": "point_greyout_opacity",
#           "type": "number",
#           "description": "Opacity of unselected nodes during selection.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "0.1"
#         },
#         {
#           "name": "default_point_size",
#           "type": "number",
#           "description": "The default size value to use for points when no point_size are provided.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "4"
#         },
#         {
#           "name": "point_size_scale",
#           "type": "number",
#           "description": "Scale factor for point sizes.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "1"
#         },
#         {
#           "name": "hovered_point_cursor",
#           "type": "string",
#           "description": "Cursor type when hovering over a point.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "'auto'"
#         },
#         {
#           "name": "render_hovered_point_ring",
#           "type": "boolean",
#           "description": "Enables ring around hovered points.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "hovered_point_ring_color",
#           "type": "string",
#           "description": "Color of hovered point ring.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "'white'"
#         },
#         {
#           "name": "focused_point_ring_color",
#           "type": "string",
#           "description": "Color of the focused point ring.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "'white'"
#         },
#         {
#           "name": "focused_point_index",
#           "type": "integer",
#           "description": "Index of the focused point, prioritized over focus_point method.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "render_links",
#           "type": "boolean",
#           "description": "Enables or disables link rendering.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "True"
#         },
#         {
#           "name": "default_link_color",
#           "type": "string",
#           "description": "Default link color when link_color not specified.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "'#666666'"
#         },
#         {
#           "name": "link_greyout_opacity",
#           "type": "number",
#           "description": "Opacity of unselected links during selection.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "0.1"
#         },
#         {
#           "name": "default_link_width",
#           "type": "number",
#           "description": "Default link width when link_width not specified.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "1"
#         },
#         {
#           "name": "link_width_scale",
#           "type": "number",
#           "description": "Scale factor for link widths.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "1"
#         },
#         {
#           "name": "curved_links",
#           "type": "boolean",
#           "description": "Enables or disables curved links.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "curved_link_segments",
#           "type": "integer",
#           "description": "Segments defining curved links.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "19"
#         },
#         {
#           "name": "curved_link_weight",
#           "type": "number",
#           "description": "Weight factor for link curvature.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "0.8"
#         },
#         {
#           "name": "curved_link_control_point_distance",
#           "type": "number",
#           "description": "Control point positioning for curves.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "0.5"
#         },
#         {
#           "name": "default_link_arrows",
#           "type": "boolean",
#           "description": "Enables or disables arrows on links when link_arrow not specified.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "link_arrows_size_scale",
#           "type": "number",
#           "description": "Scale factor for link arrow size.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "1"
#         },
#         {
#           "name": "link_visibility_distance_range",
#           "type": "array",
#           "description": "Pixel distance range for link transparency.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "[50, 150]"
#         },
#         {
#           "name": "link_visibility_min_transparency",
#           "type": "number",
#           "description": "Minimum transparency of links based on link_visibility_distance_range.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "0.25"
#         },
#         {
#           "name": "scale_points_on_zoom",
#           "type": "boolean",
#           "description": "Scales point sizes when zooming.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "True"
#         },
#         {
#           "name": "initial_zoom_level",
#           "type": "number",
#           "description": "Starting zoom level.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "disable_zoom",
#           "type": "boolean",
#           "description": "Enables or disables zooming.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "enable_drag",
#           "type": "boolean",
#           "description": "Allows graph dragging.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "fit_view_on_init",
#           "type": "boolean",
#           "description": "Automatically fits view to all points upon initialization.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "True"
#         },
#         {
#           "name": "fit_view_delay",
#           "type": "integer",
#           "description": "Delay for fitting view after initialization in milliseconds.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "250"
#         },
#         {
#           "name": "fit_view_padding",
#           "type": "number",
#           "description": "Padding around fit view area.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "0.1"
#         },
#         {
#           "name": "fit_view_duration",
#           "type": "integer",
#           "description": "Animation duration for view fitting in milliseconds.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "250"
#         },
#         {
#           "name": "fit_view_by_points_in_rect",
#           "type": "string",
#           "description": "Fits view to specified rectangle of points, active when fit_view_on_init is True.",
#           "group": "Graph Appearance",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "show_dynamic_labels",
#           "type": "boolean",
#           "description": "Flag to show dynamic labels for visible points.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "show_labels_for",
#           "type": "array",
#           "description": "An array of point ids for which to show labels.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "show_top_labels",
#           "type": "boolean",
#           "description": "Flag to display labels for the top points.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "show_top_labels_limit",
#           "type": "integer",
#           "description": "Maximum number of top points to show labels for.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "100"
#         },
#         {
#           "name": "show_top_labels_by",
#           "type": "string",
#           "description": "Column to determine which points are considered as a top.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "static_label_weight",
#           "type": "number",
#           "description": "Weight of static labels.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "0.8"
#         },
#         {
#           "name": "dynamic_label_weight",
#           "type": "number",
#           "description": "Weight of dynamic labels.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "0.7"
#         },
#         {
#           "name": "label_padding",
#           "type": "number",
#           "description": "Padding around labels in the graph.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "NO_DEFAULT"
#         },
#         {
#           "name": "show_hovered_point_label",
#           "type": "boolean",
#           "description": "Flag to display the label for the currently hovered point.",
#           "group": "Label Options",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "show_FPS_monitor",
#           "type": "boolean",
#           "description": "Display an FPS counter in the upper right corner of the canvas.",
#           "group": "Additional Parameters",
#           "optional": true,
#           "default": "False"
#         },
#         {
#           "name": "pixel_ratio",
#           "type": "number",
#           "description": "Canvas pixel ratio.",
#           "group": "Additional Parameters",
#           "optional": true,
#           "default": "2"
#         },
#         {
#           "name": "random_seed",
#           "type": "string",
#           "description": "Seed value for generating random numbers in simulations.",
#           "group": "Additional Parameters",
#           "optional": true,
#           "default": "None"
#         },
#         {
#           "name": "point_sampling_distance",
#           "type": "number",
#           "description": "Distance threshold for sampling points.",
#           "group": "Additional Parameters",
#           "optional": true,
#           "default": "150"
#         }
#       ]
#     }
#   ]
# }

# %%
{
    'interfaces': [
        {
            'name': 'SimulationConfig',
            'description': 'Configuration options for the simulation settings.',
            'properties': [
                {
                    'name': 'simulationDecay',
                    'type': "GraphSimulationSettings['decay']",
                    'description': "Decay coefficient. Use bigger values if you want the simulation to 'cool down' slower. Default value: `1000`",
                    'optional': True,
                },
                {
                    'name': 'simulationGravity',
                    'type': "GraphSimulationSettings['gravity']",
                    'description': 'Gravity force coefficient. Default value: `0`',
                    'optional': True,
                },
                {
                    'name': 'simulationCenter',
                    'type': "GraphSimulationSettings['center']",
                    'description': 'Centering to center mass force coefficient. Default value: `0`',
                    'optional': True,
                },
                {
                    'name': 'simulationRepulsion',
                    'type': "GraphSimulationSettings['repulsion']",
                    'description': 'Repulsion force coefficient. Default value: `0.1`',
                    'optional': True,
                },
                {
                    'name': 'simulationRepulsionTheta',
                    'type': "GraphSimulationSettings['repulsionTheta']",
                    'description': 'Decreases / increases the detalization of the Many-Body force calculations. When `useQuadtree` is set to `true`, this property corresponds to the Barnes–Hut approximation criterion. Default value: `1.7`',
                    'optional': True,
                },
                {
                    'name': 'simulationRepulsionQuadtreeLevels',
                    'type': "GraphSimulationSettings['repulsionQuadtreeLevels']",
                    'description': 'Barnes–Hut approximation depth. Can only be used when `useQuadtree` is set `true`. Default value: `12`',
                    'optional': True,
                },
                {
                    'name': 'simulationLinkSpring',
                    'type': "GraphSimulationSettings['linkSpring']",
                    'description': 'Link spring force coefficient. Default value: `1`',
                    'optional': True,
                },
                {
                    'name': 'simulationLinkDistance',
                    'type': "GraphSimulationSettings['linkDistance']",
                    'description': 'Minimum link distance. Default value: `2`',
                    'optional': True,
                },
                {
                    'name': 'simulationLinkDistRandomVariationRange',
                    'type': "GraphSimulationSettings['linkDistRandomVariationRange']",
                    'description': 'Range of random link distance values. Default value: `[1, 1.2]`',
                    'optional': True,
                },
                {
                    'name': 'simulationRepulsionFromMouse',
                    'type': "GraphSimulationSettings['repulsionFromMouse']",
                    'description': 'Repulsion coefficient from mouse position. The repulsion force is activated by pressing the right mouse button. Default value: `2`',
                    'optional': True,
                },
                {
                    'name': 'simulationFriction',
                    'type': "GraphSimulationSettings['friction']",
                    'description': 'Friction coefficient. Default value: `0.85`',
                    'optional': True,
                },
            ],
        },
        {
            'name': 'SimulationEventConfig',
            'description': 'Configuration options for simulation event callbacks.',
            'properties': [
                {
                    'name': 'onSimulationStart',
                    'type': "GraphSimulationSettings['onStart']",
                    'description': 'Callback function that will be called when the simulation starts.',
                    'optional': True,
                },
                {
                    'name': 'onSimulationEnd',
                    'type': "GraphSimulationSettings['onEnd']",
                    'description': 'Callback function that will be called when the simulation stops.',
                    'optional': True,
                },
                {
                    'name': 'onSimulationPause',
                    'type': "GraphSimulationSettings['onPause']",
                    'description': 'Callback function that will be called when the simulation is paused.',
                    'optional': True,
                },
                {
                    'name': 'onSimulationRestart',
                    'type': "GraphSimulationSettings['onRestart']",
                    'description': 'Callback function that will be called when the simulation is restarted.',
                    'optional': True,
                },
                {
                    'name': 'onSimulationTick',
                    'type': "GraphSimulationSettings['onTick']",
                    'description': 'Callback function that will be called on every tick of the simulation.',
                    'optional': True,
                },
            ],
        },
    ]
}
# Out:
# {'args': ('\n    You are a typescript parser.\n    Parse through the following typescript file(s) contents and extract information \n    about the objects in them, returning a json that fits the json_schema.\n\n    {ts_code}\n    ',),
#  'kwargs': {}}

# %%
{'simpleProp': {'name': 'simpleProp', 'optional': False, 'type': ': string', 'kind': 'property'}, 'optionalProp': {'name': 'optionalProp', 'optional': False, 'type': ': number', 'kind': 'property'}, 'functionTypeProp': {'name': 'functionTypeProp', 'optional': False, 'type': ': (x: T) => boolean', 'kind': 'function', 'parameters': [{'type': ': T', 'optional': False, 'rest': False}]}, 'arrayProp': {'name': 'arrayProp', 'optional': False, 'type': ': number[]', 'kind': 'property'}, 'unionProp': {'name': 'unionProp', 'optional': False, 'type': ': string | number', 'kind': 'property'}, 'nested': {'name': 'nested', 'optional': False, 'type': ': {\n            nestedProp: T;\n            nestedFunction(): void;\n        }', 'kind': 'property'}}
# Out:
# {'simpleProp': {'name': 'simpleProp',
#   'optional': False,
#   'type': ': string',
#   'kind': 'property'},
#  'optionalProp': {'name': 'optionalProp',
#   'optional': False,
#   'type': ': number',
#   'kind': 'property'},
#  'functionTypeProp': {'name': 'functionTypeProp',
#   'optional': False,
#   'type': ': (x: T) => boolean',
#   'kind': 'function',
#   'parameters': [{'type': ': T', 'optional': False, 'rest': False}]},
#  'arrayProp': {'name': 'arrayProp',
#   'optional': False,
#   'type': ': number[]',
#   'kind': 'property'},
#  'unionProp': {'name': 'unionProp',
#   'optional': False,
#   'type': ': string | number',
#   'kind': 'property'},
#  'nested': {'name': 'nested',
#   'optional': False,
#   'type': ': {\n            nestedProp: T;\n            nestedFunction(): void;\n        }',
#   'kind': 'property'}}

# %%
import cosmograph

cosmograph

import jy

jy.func_name_and_params_pairs
# Out:
# <function jy.js_parse.func_name_and_params_pairs(js_code: str, *, encoding=None)>

# %% [markdown]
# # Technique demos

# %%
from i2 import Sig

@Sig('(' + ','.join(['foo', 'bar', 'baz']) + ')')
def foo(*args, **kwargs):
    print(args, kwargs)

Sig(foo)

help(foo)
# Out:
# Help on function foo in module __main__:
#
# foo(foo, bar, baz)

# %% [markdown]
# # Parsing the interface out of TS files

# %% [markdown]
# ## Five files

# %%
from operator import attrgetter, itemgetter  # builtin

# need to pip install
import requests
from dol import Pipe 
from jy.ts_parse import parse_ts_with_oa

from cosmograph.wip.config_properties import my_ts_parser

# %%
import os 
from pathlib import Path
from functools import partial

from lkj import unique_affixes


unique_relative_paths = partial(
    unique_affixes,
    suffix=True,
    ingress=lambda p: Path(p).parts,
    egress=os.path.sep.join,
)

# CHANGE THIS TO THE DIRECTORY WHERE cosmograph IS LOCATED
cosmograph_rootdir = '/Users/thorwhalen/Dropbox/py/proj/c/cosmograph'

config_ts_subdir = 'packages/cosmograph/src/modules/cosmograph/config'
config_ts_dir = os.path.join(cosmograph_rootdir, config_ts_subdir)

# list full paths of dir
ts_paths = list(map(str, Path(config_ts_dir).iterdir()))

ts_paths = dict(zip(unique_relative_paths(ts_paths), ts_paths))

ts_paths['cosmos/config.ts'] = '/Users/thorwhalen/Dropbox/py/proj/c/cosmos/src/config.ts'

ts_paths

# _json_schemas = dict(zip(ts_paths, map(Pipe(lambda fp: Path(fp).read_text(), my_ts_parser), ts_paths.values())))
# list(_json_schemas)
## ['data.ts', 'config.ts', 'labels.ts', 'simulation.ts', 'cosmos/config.ts']
# Out:
# {'data.ts': '/Users/thorwhalen/Dropbox/py/proj/c/cosmograph/packages/cosmograph/src/modules/cosmograph/config/data.ts',
#  'config.ts': '/Users/thorwhalen/Dropbox/py/proj/c/cosmograph/packages/cosmograph/src/modules/cosmograph/config/config.ts',
#  'labels.ts': '/Users/thorwhalen/Dropbox/py/proj/c/cosmograph/packages/cosmograph/src/modules/cosmograph/config/labels.ts',
#  'simulation.ts': '/Users/thorwhalen/Dropbox/py/proj/c/cosmograph/packages/cosmograph/src/modules/cosmograph/config/simulation.ts',
#  'cosmos/config.ts': '/Users/thorwhalen/Dropbox/py/proj/c/cosmos/src/config.ts'}

# %%
# import json

# json.dump(_json_schemas, open('ts_json_schemas.json', 'w'), indent=2)

# %% [markdown]
# ## Nikita's config

# %%
from cosmograph.wip.config_properties import my_ts_parser
from graze import graze

nikitas_belief_url = 'https://raw.githubusercontent.com/cosmograph-org/cosmograph/92bf38fc0674643dcc91246d4352441219a701b0/packages/cosmograph/src/cosmograph/config/config.ts?token=GHSAT0AAAAAACSGWAOWPAK7V3BRRLXVFJ5CZ2IGIKA'

ts_code = graze(nikitas_belief_url).decode()
nikita_json_schema = my_ts_parser(ts_code)
list(nikita_json_schema)
# Out:
# ['interfaces']

# %%
t = nikita_json_schema['interfaces']
print(f"{len(t)} interfaces")
print(f"{[x['name'] for x in t]=}\n")
print("First two:")
list(t)[:1]
# Out:
# 3 interfaces
# [x['name'] for x in t]=['BasicConfig', 'CallbackConfig', 'CosmographConfig']
#
# First two:
# [{'name': 'BasicConfig',
#   'description': 'Contains basic configuration options for the cosmograph.',
#   'properties': [{'name': 'disableSimulation',
#     'type': 'boolean | null',
#     'description': 'Do not run the simulation, just render the graph. Defaults to true if null and no links are present in the data.',
#     'optional': True,
#     'default': 'null'},
#    {'name': 'rectangularSelectorClassName',
#     'type': 'string',
#     'description': 'Specifies the CSS class to use for the rectangular selector.',
#     'optional': True}]}]

# %%
def edit_nikita_config(nikita_config):
    from functools import partial
    from lkj import get_by_value

    get_by_name = partial(get_by_value, field='name')

    # add the {"left": 7, "top": 4, "right": 7, "bottom": 4} default to labelPadding
    d = get_by_name(nikita_config['interfaces'], 'CosmographConfig')
    d = get_by_name(d['properties'], 'labelPadding')
    d['default'] = {"left": 7, "top": 4, "right": 7, "bottom": 4}

    return nikita_config

nikita_json_schema = edit_nikita_config(nikita_json_schema)

# %%
# from cosmograph.util import data_files
# import json 

# data_files['nikita_config.json'] = json.dumps(nikita_json_schema).encode()

# %%
from cosmograph.util import data_files
import json 
from cosmograph.wip.config_properties import print_interfaces

nikita_config = json.loads(data_files['nikita_config.json'])
print(f"{[x['name'] for x in nikita_config['interfaces']]=}\n")
# Out:
# [x['name'] for x in nikita_config['interfaces']]=['BasicConfig', 'CallbackConfig', 'CosmographConfig']

# %%
from cosmograph.wip.config_properties import print_interfaces

print_interfaces(nikita_config['interfaces'], 'nikita_config')
# Out:
# * **nikita_config**
#     * **BasicConfig**: (2)
#         disableSimulation, rectangularSelectorClassName
#     * **CallbackConfig**: (5)
#         onPointsFiltered, onLinksFiltered, onLabelClick, onDataUpdated, onAreaSelected
#     * **CosmographConfig**: (7)
#         disableSimulation, showTopLabelsLimit, showHoveredPointLabel, staticLabelWeight, dynamicLabelWeight,
#         labelMargin, labelPadding

# %%
from cosmograph.wip.config_properties import process_schema_object, json_schema_to_dataframe, dataframes_to_markdown

def config_edits(config):
    t = config['interfaces']['CosmographConfig'] = process_schema_object(config['interfaces'])
    return config


t = dataframes_to_markdown(
    json_schema_to_dataframe(nikita_config),
    # columns=['name', 'description', 'default', 'type'],
)
print(''.join(t))
# Out:
# ## interfaces
#
# ### BasicConfig
#
# | name                         | type           | description                                                                                                      | optional   | default   |
# |:-----------------------------|:---------------|:-----------------------------------------------------------------------------------------------------------------|:-----------|:----------|
# | disableSimulation            | boolean | null | Do not run the simulation, just render the graph. Defaults to true if null and no links are present in the data. | True       | null      |
# | rectangularSelectorClassName | string         | Specifies the CSS class to use for the rectangular selector.                                                     | True       | nan       |
#
#
# ### CallbackConfig
#
# | name             | type                                                                                                                                                                                                | description                                                                 | optional   |
# |:-----------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------------------------------------------------------------------------|:-----------|
# | onPointsFiltered | (filteredPoints: CosmographData) => void                                                                                                                                                            | Callback function triggered when points are filtered by point crossfilter.  | True       |
# | onLinksFiltered  | (filteredLinks: CosmographData) => void                                                                                                                                                             | Callback function triggered when links are filtered by link crossfilter.    | True       |
# | onLabelClick     | (index: number, id: string, event: MouseEvent) => void                                                                                                                                              | Callback function triggered when a label is clicked.                        | True       |
# | onDataUpdated    | ({pointsCount, linksCount, pointsSummary, linksSummary}: { pointsCount: number; linksCount: number; pointsSummary?: Record<string, unknown>[]; linksSummary?: Record<string, unknown>[]; }) => void | Callback function executed after the graph renders with new data.           | True       |
# | onAreaSelected   | ([[number, number], [number, number]] | null) => void                                                                                                                                               | Callback function triggered when an area selection is performed or cleared. | True       |
#
#
# ### CosmographConfig
#
# | name                  | type           | description                                                                                     | optional   | default                                        | properties                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# |:----------------------|:---------------|:------------------------------------------------------------------------------------------------|:-----------|:-----------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | disableSimulation     | boolean | null | Do not run the simulation, just render the graph. Uses x and y values for position unless null. | True       | null                                           | nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | showTopLabelsLimit    | number         | Limit for the number of top labels to show.                                                     | False      | 100                                            | nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | showHoveredPointLabel | boolean        | Flag to show a label for the hovered point.                                                     | False      | false                                          | nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | staticLabelWeight     | number         | Weight for static label.                                                                        | False      | 0.8                                            | nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | dynamicLabelWeight    | number         | Weight for dynamic label.                                                                       | False      | 0.7                                            | nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | labelMargin           | number         | Margin for labels.                                                                              | False      | 5                                              | nan                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | labelPadding          | object         | Padding for labels in pixels, specified per side.                                               | False      | {'left': 7, 'top': 4, 'right': 7, 'bottom': 4} | [{'name': 'left', 'type': 'number', 'description': 'Padding on the left side.', 'optional': False, 'default': '7'}, {'name': 'top', 'type': 'number', 'description': 'Padding on the top side.', 'optional': False, 'default': '4'}, {'name': 'right', 'type': 'number', 'description': 'Padding on the right side.', 'optional': False, 'default': '7'}, {'name': 'bottom', 'type': 'number', 'description': 'Padding on the bottom side.', 'optional': False, 'default': '4'}] |

# %% [markdown]
# ## Study the json_schema a bit

# %%
import json

_json_schemas = json.load(open('ts_json_schemas.json', 'r'))
list(_json_schemas)
# Out:
# ['data.ts', 'config.ts', 'labels.ts', 'simulation.ts', 'cosmos/config.ts']

# %%
if all(map(lambda x: list(x) == ['interfaces'], _json_schemas.values())):
    print('all json_schemas have interface and only interface, so removing that field')
    json_schemas = {k: v['interfaces'] for k, v in _json_schemas.items()}
# Out:
# all json_schemas have interface and only interface, so removing that field

# %%
# Make a markdown list for the schema properties
from cosmograph.wip.config_properties import print_interfaces

for k, v in json_schemas.items():    
    print_interfaces(v, k)
# Out:
# * **data.ts**
#     * **CosmographPointsConfig**: (12)
#         Points, PointId, PointIndex, PointColor, PointColorFn, PointSize, PointSizeFn, PointLabel,
#         PointLabelWeight, PointX, PointY, PointIncludeColumns
#     * **CosmographLinksConfig**: (14)
#         Links, LinkSource, LinkSourceIndex, LinkTarget, LinkTargetIndex, LinkColor, LinkColorFn, LinkWidth,
#         LinkWidthFn, LinkArrow, LinkArrowFn, LinkStrength, LinkStrengthFn, LinkIncludeColumns
# * **config.ts**
#     * **BasicConfig**: (2)
#         disableSimulation, rectangularSelectorClassName
#     * **CallbackConfig**: (5)
#         onPointsFiltered, onLinksFiltered, onLabelClick, onDataUpdated, onAreaSelected
#     * **CosmographConfig**: (7)
#         disableSimulation, showTopLabelsLimit, showHoveredPointLabel, staticLabelWeight, dynamicLabelWeight,
#         labelMargin, labelPadding
# * **labels.ts**
#     * **LabelsCosmographConfig**: (15)
#         showDynamicLabels, showLabelsFor, showTopLabels, showTopLabelsLimit, showTopLabelsBy, pointLabelFn,
#         pointLabelWeightFn, pointLabelClassName, staticLabelWeight, dynamicLabelWeight, labelMargin,
#         labelPadding, customLabels, showHoveredPointLabel, hoveredPointLabelClassName
# * **simulation.ts**
#     * **SimulationConfig**: (12)
#         simulationDecay, simulationGravity, simulationCenter, simulationRepulsion, simulationRepulsionTheta,
#         simulationRepulsionQuadtreeLevels, simulationLinkSpring, simulationLinkDistance,
#         simulationLinkDistRandomVariationRange, simulationRepulsionFromMouse, simulationFriction,
#         simulationImpulse
#     * **SimulationEventConfig**: (5)
#         onSimulationStart, onSimulationEnd, onSimulationPause, onSimulationRestart, onSimulationTick
# * **cosmos/config.ts**
#     * **GraphEvents**: (10)
#         onClick, onMouseMove, onPointMouseOver, onPointMouseOut, onZoomStart, onZoom, onZoomEnd,
#         onDragStart, onDrag, onDragEnd
#     * **GraphSimulationSettings**: (16)
#         decay, gravity, center, repulsion, repulsionTheta, repulsionQuadtreeLevels, linkSpring,
#         linkDistance, linkDistRandomVariationRange, repulsionFromMouse, friction, onStart, onTick,
#         onEnd, onPause, onRestart
#     * **GraphConfigInterface**: (41)
#         disableSimulation, backgroundColor, spaceSize, defaultPointColor, pointGreyoutOpacity,
#         defaultPointSize, pointSizeScale, hoveredPointCursor, renderHoveredPointRing,
#         hoveredPointRingColor, focusedPointRingColor, focusedPointIndex, renderLinks,
#         defaultLinkColor, linkGreyoutOpacity, defaultLinkWidth, linkWidthScale, curvedLinks,
#         curvedLinkSegments, curvedLinkWeight, curvedLinkControlPointDistance, defaultLinkArrows,
#         linkArrowsSizeScale, linkVisibilityDistanceRange, linkVisibilityMinTransparency,
#         useQuadtree, simulation, events, showFPSMonitor, pixelRatio, scalePointsOnZoom,
#         initialZoomLevel, disableZoom, enableDrag, fitViewOnInit, fitViewDelay, fitViewPadding,
#         fitViewDuration, fitViewByPointsInRect, randomSeed, pointSamplingDistance

# %%
from i2 import postprocess

@postprocess(dict)
def _property_groups():
    for k, v in json_schemas.items():
        for interface in v:
            yield interface['name'], interface['properties']

property_groups = _property_groups()


property_groups = _property_groups()
list(property_groups)
# Out:
# ['CosmographPointsConfig',
#  'CosmographLinksConfig',
#  'BasicConfig',
#  'CallbackConfig',
#  'CosmographConfig',
#  'LabelsCosmographConfig',
#  'SimulationConfig',
#  'SimulationEventConfig',
#  'GraphEvents',
#  'GraphSimulationSettings',
#  'GraphConfigInterface']

# %%
# Make a rjsf form for the schema properties
# copy the output here and go to https://rjsf-team.github.io/react-jsonschema-form/
# replacing the "properties" field with the output of this cell

def list_of_dicts_to_dict(d: dict, key_name: str) -> dict:
    return {x[key_name]: {k: x[k] for k in x if k != 'name'} for x in d}

def filter_in_types(d: dict, allowed_types: list) -> dict:
    """Keep only the allowed_types"""
    return {k: v for k, v in d.items() if v['type'] in allowed_types}

t = list_of_dicts_to_dict(property_groups['GraphConfigInterface'], key_name='name')
t = filter_in_types(t, ['string', 'number', 'boolean'])
import json

print(json.dumps(t, indent=2))
# Out:
# {
#   "disableSimulation": {
#     "type": "boolean",
#     "description": "Disable simulation and render graph using predefined point positions. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "spaceSize": {
#     "type": "number",
#     "description": "Simulation space size with a max of 8192. Default is 4096.",
#     "optional": true,
#     "default": 4096
#   },
#   "pointGreyoutOpacity": {
#     "type": "number",
#     "description": "Opacity of points when greyed-out during selection. Default is 0.1.",
#     "optional": true,
#     "default": 0.1
#   },
#   "defaultPointSize": {
#     "type": "number",
#     "description": "Default size for points when unspecified. Default size is 4.",
#     "optional": true,
#     "default": 4
#   },
#   "pointSizeScale": {
#     "type": "number",
#     "description": "Scale factor for point size. Default is 1.",
#     "optional": true,
#     "default": 1
#   },
#   "hoveredPointCursor": {
#     "type": "string",
#     "description": "Cursor style when hovering over a point. Default is 'auto'.",
#     "optional": true,
#     "default": "auto"
#   },
#   "renderHoveredPointRing": {
#     "type": "boolean",
#     "description": "Toggle rendering of ring around hovered point. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "focusedPointIndex": {
#     "type": "number",
#     "description": "Index of the focused point; overrides other methods. Default is undefined.",
#     "optional": true
#   },
#   "renderLinks": {
#     "type": "boolean",
#     "description": "Toggle the rendering of links between points. Default is true.",
#     "optional": true,
#     "default": true
#   },
#   "linkGreyoutOpacity": {
#     "type": "number",
#     "description": "Opacity of links when greyed-out during selection. Default is 0.1.",
#     "optional": true,
#     "default": 0.1
#   },
#   "defaultLinkWidth": {
#     "type": "number",
#     "description": "Default width for links when unspecified. Default is 1.",
#     "optional": true,
#     "default": 1
#   },
#   "linkWidthScale": {
#     "type": "number",
#     "description": "Scale factor for link width. Default is 1.",
#     "optional": true,
#     "default": 1
#   },
#   "curvedLinks": {
#     "type": "boolean",
#     "description": "Render links as curved lines if true, otherwise straight. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "curvedLinkSegments": {
#     "type": "number",
#     "description": "Number of segments in a curved line. Default is 19.",
#     "optional": true,
#     "default": 19
#   },
#   "curvedLinkWeight": {
#     "type": "number",
#     "description": "Weight affects curve shaping. Default is 0.8.",
#     "optional": true,
#     "default": 0.8
#   },
#   "curvedLinkControlPointDistance": {
#     "type": "number",
#     "description": "Distance for curve control points. Default is 0.5.",
#     "optional": true,
#     "default": 0.5
#   },
#   "defaultLinkArrows": {
#     "type": "boolean",
#     "description": "Indicator for displaying link arrows. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "linkArrowsSizeScale": {
#     "type": "number",
#     "description": "Scale for link arrow size. Default is 1.",
#     "optional": true,
#     "default": 1
#   },
#   "linkVisibilityMinTransparency": {
#     "type": "number",
#     "description": "Transparency of links at max distance. Default is 0.25.",
#     "optional": true,
#     "default": 0.25
#   },
#   "useQuadtree": {
#     "type": "boolean",
#     "description": "Use classic quadtree algorithm when true. Default value false.",
#     "optional": true,
#     "default": false
#   },
#   "showFPSMonitor": {
#     "type": "boolean",
#     "description": "Toggle the display of WebGL performance monitor. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "pixelRatio": {
#     "type": "number",
#     "description": "Ratio related to canvas pixel density. Default is 2.",
#     "optional": true,
#     "default": 2
#   },
#   "scalePointsOnZoom": {
#     "type": "boolean",
#     "description": "Adjust point size on zoom if true. Default is true.",
#     "optional": true,
#     "default": true
#   },
#   "initialZoomLevel": {
#     "type": "number",
#     "description": "Set the initial zoom level of graph. Default is undefined.",
#     "optional": true
#   },
#   "disableZoom": {
#     "type": "boolean",
#     "description": "Disable zoom functionality in graph. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "enableDrag": {
#     "type": "boolean",
#     "description": "Enable point dragging within the graph. Default is false.",
#     "optional": true,
#     "default": false
#   },
#   "fitViewOnInit": {
#     "type": "boolean",
#     "description": "Fit view to show all points at startup. Default is true.",
#     "optional": true,
#     "default": true
#   },
#   "fitViewDelay": {
#     "type": "number",
#     "description": "Delay in ms before fitting view. Default is 250.",
#     "optional": true,
#     "default": 250
#   },
#   "fitViewPadding": {
#     "type": "number",
#     "description": "Padding applied when fitting the view. Default is 0.1.",
#     "optional": true,
#     "default": 0.1
#   },
#   "fitViewDuration": {
#     "type": "number",
#     "description": "Duration for fitting the view in ms. Default is 250.",
#     "optional": true,
#     "default": 250
#   },
#   "pointSamplingDistance": {
#     "type": "number",
#     "description": "Pixel distance for point sampling. Default is 150.",
#     "optional": true,
#     "default": 150
#   }
# }

# %%
# to more:
import ju.rjsf
# Out:
# <module 'ju.rjsf' from '/Users/thorwhalen/Dropbox/py/proj/i/ju/ju/rjsf.py'>

# %%
# from pprint import pprint

# pprint(property_groups)

# %%
from cosmograph.wip.config_properties import process_schema_object, json_schema_to_dataframe, dataframes_to_markdown

t = ''.join(dataframes_to_markdown(
    json_schema_to_dataframe(json_schemas),
    columns=['name', 'description', 'default', 'type'],
))
print(t)
# Out:
# ## data.ts
#
# ### CosmographPointsConfig
#
# | name                | description                                                                                                                       | type                                                  |
# |:--------------------|:----------------------------------------------------------------------------------------------------------------------------------|:------------------------------------------------------|
# | Points              | Input data for the points. Accepts `File | string | Table | Uint8Array | ArrayBuffer | Record<string, unknown>[]`                 | CosmographInputData                                   |
# | PointId             | Unique identifier column for each point. Required for mapping links to points correctly.                                          | string                                                |
# | PointIndex          | Numeric index column for each point. Used for efficient lookups and should be a sequential integer starting from 0.               | string                                                |
# | PointColor          | The column name for the point color. Points will be colored based on the values in this column.                                   | string                                                |
# | PointColorFn        | Function to generate the color for each point based on the value in the `pointColor` column.                                      | AccessorFn<string | [number, number, number, number]> |
# | PointSize           | The column name for the point size. Points will be sized based on the values in this column.                                      | string                                                |
# | PointSizeFn         | Function to generate the size for each point based on the value in the `pointSize` column.                                        | AccessorFn<number>                                    |
# | PointLabel          | The column name for the point label.                                                                                              | string                                                |
# | PointLabelWeight    | The column name for the point label weight. Accepts float values from 0 to 1. Higher weights make labels more likely to be shown. | string                                                |
# | PointX              | The column name for the point's x-coordinate. Used along with `pointY` to position points.                                        | string                                                |
# | PointY              | The column name for the point's y-coordinate. Used along with `pointX` to position points.                                        | string                                                |
# | PointIncludeColumns | Additional column names to include in the point data. Useful for storing extra information about the points.                      | string[]                                              |
#
#
# ### CosmographLinksConfig
#
# | name               | description                                                                                                      | type                                                  |
# |:-------------------|:-----------------------------------------------------------------------------------------------------------------|:------------------------------------------------------|
# | Links              | Input data for the links. Accepts `File | string | Table | Uint8Array | ArrayBuffer | Record<string, unknown>[]` | CosmographInputData                                   |
# | LinkSource         | The column name for the source point of each link.                                                               | string                                                |
# | LinkSourceIndex    | The column name for the index of the source point. Used for efficient lookups.                                   | string                                                |
# | LinkTarget         | The column name for the target point of each link.                                                               | string                                                |
# | LinkTargetIndex    | The column name for the index of the target point. Used for efficient lookups.                                   | string                                                |
# | LinkColor          | The column name for link color, colors links based on the values in this column.                                 | string                                                |
# | LinkColorFn        | Function to generate the color for each link based on the value in the `linkColor` column.                       | AccessorFn<string | [number, number, number, number]> |
# | LinkWidth          | The column name for the link width. Sets link widths based on column values.                                     | string                                                |
# | LinkWidthFn        | Function to generate the width for each link based on the `linkWidth` column.                                    | AccessorFn<number>                                    |
# | LinkArrow          | The column for determining arrow presence in links. Uses boolean values to set.                                  | string                                                |
# | LinkArrowFn        | Function to determine arrow presence based on the `linkArrow` column.                                            | AccessorFn<boolean>                                   |
# | LinkStrength       | The column name for the link strength, sets link strength values utilized in force simulation.                   | string                                                |
# | LinkStrengthFn     | Function to generate link strength values based on the `linkStrength` column.                                    | AccessorFn<number>                                    |
# | LinkIncludeColumns | Additional column names to include in the link data. Useful for storing extra information about the links.       | string[]                                              |
#
#
# ## config.ts
#
# ### BasicConfig
#
# | name                         | description                                                  | default   | type           |
# |:-----------------------------|:-------------------------------------------------------------|:----------|:---------------|
# | disableSimulation            | Do not run the simulation, just render the graph.            | null      | boolean | null |
# | rectangularSelectorClassName | Specifies the CSS class to use for the rectangular selector. | nan       | string         |
#
#
# ### CallbackConfig
#
# | name             | description                                                                               | type                                                                               |
# |:-----------------|:------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------|
# | onPointsFiltered | Callback function that will be called when the points were filtered by point crossfilter. | (filteredPoints: CosmographData) => void                                           |
# | onLinksFiltered  | Callback function that will be called when the links were filtered by link crossfilter.   | (filteredLinks: CosmographData) => void                                            |
# | onLabelClick     | Callback function that will be called when clicked on a label.                            | (index: number, id: string, event: MouseEvent) => void                             |
# | onDataUpdated    | Callback function that will be called when the graph is created.                          | ({ pointsCount, linksCount }: { pointsCount: number; linksCount: number }) => void |
# | onAreaSelected   | Callback function that will be called when area selection was performed.                  | ([[number, number], [number, number]] | null) => void                              |
#
#
# ### CosmographConfig
#
# | name                  | description                                       | default                                  | type                                                         |
# |:----------------------|:--------------------------------------------------|:-----------------------------------------|:-------------------------------------------------------------|
# | disableSimulation     | Do not run the simulation, just render the graph. | null                                     | boolean | null                                               |
# | showTopLabelsLimit    |                                                   | 100                                      | number                                                       |
# | showHoveredPointLabel |                                                   | false                                    | boolean                                                      |
# | staticLabelWeight     |                                                   | 0.8                                      | number                                                       |
# | dynamicLabelWeight    |                                                   | 0.7                                      | number                                                       |
# | labelMargin           |                                                   | 5                                        | number                                                       |
# | labelPadding          |                                                   | { left: 7, top: 4, right: 7, bottom: 4 } | { left: number; top: number; right: number; bottom: number } |
#
#
# ## labels.ts
#
# ### LabelsCosmographConfig
#
# | name                       | description                                                             | default                                  | type                                                                      |
# |:---------------------------|:------------------------------------------------------------------------|:-----------------------------------------|:--------------------------------------------------------------------------|
# | showDynamicLabels          | Display labels that dynamically update based on the current view.       | False                                    | boolean                                                                   |
# | showLabelsFor              | Array of point IDs for which labels need to be displayed.               | undefined                                | string[]                                                                  |
# | showTopLabels              | Display labels for the top-ranking points.                              | False                                    | boolean                                                                   |
# | showTopLabelsLimit         | Maximum number of top points to show labels for.                        | 100                                      | number                                                                    |
# | showTopLabelsBy            | Column used to sort and display top points for labels.                  | undefined                                | string                                                                    |
# | pointLabelFn               | Function to generate labels from a given pointLabel column.             | nan                                      | AccessorFn<string>                                                        |
# | pointLabelWeightFn         | Function to determine label weight using pointLabelWeight column.       | nan                                      | AccessorFn<number>                                                        |
# | pointLabelClassName        | CSS class for point labels, either fixed or function-generated.         | nan                                      | string | ((text: string, pointIndex: number, pointId?: string) => string) |
# | staticLabelWeight          | Weight for static labels.                                               | 0.8                                      | number                                                                    |
# | dynamicLabelWeight         | Weight for dynamic labels.                                              | 0.7                                      | number                                                                    |
# | labelMargin                | Margin between label and its associated point.                          | 5                                        | number                                                                    |
# | labelPadding               | Padding around the label element.                                       | { left: 7, top: 4, right: 7, bottom: 4 } | {top: number; left: number; right: number; bottom: number}                |
# | customLabels               | Array of custom Cosmograph labels to display.                           | nan                                      | CosmographCustomLabel[]                                                   |
# | showHoveredPointLabel      | Display label for hovered point.                                        | False                                    | boolean                                                                   |
# | hoveredPointLabelClassName | CSS class for hovered point labels, either fixed or function-generated. | nan                                      | string | ((text: string, pointIndex: number, pointId?: string) => string) |
#
#
# ## simulation.ts
#
# ### SimulationConfig
#
# | name                                   | description                                                                                                                                                                                                                                                                          | default   | type                                                    |
# |:---------------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:----------|:--------------------------------------------------------|
# | simulationDecay                        | Decay coefficient. Use bigger values if you want the simulation to "cool down" slower.                                                                                                                                                                                               | 1000      | GraphSimulationSettings['decay']                        |
# | simulationGravity                      | Gravity force coefficient.                                                                                                                                                                                                                                                           | 0         | GraphSimulationSettings['gravity']                      |
# | simulationCenter                       | Centering to center mass force coefficient.                                                                                                                                                                                                                                          | 0         | GraphSimulationSettings['center']                       |
# | simulationRepulsion                    | Repulsion force coefficient.                                                                                                                                                                                                                                                         | 0.1       | GraphSimulationSettings['repulsion']                    |
# | simulationRepulsionTheta               | Decreases / increases the detalization of the Many-Body force calculations. When `useQuadtree` is set to `true`, this property corresponds to the Barnes–Hut approximation criterion.                                                                                                | 1.7       | GraphSimulationSettings['repulsionTheta']               |
# | simulationRepulsionQuadtreeLevels      | Barnes–Hut approximation depth. Can only be used when `useQuadtree` is set `true`.                                                                                                                                                                                                   | 12        | GraphSimulationSettings['repulsionQuadtreeLevels']      |
# | simulationLinkSpring                   | Link spring force coefficient.                                                                                                                                                                                                                                                       | 1         | GraphSimulationSettings['linkSpring']                   |
# | simulationLinkDistance                 | Minimum link distance.                                                                                                                                                                                                                                                               | 2         | GraphSimulationSettings['linkDistance']                 |
# | simulationLinkDistRandomVariationRange | Range of random link distance values.                                                                                                                                                                                                                                                | [1, 1.2]  | GraphSimulationSettings['linkDistRandomVariationRange'] |
# | simulationRepulsionFromMouse           | Repulsion coefficient from mouse position. The repulsion force is activated by pressing the right mouse button.                                                                                                                                                                      | 2         | GraphSimulationSettings['repulsionFromMouse']           |
# | simulationFriction                     | Friction coefficient.                                                                                                                                                                                                                                                                | 0.85      | GraphSimulationSettings['friction']                     |
# | simulationImpulse                      | Coefficient of simulation impulse from 0 to 1. If `undefined`, the graph will not apply a new impulse to the renders during adding or removing data items, but instead will use the current simulation impulse value from the graph. Has no impact if `disableSimulation` is `true`. | undefined | number                                                  |
#
#
# ### SimulationEventConfig
#
# | name                | description                                                                                                                                                                                                                                                                                                                                                | type                                 |
# |:--------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:-------------------------------------|
# | onSimulationStart   | Callback function that will be called when the simulation starts.                                                                                                                                                                                                                                                                                          | GraphSimulationSettings['onStart']   |
# | onSimulationEnd     | Callback function that will be called when the simulation stops.                                                                                                                                                                                                                                                                                           | GraphSimulationSettings['onEnd']     |
# | onSimulationPause   | Callback function that will be called when the simulation is paused.                                                                                                                                                                                                                                                                                       | GraphSimulationSettings['onPause']   |
# | onSimulationRestart | Callback function that will be called when the simulation is restarted.                                                                                                                                                                                                                                                                                    | GraphSimulationSettings['onRestart'] |
# | onSimulationTick    | Callback function that will be called on every tick of the simulation.\n\n* @param {number} alpha - The value of alpha will decrease over time as the simulation "cools down".\n* @param {number | undefined} index - The index of the hovered point.\n* @param {[number, number] | undefined} pointPosition - The position of the point under the cursor. | GraphSimulationSettings['onTick']    |
#
#
# ## cosmos/config.ts
#
# ### GraphEvents
#
# | name             | description                                                                                                        | type                                                                                                                                                                                     |
# |:-----------------|:-------------------------------------------------------------------------------------------------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | onClick          | Callback function for canvas click events. If a point is clicked, its index and position are provided.             | (index: number | undefined, pointPosition: [number, number] | undefined, event: MouseEvent) => void                                                                                      |
# | onMouseMove      | Callback function for mouse movement events. If the mouse moves over a point, its index and position are provided. | (index: number | undefined, pointPosition: [number, number] | undefined, event: MouseEvent) => void                                                                                      |
# | onPointMouseOver | Callback function for when a point appears under the mouse due to an event.                                        | (index: number, pointPosition: [number, number], event: MouseEvent | D3DragEvent<HTMLCanvasElement, undefined, Hovered> | D3ZoomEvent<HTMLCanvasElement, undefined> | undefined) => void |
# | onPointMouseOut  | Callback function for when a point is no longer under the mouse pointer due to various events.                     | (event: MouseEvent | D3ZoomEvent<HTMLCanvasElement, undefined> | D3DragEvent<HTMLCanvasElement, undefined, Hovered> | undefined) => void                                                 |
# | onZoomStart      | Callback function when zooming or panning starts, with an indication if it's user-driven.                          | (e: D3ZoomEvent<HTMLCanvasElement, undefined>, userDriven: boolean) => void                                                                                                              |
# | onZoom           | Callback function invoked continuously during zooming or panning.                                                  | (e: D3ZoomEvent<HTMLCanvasElement, undefined>, userDriven: boolean) => void                                                                                                              |
# | onZoomEnd        | Callback function called when zooming or panning ends.                                                             | (e: D3ZoomEvent<HTMLCanvasElement, undefined>, userDriven: boolean) => void                                                                                                              |
# | onDragStart      | Callback function called at the start of a drag event.                                                             | (e: D3DragEvent<HTMLCanvasElement, undefined, Hovered>) => void                                                                                                                          |
# | onDrag           | Callback function invoked continuously during dragging events.                                                     | (e: D3DragEvent<HTMLCanvasElement, undefined, Hovered>) => void                                                                                                                          |
# | onDragEnd        | Callback function called when dragging ends.                                                                       | (e: D3DragEvent<HTMLCanvasElement, undefined, Hovered>) => void                                                                                                                          |
#
#
# ### GraphSimulationSettings
#
# | name                         | description                                                                         | default   | type                                                                             |
# |:-----------------------------|:------------------------------------------------------------------------------------|:----------|:---------------------------------------------------------------------------------|
# | decay                        | Decay coefficient controlling simulation cooldown. Default is 5000.                 | 5000      | number                                                                           |
# | gravity                      | Gravity force coefficient. Default is 0.25.                                         | 0.25      | number                                                                           |
# | center                       | Center-of-mass force coefficient. Default is 0.                                     | 0         | number                                                                           |
# | repulsion                    | Repulsion force coefficient. Default is 1.0.                                        | 1.0       | number                                                                           |
# | repulsionTheta               | Detailed calculation parameter for the Many-Body force. Default is 1.15.            | 1.15      | number                                                                           |
# | repulsionQuadtreeLevels      | Approximation depth when using quadtree. Default is 12.                             | 12        | number                                                                           |
# | linkSpring                   | Link spring force coefficient. Default is 1.                                        | 1         | number                                                                           |
# | linkDistance                 | Minimum distance for links. Default is 10.                                          | 10        | number                                                                           |
# | linkDistRandomVariationRange | Random link distance variation; Default is [1, 1.2].                                | [1, 1.2]  | number[]                                                                         |
# | repulsionFromMouse           | Repulsion from mouse coefficient; activated by right click. Default is 2.           | 2         | number                                                                           |
# | friction                     | Friction coefficient. Default is 0.85.                                              | 0.85      | number                                                                           |
# | onStart                      | Callback when simulation starts.                                                    | nan       | () => void                                                                       |
# | onTick                       | Callback on every simulation tick. Provides cooling factor and optional point data. | nan       | (alpha: number, hoveredIndex?: number, pointPosition?: [number, number]) => void |
# | onEnd                        | Callback when simulation ends.                                                      | nan       | () => void                                                                       |
# | onPause                      | Callback when simulation is paused.                                                 | nan       | () => void                                                                       |
# | onRestart                    | Callback when simulation is restarted.                                              | nan       | () => void                                                                       |
#
#
# ### GraphConfigInterface
#
# | name                           | description                                                                             | default   | type                                                      |
# |:-------------------------------|:----------------------------------------------------------------------------------------|:----------|:----------------------------------------------------------|
# | disableSimulation              | Disable simulation and render graph using predefined point positions. Default is false. | False     | boolean                                                   |
# | backgroundColor                | Canvas background color; can be hex or RGBA array. Default is '#222222'.                | #222222   | string | [number, number, number, number]                 |
# | spaceSize                      | Simulation space size with a max of 8192. Default is 4096.                              | 4096      | number                                                    |
# | defaultPointColor              | Default color for points when unspecified. Default is '#b3b3b3'.                        | #b3b3b3   | string | [number, number, number, number]                 |
# | pointGreyoutOpacity            | Opacity of points when greyed-out during selection. Default is 0.1.                     | 0.1       | number                                                    |
# | defaultPointSize               | Default size for points when unspecified. Default size is 4.                            | 4         | number                                                    |
# | pointSizeScale                 | Scale factor for point size. Default is 1.                                              | 1         | number                                                    |
# | hoveredPointCursor             | Cursor style when hovering over a point. Default is 'auto'.                             | auto      | string                                                    |
# | renderHoveredPointRing         | Toggle rendering of ring around hovered point. Default is false.                        | False     | boolean                                                   |
# | hoveredPointRingColor          | Color of ring around hovered points, either hex or RGBA. Default is 'white'.            | white     | string | [number, number, number, number]                 |
# | focusedPointRingColor          | Color of ring around focused points, either hex or RGBA. Default is 'white'.            | white     | string | [number, number, number, number]                 |
# | focusedPointIndex              | Index of the focused point; overrides other methods. Default is undefined.              | nan       | number                                                    |
# | renderLinks                    | Toggle the rendering of links between points. Default is true.                          | True      | boolean                                                   |
# | defaultLinkColor               | Default color for links, hex or RGBA format. Default is '#666666'.                      | #666666   | string | [number, number, number, number]                 |
# | linkGreyoutOpacity             | Opacity of links when greyed-out during selection. Default is 0.1.                      | 0.1       | number                                                    |
# | defaultLinkWidth               | Default width for links when unspecified. Default is 1.                                 | 1         | number                                                    |
# | linkWidthScale                 | Scale factor for link width. Default is 1.                                              | 1         | number                                                    |
# | curvedLinks                    | Render links as curved lines if true, otherwise straight. Default is false.             | False     | boolean                                                   |
# | curvedLinkSegments             | Number of segments in a curved line. Default is 19.                                     | 19        | number                                                    |
# | curvedLinkWeight               | Weight affects curve shaping. Default is 0.8.                                           | 0.8       | number                                                    |
# | curvedLinkControlPointDistance | Distance for curve control points. Default is 0.5.                                      | 0.5       | number                                                    |
# | defaultLinkArrows              | Indicator for displaying link arrows. Default is false.                                 | False     | boolean                                                   |
# | linkArrowsSizeScale            | Scale for link arrow size. Default is 1.                                                | 1         | number                                                    |
# | linkVisibilityDistanceRange    | Range for link visibility determining min and max distance. Default is [50, 150].       | [50, 150] | number[]                                                  |
# | linkVisibilityMinTransparency  | Transparency of links at max distance. Default is 0.25.                                 | 0.25      | number                                                    |
# | useQuadtree                    | Use classic quadtree algorithm when true. Default value false.                          | False     | boolean                                                   |
# | simulation                     | Settings associated with simulation dynamics.                                           | nan       | GraphSimulationSettings                                   |
# | events                         | Event listeners and configurations.                                                     | nan       | GraphEvents                                               |
# | showFPSMonitor                 | Toggle the display of WebGL performance monitor. Default is false.                      | False     | boolean                                                   |
# | pixelRatio                     | Ratio related to canvas pixel density. Default is 2.                                    | 2         | number                                                    |
# | scalePointsOnZoom              | Adjust point size on zoom if true. Default is true.                                     | True      | boolean                                                   |
# | initialZoomLevel               | Set the initial zoom level of graph. Default is undefined.                              | nan       | number                                                    |
# | disableZoom                    | Disable zoom functionality in graph. Default is false.                                  | False     | boolean                                                   |
# | enableDrag                     | Enable point dragging within the graph. Default is false.                               | False     | boolean                                                   |
# | fitViewOnInit                  | Fit view to show all points at startup. Default is true.                                | True      | boolean                                                   |
# | fitViewDelay                   | Delay in ms before fitting view. Default is 250.                                        | 250       | number                                                    |
# | fitViewPadding                 | Padding applied when fitting the view. Default is 0.1.                                  | 0.1       | number                                                    |
# | fitViewDuration                | Duration for fitting the view in ms. Default is 250.                                    | 250       | number                                                    |
# | fitViewByPointsInRect          | Specific rectangle area for fitting view. Default is undefined.                         | nan       | [[number, number], [number, number]] | [number, number][] |
# | randomSeed                     | Seed value for layout randomness control. Default is undefined.                         | nan       | number | string                                           |
# | pointSamplingDistance          | Pixel distance for point sampling. Default is 150.                                      | 150       | number                                                    |

# %%
df = json_schema_to_dataframe(json_schemas)
list(df)
# Out:
# ['data.ts', 'config.ts', 'labels.ts', 'simulation.ts', 'cosmos/config.ts']

# %%
# Out:
#                                       name  \
# 0                          simulationDecay
# 1                        simulationGravity
# 2                         simulationCenter
# 3                      simulationRepulsion
# 4                 simulationRepulsionTheta
# 5        simulationRepulsionQuadtreeLevels
# 6                     simulationLinkSpring
# 7                   simulationLinkDistance
# 8   simulationLinkDistRandomVariationRange
# 9             simulationRepulsionFromMouse
# 10                      simulationFriction
# 11                       simulationImpulse
#
#                                                  type  \
# 0                    GraphSimulationSettings['decay']
# 1                  GraphSimulationSettings['gravity']
# 2                   GraphSimulationSettings['center']
# 3                GraphSimulationSettings['repulsion']
# 4           GraphSimulationSettings['repulsionTheta']
# 5   GraphSimulationSettings['repulsionQuadtreeLeve...
# 6               GraphSimulationSettings['linkSpring']
# 7             GraphSimulationSettings['linkDistance']
# 8   GraphSimulationSettings['linkDistRandomVariati...
# 9       GraphSimulationSettings['repulsionFromMouse']
# 10                GraphSimulationSettings['friction']
# 11                                             number
#
#                                           description  optional    default
# 0   Decay coefficient. Use bigger values if you wa...      True       1000
# 1                          Gravity force coefficient.      True          0
# 2         Centering to center mass force coefficient.      True          0
# 3                        Repulsion force coefficient.      True        0.1
# 4   Decreases / increases the detalization of the ...      True        1.7
# 5   Barnes–Hut approximation depth. Can only be us...      True         12
# 6                      Link spring force coefficient.      True          1
# 7                              Minimum link distance.      True          2
# 8               Range of random link distance values.      True   [1, 1.2]
# 9   Repulsion coefficient from mouse position. The...      True          2
# 10                              Friction coefficient.      True       0.85
# 11  Coefficient of simulation impulse from 0 to 1....      True  undefined

# %%
t = property_groups['GraphSimulationSettings']
t[0]
# Out:
# {'name': 'decay',
#  'type': 'number',
#  'description': 'Decay coefficient controlling simulation cooldown. Default is 5000.',
#  'optional': True,
#  'default': 5000}

# %% [markdown]
# # Orphan utils developped on the way

# %% [markdown]
# See [github_raw_utils.py gist](https://gist.github.com/thorwhalen/92fa45e8f36f8caf155ea3012ad61629): `ensure_raw_github_url`, `get_url_text`, `ensure_text`, `might_be_url`.
